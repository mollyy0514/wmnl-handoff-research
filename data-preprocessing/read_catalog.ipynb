# %%
import json
from pprint import pprint

filename = '../catalog.json'

# Read JSON from a file
with open(filename, 'r') as file:
    catalog = json.load(file)

catalog_by_date = []
for key, content in catalog.items():
    if not isinstance(content, dict):
        # print("The content is not a dictionary.")
        print(key, content)
        continue
    
    # print("The content is a dictionary.")
    if isinstance(content['routes'], dict) and not content['routes']:
        # print("content['routes'] is an empty dictionary.")
        print(key, content['routes'])
        continue
    
    print(key, content['routes'])
    
    routes = content['routes']
    for route, content in routes.items():
        print(key, route, content['stations'], content['dates'])
        # print(content['dates'])
        
        for date, exps in content['dates'].items():
            # print(date, dataset)
            for dataset in exps:
                print(date, dataset)
                catalog_by_date.append({
                    "date": date,
                    "line": key,
                    "das": route,
                    "stations": content['stations'],
                    **dataset
                })

# Sort the dictionary by keys
catalog_by_date = sorted(catalog_by_date, key=lambda x: x["date"])
# Out:
# Worksheet https://docs.google.com/spreadsheets/d/1kWy5pK14Hb18T5t7fNBjKaxIUpGOSa_71pcbwFkHSfc/edit?usp=sharing
# BR {'動物園:萬芳醫院': {'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'], 'dates': {'2023-03-16': [{'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 12, 'directions': 'RFRFRFRFRFRF', 'period': 'evening', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}], '2023-03-26': [{'name': 'Bandlock_Udp_All_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}], '2023-04-01': [{'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'}, 'comment': ''}], '2023-04-10': [{'name': 'Experiment1', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}, {'name': 'Experiment2', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}, {'name': 'Experiment3', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'}, 'comment': ''}], '2023-04-17': [{'name': 'Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_All_LTE_RM500Q', 'trips': 4, 'directions': 'FFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1_B3_RM500Q', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'mod ...
# BR 動物園:萬芳醫院 ['動物園', '木柵', '萬芳社區', '萬芳醫院'] {'2023-03-16': [{'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 12, 'directions': 'RFRFRFRFRFRF', 'period': 'evening', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}], '2023-03-26': [{'name': 'Bandlock_Udp_All_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}], '2023-04-01': [{'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'}, 'comment': ''}], '2023-04-10': [{'name': 'Experiment1', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}, {'name': 'Experiment2', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}, {'name': 'Experiment3', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'}, 'comment': ''}], '2023-04-17': [{'name': 'Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_All_LTE_RM500Q', 'trips': 4, 'directions': 'FFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'}, 'comment': ''}, {'name': 'Bandlock_Udp_All_LTE_B1_B3_RM500Q', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'setti ...
# 2023-03-16 {'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 12, 'directions': 'RFRFRFRFRFRF', 'period': 'evening', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}
# 2023-03-26 {'name': 'Bandlock_Udp_All_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}
# 2023-04-01 {'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}
# 2023-04-01 {'name': 'Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'}, 'comment': ''}
# 2023-04-10 {'name': 'Experiment1', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'}, 'comment': ''}
# 2023-04-10 {'name': 'Experiment2', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}
# 2023-04-10 {'name': 'Experiment3', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_All_LTE_RM500Q', 'trips': 4, 'directions': 'FFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_B1_B3_RM500Q', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1', 'qc03': 'B3'}, 'comment': ''}
# 2023-04-17 {'name': 'Bandlock_Udp_All_LTE_B7_B8_RM500Q', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B7', 'qc03': 'B8'}, 'comment': ''}
# 2023-05-04 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-05-07 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 7, 'directions': 'RFRFRFR', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-05-15 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-05-24 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 8, 'directions': 'RFRFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-05-26 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 10, 'directions': 'RFRFRFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-06-12 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 10, 'directions': 'RFRFRFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': ''}
# 2023-06-13 {'name': 'Bandlock_8_Schemes_Phone', 'trips': 9, 'directions': 'FRFRFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}, 'comment': '#01 實驗失敗, 因此編號為 #02-#10.'}
# 2023-06-14 {'name': 'Modem_Action_Test', 'trips': 2, 'directions': 'RF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'test', 'qc03': 'test'}, 'comment': ''}
# 2023-06-15 {'name': 'Bandlock_B1_B3_B7_B8_Dupl_Phone', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'B1', 'sm01': 'B1', 'sm02': 'B3', 'sm03': 'B3', 'sm04': 'B7', 'sm05': 'B7', 'sm06': 'B8', 'sm07': 'B8'}, 'comment': ''}
# 2023-06-15 {'name': 'Bandlock_All_B3_B7_B8_Dupl_Phone', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B3', 'sm04': 'B7', 'sm05': 'B7', 'sm06': 'B8', 'sm07': 'B8'}, 'comment': ''}
# 2023-06-15 {'name': 'Bandlock_LTE_B3_B7_B8_Dupl_Phone', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'LTE', 'sm01': 'LTE', 'sm02': 'B3', 'sm03': 'B3', 'sm04': 'B7', 'sm05': 'B7', 'sm06': 'B8', 'sm07': 'B8'}, 'comment': ''}
# 2023-06-15 {'name': 'Bandlock_LTE_LTEb3_LTEb7_LTEb8_Dupl_Phone', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'LTE', 'sm01': 'LTE', 'sm02': 'LTEb3', 'sm03': 'LTEb3', 'sm04': 'LTEb7', 'sm05': 'LTEb7', 'sm06': 'LTEb8', 'sm07': 'LTEb8'}, 'comment': 'sm03 #03 沒有 mi2log.'}
# 2023-06-15 {'name': 'Bandlock_LTEb1_LTEb3_LTEb7_LTEb8_Dupl_Phone', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'LTEb1', 'sm01': 'LTEb1', 'sm02': 'LTEb3', 'sm03': 'LTEb3', 'sm04': 'LTEb7', 'sm05': 'LTEb7', 'sm06': 'LTEb8', 'sm07': 'LTEb8'}, 'comment': ''}
# 2023-06-21 {'name': 'Modem_Action_Test', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'test', 'qc03': 'test'}, 'comment': ''}
# 2023-06-24 {'name': 'Control_Group', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc03': 'All'}, 'comment': ''}
# 2023-06-24 {'name': 'Modem_Action_Test', 'trips': 5, 'directions': 'RRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'test', 'qc03': 'test'}, 'comment': ''}
# 2023-08-29 {'name': 'Modem_Action_Test', 'trips': 4, 'directions': 'RFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'test', 'qc03': 'test'}, 'comment': ''}
# 2023-08-29 {'name': 'Modem_Control_Group', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'modem', 'terminal': '', 'settings': {'qc00': 'All', 'qc03': 'All'}, 'comment': ''}
# BR 動物園:辛亥 ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥'] {'2023-08-16': [{'name': 'Phone_Experiment_LTE_NR', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'LTE', 'sm01': 'All'}, 'comment': ''}]}
# 2023-08-16 {'name': 'Phone_Experiment_LTE_NR', 'trips': 6, 'directions': 'RFRFRF', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'LTE', 'sm01': 'All'}, 'comment': ''}
# BR 科技大樓:中山國中 ['科技大樓', '大安', '忠孝復興', '南京復興', '中山國中'] {'2023-08-21': [{'name': 'Phone_Experiment_LTE_NR', 'trips': 6, 'directions': 'FRFRFR', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'LTE'}, 'comment': ''}]}
# 2023-08-21 {'name': 'Phone_Experiment_LTE_NR', 'trips': 6, 'directions': 'FRFRFR', 'period': 'afternoon', 'weather': '', 'gps': 'no', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'LTE'}, 'comment': ''}
# BR 動物園:南港展覽館 ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥', '麟光', '六張犁', '科技大樓', '大安', '忠孝復興', '南京復興', '中山國中', '松山機場', '大直', '劍南路', '西湖', '港墘', '文德', '內湖', '大湖公園', '葫洲', '東湖', '南港軟體園區', '南港展覽館'] {'2023-09-12_2': [{'name': 'Bandlock_9_Schemes_Phone_UDP', 'trips': 2, 'directions': 'FR', 'period': 'afternoon', 'weather': 'sunny', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}], '2023-09-21': [{'name': 'Bandlock_9_Schemes_Phone_UDP', 'trips': 2, 'directions': ['動物園:南港展覽館', '南港展覽館:動物園'], 'period': 'afternoon', 'weather': 'cloudy', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': 'lpt2', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}]}
# 2023-09-12_2 {'name': 'Bandlock_9_Schemes_Phone_UDP', 'trips': 2, 'directions': 'FR', 'period': 'afternoon', 'weather': 'sunny', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}
# 2023-09-21 {'name': 'Bandlock_9_Schemes_Phone_UDP', 'trips': 2, 'directions': ['動物園:南港展覽館', '南港展覽館:動物園'], 'period': 'afternoon', 'weather': 'cloudy', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'UDP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': 'lpt2', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}
# BR 動物園:麟光 ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥', '麟光'] {'2023-09-12_2': [{'name': 'Bandlock_9_Schemes_Phone_TCP', 'trips': 1, 'directions': 'F', 'period': 'afternoon', 'weather': 'sunny', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'TCP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}]}
# 2023-09-12_2 {'name': 'Bandlock_9_Schemes_Phone_TCP', 'trips': 1, 'directions': 'F', 'period': 'afternoon', 'weather': 'sunny', 'gps': 'yes', 'telecom': 'CHT', 'protocol': 'TCP', 'length': '250 bytes', 'bitrate': '1 Mbps', 'device': 'phone', 'terminal': '', 'settings': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'comment': ''}
# R {}
# G {}
# O {}
# BL {}
# Y {}
# A {}
# V {}
# K {}
# HSR {}
# TSR {}

# %%
pprint(catalog_by_date, sort_dicts=False)
# Out:
# [{'date': '2023-03-16',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q',
#   'trips': 12,
#   'directions': 'RFRFRFRFRFRF',
#   'period': 'evening',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'},
#   'comment': ''},
#  {'date': '2023-03-26',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_RM500Q',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc02': 'All', 'qc03': 'All'},
#   'comment': ''},
#  {'date': '2023-04-01',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_B1_B3_B7_B8_RM500Q',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#   'comment': ''},
#  {'date': '2023-04-01',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'},
#   'comment': ''},
#  {'date': '2023-04-10',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Experiment1',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'},
#   'comment': ''},
#  {'date': '2023-04-10',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Experiment2',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#   'comment': ''},
#  {'date': '2023-04-10',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Experiment3',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_All_LTE_RM500Q',
#   'trips': 4,
#   'directions': 'FFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B1_B3_RM500Q',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1', 'qc03': 'B3'},
#   'comment': ''},
#  {'date': '2023-04-17',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_Udp_All_LTE_B7_B8_RM500Q',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B7', 'qc03': 'B8'},
#   'comment': ''},
#  {'date': '2023-05-04',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-05-07',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 7,
#   'directions': 'RFRFRFR',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-05-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-05-24',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 8,
#   'directions': 'RFRFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-05-26',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 10,
#   'directions': 'RFRFRFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-06-12',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 10,
#   'directions': 'RFRFRFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': ''},
#  {'date': '2023-06-13',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_8_Schemes_Phone',
#   'trips': 9,
#   'directions': 'FRFRFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B3B7B8',
#                'sm01': 'B3',
#                'sm02': 'B7',
#                'sm03': 'B8',
#                'sm04': 'B3B7',
#                'sm05': 'B3B8',
#                'sm06': 'B7B8',
#                'sm07': 'LTE'},
#   'comment': '#01 實驗失敗, 因此編號為 #02-#10.'},
#  {'date': '2023-06-14',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Modem_Action_Test',
#   'trips': 2,
#   'directions': 'RF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'test', 'qc03': 'test'},
#   'comment': ''},
#  {'date': '2023-06-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_B1_B3_B7_B8_Dupl_Phone',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'B1',
#                'sm01': 'B1',
#                'sm02': 'B3',
#                'sm03': 'B3',
#                'sm04': 'B7',
#                'sm05': 'B7',
#                'sm06': 'B8',
#                'sm07': 'B8'},
#   'comment': ''},
#  {'date': '2023-06-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_All_B3_B7_B8_Dupl_Phone',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'All',
#                'sm01': 'All',
#                'sm02': 'B3',
#                'sm03': 'B3',
#                'sm04': 'B7',
#                'sm05': 'B7',
#                'sm06': 'B8',
#                'sm07': 'B8'},
#   'comment': ''},
#  {'date': '2023-06-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_LTE_B3_B7_B8_Dupl_Phone',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'LTE',
#                'sm01': 'LTE',
#                'sm02': 'B3',
#                'sm03': 'B3',
#                'sm04': 'B7',
#                'sm05': 'B7',
#                'sm06': 'B8',
#                'sm07': 'B8'},
#   'comment': ''},
#  {'date': '2023-06-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_LTE_LTEb3_LTEb7_LTEb8_Dupl_Phone',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'LTE',
#                'sm01': 'LTE',
#                'sm02': 'LTEb3',
#                'sm03': 'LTEb3',
#                'sm04': 'LTEb7',
#                'sm05': 'LTEb7',
#                'sm06': 'LTEb8',
#                'sm07': 'LTEb8'},
#   'comment': 'sm03 #03 沒有 mi2log.'},
#  {'date': '2023-06-15',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Bandlock_LTEb1_LTEb3_LTEb7_LTEb8_Dupl_Phone',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'LTEb1',
#                'sm01': 'LTEb1',
#                'sm02': 'LTEb3',
#                'sm03': 'LTEb3',
#                'sm04': 'LTEb7',
#                'sm05': 'LTEb7',
#                'sm06': 'LTEb8',
#                'sm07': 'LTEb8'},
#   'comment': ''},
#  {'date': '2023-06-21',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Modem_Action_Test',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'test', 'qc03': 'test'},
#   'comment': ''},
#  {'date': '2023-06-24',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Control_Group',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc03': 'All'},
#   'comment': ''},
#  {'date': '2023-06-24',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Modem_Action_Test',
#   'trips': 5,
#   'directions': 'RRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'test', 'qc03': 'test'},
#   'comment': ''},
#  {'date': '2023-08-16',
#   'line': 'BR',
#   'das': '動物園:辛亥',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥'],
#   'name': 'Phone_Experiment_LTE_NR',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'LTE', 'sm01': 'All'},
#   'comment': ''},
#  {'date': '2023-08-21',
#   'line': 'BR',
#   'das': '科技大樓:中山國中',
#   'stations': ['科技大樓', '大安', '忠孝復興', '南京復興', '中山國中'],
#   'name': 'Phone_Experiment_LTE_NR',
#   'trips': 6,
#   'directions': 'FRFRFR',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'All', 'sm01': 'LTE'},
#   'comment': ''},
#  {'date': '2023-08-29',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Modem_Action_Test',
#   'trips': 4,
#   'directions': 'RFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'test', 'qc03': 'test'},
#   'comment': ''},
#  {'date': '2023-08-29',
#   'line': 'BR',
#   'das': '動物園:萬芳醫院',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'],
#   'name': 'Modem_Control_Group',
#   'trips': 6,
#   'directions': 'RFRFRF',
#   'period': 'afternoon',
#   'weather': '',
#   'gps': 'no',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'modem',
#   'terminal': '',
#   'settings': {'qc00': 'All', 'qc03': 'All'},
#   'comment': ''},
#  {'date': '2023-09-12_2',
#   'line': 'BR',
#   'das': '動物園:南港展覽館',
#   'stations': ['動物園',
#                '木柵',
#                '萬芳社區',
#                '萬芳醫院',
#                '辛亥',
#                '麟光',
#                '六張犁',
#                '科技大樓',
#                '大安',
#                '忠孝復興',
#                '南京復興',
#                '中山國中',
#                '松山機場',
#                '大直',
#                '劍南路',
#                '西湖',
#                '港墘',
#                '文德',
#                '內湖',
#                '大湖公園',
#                '葫洲',
#                '東湖',
#                '南港軟體園區',
#                '南港展覽館'],
#   'name': 'Bandlock_9_Schemes_Phone_UDP',
#   'trips': 2,
#   'directions': 'FR',
#   'period': 'afternoon',
#   'weather': 'sunny',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'All',
#                'sm01': 'All',
#                'sm02': 'B3',
#                'sm03': 'B7',
#                'sm04': 'B8',
#                'sm05': 'B3B7',
#                'sm06': 'B3B8',
#                'sm07': 'B7B8',
#                'sm08': 'LTE'},
#   'comment': ''},
#  {'date': '2023-09-12_2',
#   'line': 'BR',
#   'das': '動物園:麟光',
#   'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥', '麟光'],
#   'name': 'Bandlock_9_Schemes_Phone_TCP',
#   'trips': 1,
#   'directions': 'F',
#   'period': 'afternoon',
#   'weather': 'sunny',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'TCP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': '',
#   'settings': {'sm00': 'All',
#                'sm01': 'All',
#                'sm02': 'B3',
#                'sm03': 'B7',
#                'sm04': 'B8',
#                'sm05': 'B3B7',
#                'sm06': 'B3B8',
#                'sm07': 'B7B8',
#                'sm08': 'LTE'},
#   'comment': ''},
#  {'date': '2023-09-21',
#   'line': 'BR',
#   'das': '動物園:南港展覽館',
#   'stations': ['動物園',
#                '木柵',
#                '萬芳社區',
#                '萬芳醫院',
#                '辛亥',
#                '麟光',
#                '六張犁',
#                '科技大樓',
#                '大安',
#                '忠孝復興',
#                '南京復興',
#                '中山國中',
#                '松山機場',
#                '大直',
#                '劍南路',
#                '西湖',
#                '港墘',
#                '文德',
#                '內湖',
#                '大湖公園',
#                '葫洲',
#                '東湖',
#                '南港軟體園區',
#                '南港展覽館'],
#   'name': 'Bandlock_9_Schemes_Phone_UDP',
#   'trips': 2,
#   'directions': ['動物園:南港展覽館', '南港展覽館:動物園'],
#   'period': 'afternoon',
#   'weather': 'cloudy',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': 'lpt2',
#   'settings': {'sm00': 'All',
#                'sm01': 'All',
#                'sm02': 'B3',
#                'sm03': 'B7',
#                'sm04': 'B8',
#                'sm05': 'B3B7',
#                'sm06': 'B3B8',
#                'sm07': 'B7B8',
#                'sm08': 'LTE'},
#   'comment': ''}]

# %%
# 要选择的日期列表
selected_dates = ["2023-08-21", "2023-09-21", "2023-10-11"]
selected_data = []

# 遍历要选择的日期
for date in selected_dates:
    for item in catalog_by_date:
        if item['date'].startswith(date):
            selected_data.append(item)

# 打印选定的数据
pprint(selected_data, sort_dicts=False)
# Out:
# [{'date': '2023-09-21',
#   'line': 'BR',
#   'das': '動物園:南港展覽館',
#   'stations': ['動物園',
#                '木柵',
#                '萬芳社區',
#                '萬芳醫院',
#                '辛亥',
#                '麟光',
#                '六張犁',
#                '科技大樓',
#                '大安',
#                '忠孝復興',
#                '南京復興',
#                '中山國中',
#                '松山機場',
#                '大直',
#                '劍南路',
#                '西湖',
#                '港墘',
#                '文德',
#                '內湖',
#                '大湖公園',
#                '葫洲',
#                '東湖',
#                '南港軟體園區',
#                '南港展覽館'],
#   'name': 'Bandlock_9_Schemes_Phone_UDP',
#   'trips': 2,
#   'directions': ['動物園:南港展覽館', '南港展覽館:動物園'],
#   'period': 'afternoon',
#   'weather': 'cloudy',
#   'gps': 'yes',
#   'telecom': 'CHT',
#   'protocol': 'UDP',
#   'length': '250 bytes',
#   'bitrate': '1 Mbps',
#   'device': 'phone',
#   'terminal': 'lpt2',
#   'settings': {'sm00': 'All',
#                'sm01': 'All',
#                'sm02': 'B3',
#                'sm03': 'B7',
#                'sm04': 'B8',
#                'sm05': 'B3B7',
#                'sm06': 'B3B8',
#                'sm07': 'B7B8',
#                'sm08': 'LTE'},
#   'comment': ''}]
