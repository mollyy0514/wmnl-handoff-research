# %%
import os, sys
import shutil

def makedir(dirpath, mode=0):  # mode=1: show message, mode=0: hide message
    if os.path.isdir(dirpath):
        if mode:
            print("mkdir: cannot create directory '{}': directory has already existed.".format(dirpath))
        return
    ### recursively make directory
    _temp = []
    while not os.path.isdir(dirpath):
        _temp.append(dirpath)
        dirpath = os.path.dirname(dirpath)
    while _temp:
        dirpath = _temp.pop()
        print("mkdir", dirpath)
        os.mkdir(dirpath)

# %%
database = "/home/wmnlab/D/database/"
dates = ["2023-04-10"]
exps = {  # experiment_name: (number_of_experiment_rounds, list_of_experiment_round)
            # If the list is None, it will not list as directories.
            # If the list is empty, it will list all directories in the current directory by default.
            # If the number of experiment times != the length of existing directories of list, it would trigger warning and skip the directory.
    # "_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q": (4, ["#{:02d}".format(i+1) for i in range(4)]),
    # "_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q": (4, ["#{:02d}".format(i+1) for i in range(4)]),
    # "_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q": (4, ["#{:02d}".format(i+1) for i in range(4)]),
    # "_Bandlock_Udp_All_LTE_All_LTE_RM500Q": (4, ["#{:02d}".format(i+1) for i in range(4)]),
    # "_Bandlock_Udp_All_LTE_B1_B3_RM500Q": (2, ["#{:02d}".format(i+1) for i in range(2)]),
    # "_Bandlock_Udp_All_LTE_B7_B8_RM500Q": (2, ["#{:02d}".format(i+1) for i in range(2)]),
    "_Experiment1": (4, ["#{:02d}".format(i+1) for i in range(2)]),
    "_Experiment1": (4, ["#{:02d}".format(i+1) for i in range(2)]),
    "_Experiment1": (4, ["#{:02d}".format(i+1) for i in range(2)]),
}
_devices = [
    ["qc00", "qc01", "qc02", "qc03"],
    ["qc00", "qc01", "qc02", "qc03"],
    ["qc00", "qc01", "qc02", "qc03"],
    # ["qc00", "qc01", "qc02", "qc03"],
    # ["qc00", "qc01", "qc02", "qc03"],
    # ["qc00", "qc01", "qc02", "qc03"],
]
folders = [
    'data',
    # 'middle',
    # 'raw',
    # 'statistics',
]

# %%
targetdir = os.path.join(database, 'temp')
for date in dates:
    db1 = os.path.join(targetdir, date)
    makedir(db1)
    for (expr, (times, traces)), devices in zip(exps.items(), _devices):
        db2 = os.path.join(db1, expr)
        makedir(db2)
        for dev in devices:
            db3 = os.path.join(db2, dev)
            makedir(db3)
            for trace in traces:
                db4 = os.path.join(db3, trace)
                makedir(db4)
                for folder in folders:
                    shutil.copytree(os.path.join(database, date, expr, dev, trace, folder), os.path.join(db4, folder))
# Out:
# mkdir /home/wmnlab/D/database/temp/2023-04-10
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01
# mkdir /home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02

# %%
targetdir = os.path.join(database, 'temp')
for date in dates:
    db1 = os.path.join(targetdir, date)
    files = [os.path.join(database, date, s) for s in os.listdir(os.path.join(database, date)) if os.path.isfile(os.path.join(database, date, s))]
    for file in files:
        shutil.copy2(file, os.path.join(db1, os.path.basename(file)))

# %%
targetdir = os.path.join(database, 'temp')
for date in dates:
    db1 = os.path.join(targetdir, date)
    zf1 = os.path.join(targetdir, f'{date}_spl.zip')
    os.system(f'zip -r {zf1} {db1} -s 3g')
# Out:
#   adding: home/wmnlab/D/database/temp/2023-04-10/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/cimon_2023-04-10_15-02-27.csv (deflated 92%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/cimon_2023-04-10_15-02-27_new.csv (deflated 92%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/time_sync_lpt3.json (deflated 57%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/04-10.md (deflated 54%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_ml1.csv (deflated 82%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/udp_uplk_loss_latency.csv (deflated 84%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_nr_ml1.csv (deflated 84%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_ml1.csv (deflated 82%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_ml1.csv (deflated 84%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/udp_uplk_loss_latency.csv (deflated 84%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_ml1.csv (deflated 82%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/ (stored 0%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/udp_uplk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_nr_ml1.csv (deflated 83%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_rrc.csv (deflated 94%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/udp_dnlk_loss_latency.csv (deflated 85%)
#   adding: home/wmnlab/D/database/temp/2023-04-10/_Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_ml1.csv (deflated 83%)
