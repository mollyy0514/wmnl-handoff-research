# %%
### Filename: auto_mv_files.ipynb

"""
An automation script to categorize raw data captured in each experiment.

This script can be divided into four parts:
    User Settings: Modify settings to fit your experiment data.
    Stage 0:       Check files to make sure the numbers of each type of files are reasonable.
    Stage 1:       Categorize files in chronological order
    Stage 2:       Categorize files/directories with experiment names

Before you go to stage 1 & 2, 
you need to upload (manually or using py-script) all the raw data to database into specific directories, 
and remove the redundant files manually.

Author: Yuan-Jye Chen
"""

"""
    Future Development Plan
        (1) Write a script to transfer data via wi-fi automatically.

"""
# Out:
# '\n    Future Development Plan\n        (1) Write a script to transfer data via wi-fi automatically.\n\n'

# %% [markdown]
# ### Import Modules & Initialization

# %%
import os
import sys
import shutil
from genericpath import exists
from pprint import pprint

# ********************* User Settings *********************
database = "/home/wmnlab/D/database/"

# TODO: Revise Parameters
date = "2023-12-16"
Exp_Name = [  # every experiment name should start with '_' (underline)
    # "Bandlock_8_Schemes_Phone",
    # "Bandlock_B1_B3_B7_B8_Dupl_Phone",
    # "Bandlock_All_B3_B7_B8_Dupl_Phone",
    # "Bandlock_LTE_B3_B7_B8_Dupl_Phone",
    # "Bandlock_LTE_LTEb3_LTEb7_LTEb8_Dupl_Phone",
    # "Bandlock_LTEb1_LTEb3_LTEb7_LTEb8_Dupl_Phone",
    # "Modem_Action_Test",
    "UDP_Bandlock_9S_Phone_BR",
]
Exp_Rounds = [
    ["#{:02d}".format(i+1) for i in range(1)],
    # ["#{:02d}".format(i+1) for i in range(4, 8)],
    # ["#{:02d}".format(i+1) for i in range(8, 12)],
    # ["#{:02d}".format(i+1) for i in range(12, 16)],
    # ["#{:02d}".format(i+1) for i in range(16, 20)],
]
devices = sorted([
    "sm00",
    "sm01",
    "sm02",
    "sm03",
    "sm04",
    "sm05",
    "sm06",
    "sm07",
    "sm08",
    # "qc00",
    # "qc01",
    # "qc02",
    # "qc03",
])

# TODO: Optional Settings
delete_after_copy = True
items_copy = [  # needs to make multiple copies
    # "at_log",
    # "cimon",
    # "mi2log",
]
items_move = [  # only needs to move files
    # "at_log",
    # "cimon",
    "mi2log",
    # "client_log",
    "client_pcap",
    # "client_ss",
    # "server_log",
    "server_pcap",
    # "server_ss",
]
# *********************************************************

# --------------------- Parameters ---------------------
N = sum([len(expr) for expr in Exp_Rounds])  # rounds of total experiment
db_path = os.path.join(database, date)
raw_path = os.path.join(db_path, "raw_data")
all_dirs = [os.path.join(raw_path, item) for item in ["at_log", "cimon", "mi2log", "client_log", "client_pcap", "client_stats", "server_log", "server_pcap", "server_stats"]]
dirs_copy = [os.path.join(raw_path, item) for item in items_copy]
dirs_move = [os.path.join(raw_path, item) for item in items_move]

# --------------------- Util Functions ---------------------
def makedir(dirpath, mode=0):  # mode=1: show message, mode=0: hide message
    if os.path.isdir(dirpath):
        if mode:
            print("mkdir: cannot create directory '{}': directory has already existed.".format(dirpath))
        return
    ### recursively make directory
    _temp = []
    while not os.path.isdir(dirpath):
        _temp.append(dirpath)
        dirpath = os.path.dirname(dirpath)
    while _temp:
        dirpath = _temp.pop()
        print("mkdir", dirpath)
        os.mkdir(dirpath)

def movedir(dirpath, targetdir):
    ### dirname can be different from basename of dirpath, can be used to rename a directory.
    makedir(targetdir)
    print("mv", dirpath, targetdir)
    shutil.move(dirpath, targetdir)

def savecopy(filepath, targetdir, filename):
    ### filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("cp -p", filepath, os.path.join(targetdir, filename))
    shutil.copy2(filepath, os.path.join(targetdir, filename))  # reserve modified date and some meta data

def savemove(filepath, targetdir, filename):
    ### filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("mv", filepath, os.path.join(targetdir, filename))
    shutil.move(filepath, os.path.join(targetdir, filename))

def delete(filepath):
    if not os.path.exists(filepath):
        print("rm: '{}': No such file or directory".format(filepath))
        return
    print("rm", filepath)
    os.remove(filepath)

def deletedir_empty(filepath):
    if not os.path.exists(filepath):
        print("rmdir: '{}': No such file or directory".format(filepath))
        return
    print("rmdir", filepath)
    os.rmdir(filepath)

def deletedir_nonempty(filepath):
    if not os.path.exists(filepath):
        print("rm -rf: '{}': No such file or directory".format(filepath))
        return
    print("rm -rf", filepath)
    shutil.rmtree(filepath, ignore_errors=True)

# --------------------- Initialization ---------------------
makedir(db_path)
# fsettings = os.path.join(db_path, "experiment-settings.txt")
# if not os.path.exists(fsettings):
#     print("touch", fsettings)
#     open(fsettings, mode='x', encoding="utf-8")

makedir(raw_path)
for dir in all_dirs:
    makedir(dir)

print("Rounds:", N)
print("raw_path:", raw_path)
print("dirs_copy:")
pprint(dirs_copy)
print("dirs_move:")
pprint(dirs_move)
# Out:
# mkdir /home/wmnlab/D/database/2023-08-21
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/at_log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/cimon
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/client_log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/client_stats
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/server_log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/server_stats
# Rounds: 6
# raw_path: /home/wmnlab/D/database/2023-08-21/raw_data
# dirs_copy:
# []
# dirs_move:
# ['/home/wmnlab/D/database/2023-08-21/raw_data/mi2log',
#  '/home/wmnlab/D/database/2023-08-21/raw_data/client_pcap',
#  '/home/wmnlab/D/database/2023-08-21/raw_data/server_pcap']

# %% [markdown]
# ### Check Files
#
# 檢查資料的數量是否正確
#
# cimon（不分趟） =>　機台數量
#
# mi2log => 機台數量*總趟次
#
# client_pcap => 機台數量*總趟次 (Bilink)
#
# server_pcap => 機台數量*總趟次\*2 or 1 (Uplink/Downlink, bilink)
#
# server_stats => 機台數量*總趟次\*2 or 1 (Uplink/Downlink, bilink)

# %%
# --------------------- Stage 0: Check Files ---------------------
print(raw_path)
for item, dir in zip(items_copy, dirs_copy):
    files = sorted(os.listdir(dir))  # default: reverse=False 按字典升冪排列
    print("|_____")
    print("      ", item, len(files))
    pprint(files)
for item, dir in zip(items_move, dirs_move):
    files = sorted(os.listdir(dir))  # default: reverse=False 按字典升冪排列
    print("|_____")
    print("      ", item, len(files))
    pprint(files)
# Out:
# /home/wmnlab/D/database/2023-08-21/raw_data
# |_____
#        mi2log 12
# ['diag_log_sm00_2023-08-21_14-32-43.mi2log',
#  'diag_log_sm00_2023-08-21_14-44-11.mi2log',
#  'diag_log_sm00_2023-08-21_14-57-50.mi2log',
#  'diag_log_sm00_2023-08-21_15-09-15.mi2log',
#  'diag_log_sm00_2023-08-21_15-23-00.mi2log',
#  'diag_log_sm00_2023-08-21_15-34-31.mi2log',
#  'diag_log_sm01_2023-08-21_14-32-43.mi2log',
#  'diag_log_sm01_2023-08-21_14-44-11.mi2log',
#  'diag_log_sm01_2023-08-21_14-57-50.mi2log',
#  'diag_log_sm01_2023-08-21_15-09-15.mi2log',
#  'diag_log_sm01_2023-08-21_15-23-00.mi2log',
#  'diag_log_sm01_2023-08-21_15-34-31.mi2log']
# |_____
#        client_pcap 12
# ['client_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap',
#  'client_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap',
#  'client_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap',
#  'client_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap',
#  'client_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap',
#  'client_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap',
#  'client_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap']
# |_____
#        server_pcap 12
# ['server_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap',
#  'server_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap',
#  'server_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap',
#  'server_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap',
#  'server_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap',
#  'server_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap',
#  'server_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap']

# %% [markdown]
# ### Stage 1 & 2 Categorize

# %%
# --------------------- Stage 1: Categorize In Chronological Order ---------------------
### make a directory for each round of experiments
for i in range(N):
    targetdir = os.path.join(raw_path, "#{:02d}".format(i+1))
    makedir(targetdir)
    # if os.path.isdir(targetdir):
    #     os.rmdir(targetdir)

### copy files
for item, dir in zip(items_copy, dirs_copy):
    files = sorted(os.listdir(dir))
    print("|_____")
    print("      ", item, "({})".format(len(files)))
    for i, dev in enumerate(devices):
        filename = files[i]
        for j in range(N):
            filepath = os.path.join(dir, filename)
            targetdir = os.path.join(raw_path, "#{:02d}".format(j+1), dev, "raw")
            # print("cp -p", filepath, os.path.join(targetdir, filename))
            savecopy(filepath, targetdir, filename)
        if delete_after_copy:
            # print("rm", filepath)
            delete(filepath)

### move files
M = N * len(devices)
for item, dir in zip(items_move, dirs_move):
    _files = sorted(os.listdir(dir))
    print("|_____")
    print("      ", item, "({})".format(len(_files)))
    L = len(_files) // M
    for k in range(L):
        files = _files[k*M : (k+1)*M]
        for i, dev in enumerate(devices):
            for j in range(N):
                filename = files[i*N+j]
                filepath = os.path.join(dir, filename)
                targetdir = os.path.join(raw_path, "#{:02d}".format(j+1), dev, "raw")
                # print("mv", filepath, os.path.join(targetdir, filename))
                savemove(filepath, targetdir, filename)
# Out:
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#02
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#03
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#04
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#05
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#06
# |_____
#        mi2log (12)
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_14-32-43.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00/raw/diag_log_sm00_2023-08-21_14-32-43.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_14-44-11.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00/raw/diag_log_sm00_2023-08-21_14-44-11.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_14-57-50.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00/raw/diag_log_sm00_2023-08-21_14-57-50.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_15-09-15.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00/raw/diag_log_sm00_2023-08-21_15-09-15.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_15-23-00.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00/raw/diag_log_sm00_2023-08-21_15-23-00.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm00_2023-08-21_15-34-31.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00/raw/diag_log_sm00_2023-08-21_15-34-31.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_14-32-43.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01/raw/diag_log_sm01_2023-08-21_14-32-43.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_14-44-11.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01/raw/diag_log_sm01_2023-08-21_14-44-11.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_14-57-50.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01/raw/diag_log_sm01_2023-08-21_14-57-50.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_15-09-15.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01/raw/diag_log_sm01_2023-08-21_15-09-15.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_15-23-00.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01/raw/diag_log_sm01_2023-08-21_15-23-00.mi2log
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01/raw
# mv /home/wmnlab/D/database/2023-08-21/raw_data/mi2log/diag_log_sm01_2023-08-21_15-34-31.mi2log /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01/raw/diag_log_sm01_2023-08-21_15-34-31.mi2log
# |_____
#        client_pcap (12)
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00/raw/client_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/client_pcap/client_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01/raw/client_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap
# |_____
#        server_pcap (12)
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_14-32-37_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_14-44-03_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_14-57-41_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_15-09-07_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_15-22-52_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00/raw/server_pcap_BL_sm00_3200_3201_2023-08-21_15-34-22_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_14-32-37_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_14-44-03_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_14-57-41_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_15-09-07_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_15-22-52_sock.pcap
# mv /home/wmnlab/D/database/2023-08-21/raw_data/server_pcap/server_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01/raw/server_pcap_BL_sm01_3202_3203_2023-08-21_15-34-22_sock.pcap

# %%
# --------------------- Stage 2: Categorize With Experiment Names ---------------------
for j, exp in enumerate(Exp_Name):
    print("|_____")
    print("      ", exp, "({})".format(len(Exp_Rounds[j])))
    for i, _round in enumerate(Exp_Rounds[j]):
        for dev in devices:
            dirpath = os.path.join(raw_path, _round, dev, "raw")
            targetdir = os.path.join(db_path, exp, dev, "#{:02d}".format(i+1))
            try:
                movedir(dirpath, targetdir)
            except:
                filenames = os.listdir(dirpath)
                for filename in filenames:
                    savemove(os.path.join(dirpath, filename), os.path.join(targetdir, "raw"), filename)
        deletedir_nonempty(os.path.join(raw_path, _round))
# Out:
# |_____
#        Phone_Experiment_LTE_NR (6)
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#01
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#01
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#01
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#01/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#01
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#01
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#02
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#02
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#02
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#02/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#02
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#02
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#03
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#03
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#03
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#03/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#03
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#03
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#04
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#04
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#04
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#04/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#04
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#04
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#05
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#05
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#05
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#05/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#05
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#05
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#06
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm00/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm00/#06
# mkdir /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#06
# mv /home/wmnlab/D/database/2023-08-21/raw_data/#06/sm01/raw /home/wmnlab/D/database/2023-08-21/Phone_Experiment_LTE_NR/sm01/#06
# rm -rf /home/wmnlab/D/database/2023-08-21/raw_data/#06
