# %% [markdown]
# # Import Modules

# %%
import os
import sys
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from tqdm.notebook import tqdm
from collections import namedtuple
from collections import defaultdict
from pprint import pprint
import random
import pickle

# Configure display options
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
# %config InlineBackend.figure_format = 'retina'

# Add project directory to sys.path
# pdir = os.path.abspath(os.path.join(os.getcwd(), '.'))
# sys.path.insert(1, pdir)
# from myutils import *

# Other module imports
import ast, math, swifter, csv, json, itertools as it, portion as P

# Set plot style
# plt.style.use('ggplot')

# %%
# ************************************************* unify data format *************************************************

def set_data(df, mode='pcap', tz=0):
    def nr_serv_cel(row):
        pos = row.serv_cel_pos
        if pos == 255:
            return 65535, -160, -50
        else:
            return row[f'PCI{pos}'], row[f'RSRP{pos}'], row[f'RSRQ{pos}']
    
    if mode == 'pcap':
        common_column_names = ['seq', 'rpkg', 'frame_id', 'Timestamp', 'lost', 'excl', 'latency', 'xmit_time', 'arr_time']
        
        if df.empty:
            return pd.DataFrame(columns=common_column_names)
        
        date_columns = ['Timestamp', 'xmit_time', 'arr_time']
        df[date_columns] = df[date_columns].apply(pd.to_datetime)
        df[['seq', 'rpkg', 'frame_id']] = df[['seq', 'rpkg', 'frame_id']].astype('Int32')
        df[['latency']] = df[['latency']].astype('float32')
        df[['lost', 'excl']] = df[['lost', 'excl']].astype('boolean')

    if mode in ['lte', 'nr']:
        common_column_names = [
            'Timestamp', 'type_id', 'PCI', 'RSRP', 'RSRQ', 'serv_cel_index', 'EARFCN', 'NR_ARFCN', 
            'num_cels', 'num_neigh_cels', 'serv_cel_pos', 'PCI0', 'RSRP0', 'RSRQ0',
        ]
        
        if df.empty:
            return pd.DataFrame(columns=common_column_names)
        
        if mode == 'lte':
            columns_mapping = {
                'RSRP(dBm)': 'RSRP',
                'RSRQ(dB)': 'RSRQ',
                'Serving Cell Index': 'serv_cel_index',
                'Number of Neighbor Cells': 'num_neigh_cels',
                'Number of Detected Cells': 'num_cels',
            }
            columns_order = [*common_column_names, *df.columns[df.columns.get_loc('PCI1'):].tolist()]
            
            df = df.rename(columns=columns_mapping).reindex(columns_order, axis=1)
            df['serv_cel_index'] = np.where(df['serv_cel_index'] == '(MI)Unknown', '3_SCell', df['serv_cel_index'])
            df['num_cels'] = df['num_neigh_cels'] + 1
            df['type_id'] = 'LTE_PHY'

        if mode == 'nr':
            columns_mapping = {
                'Raster ARFCN': 'NR_ARFCN',
                'Serving Cell Index': 'serv_cel_pos',
                'Num Cells': 'num_cels',
            }
            columns_order = [*common_column_names, *df.columns[df.columns.get_loc('PCI1'):].tolist()]
            
            df = df.rename(columns=columns_mapping).reindex(columns_order, axis=1)
            df[['PCI', 'RSRP', 'RSRQ']] = df.apply(nr_serv_cel, axis=1, result_type='expand')
            df['serv_cel_index'] = np.where(df['serv_cel_pos'] == 255, df['serv_cel_index'], 'PSCell')
            df['num_neigh_cels'] = np.where(df['serv_cel_pos'] == 255, df['num_cels'], df['num_cels'] - 1)
            df['type_id'] = '5G_NR_ML1'
        
        df['Timestamp'] = pd.to_datetime(df['Timestamp']) + pd.Timedelta(hours=tz)
        df[['type_id', 'serv_cel_index']] = df[['type_id', 'serv_cel_index']].astype('category')
        df[['EARFCN', 'NR_ARFCN']] = df[['EARFCN', 'NR_ARFCN']].astype('Int32')
        df[['num_cels', 'num_neigh_cels', 'serv_cel_pos']] = df[['num_cels', 'num_neigh_cels', 'serv_cel_pos']].astype('UInt8')

        for tag in df.columns:
            if tag.startswith('PCI'):
                df[tag] = df[tag].astype('Int32')
            if tag.startswith(('RSRP', 'RSRQ')):
                df[tag] = df[tag].astype('float32')

    return df

# %% [markdown]
# ## handover parsing

# %%
# ************************************************* Sheng-Ru Latest Version (09-25) add try except (10-27) add nr arfcn (11-13) add BSID (11-21) *************************************************

def parse_mi_ho(df, tz=8):

    # df = pd.read_csv(f)
    df["Timestamp"] = df["Timestamp"].swifter.apply(lambda x: pd.to_datetime(x) + dt.timedelta(hours=tz))
    nr_pci = 'O'
    nr_arfcn = 0
    scells = []

    def NR_OTA(idx):

        if df["type_id"].iloc[idx] == "5G_NR_RRC_OTA_Packet": return True
        else: return False
    
    def LTE_SERV_INFO(idx):

        if df["type_id"].iloc[idx] == "LTE_RRC_Serv_Cell_Info": return True
        else: return False
    

    def find_1st_after(start_idx, target, look_after=1):
        for j in range(start_idx, len(df)):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t_ - t).total_seconds() > look_after:
                return None, None
            if df[target].iloc[j] not in [0,'0'] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_1st_before(start_idx, target, look_before=1):
        for j in range(start_idx, -1, -1):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t - t_).total_seconds() > look_before:
                return None, None
            if df[target].iloc[j] not in [0,'0'] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_1st_before_with_special_value(start_idx, target, target_value, look_before=1):
        for j in range(start_idx, -1, -1):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t - t_).total_seconds() > look_before:
                return None, None
            if df[target].iloc[j] in [target_value] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_in_D_exact(targets):

        l = []
        # In l : (second, ho_type)
        for target in targets:
            for ho in D[target]:
                l.append(((t - ho.start).total_seconds(), target))

        if len(l) != 0:
            for x in l:
                if (x[0]== 0):
                    return x[1]
        
        return None
    
    def find_in_D_first_before(targets, look_before=1):

        l = []
        # In l : (second, ho_type)
        for target in targets:
            for ho in D[target]:
                try:
                    l.append(((t - ho.end).total_seconds(), target, ho))
                except:
                    pass

        if len(l) != 0:
            closest = min(filter(lambda x: x[0] > 0, l), key=lambda x: x[0])
            if 0 <= closest[0] < look_before:
                return closest[1], closest[2]
        
        return None, None
    
    HO = namedtuple('HO',['start', 'end', 'others', 'trans'], defaults=[None,None,'',''])
    
    D = {
        'Conn_Rel':[], 
        'Conn_Req':[], # Setup
        'LTE_HO': [], # LTE -> newLTE
        'MN_HO': [], # LTE + NR -> newLTE + NR
        'MN_HO_to_eNB': [], # LTE + NR -> newLTE
        'SN_setup': [], # LTE -> LTE + NR => NR setup
        'SN_Rel': [], # LTE + NR -> LTE
        'SN_HO': [], # LTE + NR -> LTE + newNR  
        'RLF_II': [],
        'RLF_III': [],
        'SCG_RLF': [],
        'Add_SCell': [],
        }

    for i in range(len(df)):

        # Pass NR RRC packet. In NSA mode, LTE RRC packet include NR packet message.
        if NR_OTA(i) or LTE_SERV_INFO(i):
            continue

        others = ''
        t = df["Timestamp"].iloc[i]

        if df["rrcConnectionRelease"].iloc[i] == 1:
            D['Conn_Rel'].append(HO(start=t))
            nr_pci = 'O'

        if df["rrcConnectionRequest"].iloc[i] == 1:
            
            # Define end of rrcConnectionRequest to be rrcConnectionReconfigurationComplete or securityModeComplete.
            a = find_1st_after(i, 'rrcConnectionReconfigurationComplete',look_after=2)[0]
            b = find_1st_after(i, 'securityModeComplete',look_after=2)[0]
            if a is None and b is None: end = None
            elif a is None and b is not None: end = b
            elif a is not None and b is None: end = a 
            else: end = a if a > b else b
            
            serv_cell, serv_freq = df["PCI"].iloc[i], int(df["Freq"].iloc[i])
            trans = f'? -> ({serv_cell}, {serv_freq})'
            D['Conn_Req'].append(HO(start=t,end=end,trans=trans))
            nr_pci = 'O'
        
        if df["lte-rrc.t304"].iloc[i] == 1:
            
            end, _ = find_1st_after(i, 'rrcConnectionReconfigurationComplete')
            serv_cell, target_cell = df["PCI"].iloc[i], int(df['lte_targetPhysCellId'].iloc[i])
            serv_freq, target_freq = int(df["Freq"].iloc[i]), int(df['dl-CarrierFreq'].iloc[i])

            if df["SCellToAddMod-r10"].iloc[i] == 1:
                n =len(str(df["SCellIndex-r10.1"].iloc[i]).split('@'))
                others += f' Set up {n} SCell.'
            else:
                scells = []
            
            if serv_freq != target_freq:
                a,b = find_1st_before(i, "rrcConnectionReestablishmentRequest", 1)
                others += " Inter frequency HO."
                if a is not None:
                    others += " Near after RLF."
                
            if df["nr-rrc.t304"].iloc[i] == 1 and df["dualConnectivityPHR: setup (1)"].iloc[i] == 1:
                
                if serv_cell == target_cell and serv_freq == target_freq:

                    a, _ = find_1st_before(i, "rrcConnectionReestablishmentRequest", 2)
                    
                    if a is not None:

                        ho_type, ho = find_in_D_first_before(['RLF_II', 'RLF_III'], 2)
                        try:
                            others += f' Near after RLF of trans: {ho.trans}.'
                        except:
                            others += f' Near after RLF.'

                    else:
                        
                        ho_type, _ = find_in_D_first_before(['MN_HO_to_eNB', 'SN_Rel'], 2)
                        if ho_type is not None:
                            others += f' Near after {ho_type}.'
                    orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                    nr_pci = int(df['nr_physCellId'].iloc[i])
                    nr_arfcn = int(df['absoluteFrequencySSB'].iloc[i])
                    trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> ({nr_pci}, {nr_arfcn})'
                    D['SN_setup'].append(HO(start=t, end=end, others=others, trans=trans))

                else:
                    
                    nr_pci = int(df['nr_physCellId'].iloc[i])
                    trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | ({nr_pci}, {nr_arfcn})'
                    D['MN_HO'].append(HO(start=t, end=end, others=others, trans=trans))

            else:
                
                if serv_cell == target_cell and serv_freq == target_freq:

                    a, b = find_1st_before(i, "scgFailureInformationNR-r15")
                    if a is not None:
                        others += " Caused by scg-failure."
                    
                    orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                    nr_pci = 'O'
                    trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> {nr_pci}'
                    D['SN_Rel'].append(HO(start=t, end=end, others=others, trans=trans))
                    
                else:

                    a, _ = find_1st_before(i,"rrcConnectionSetup",3)
                    if a is not None:
                        others += ' Near After connection setup.'
                    if nr_pci == 'O':
                        trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | {nr_pci}'
                        D['LTE_HO'].append(HO(start=t, end=end, others=others, trans=trans))
                    else:
                        orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                        nr_pci = 'O'
                        trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | {orig_serv} -> {nr_pci}'
                        D['MN_HO_to_eNB'].append(HO(start=t, end=end, others=others, trans=trans))


        if df["nr-rrc.t304"].iloc[i] == 1 and not df["dualConnectivityPHR: setup (1)"].iloc[i] == 1:

            end, _ = find_1st_after(i,'rrcConnectionReconfigurationComplete')
        
            serv_cell, serv_freq = df["PCI"].iloc[i], int(df["Freq"].iloc[i])
            orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
            nr_pci = int(df['nr_physCellId'].iloc[i])
            nr_arfcn = int(df['absoluteFrequencySSB'].iloc[i])
            trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> ({nr_pci}, {nr_arfcn})'
            D['SN_HO'].append(HO(start=t,end=end,trans=trans))


        if df["rrcConnectionReestablishmentRequest"].iloc[i] == 1:

            end1, _ = find_1st_after(i, 'rrcConnectionReestablishmentComplete', look_after=1)
            b, _ = find_1st_after(i, 'rrcConnectionReestablishmentReject', look_after=1)
            end2, _ = find_1st_after(i, 'securityModeComplete',look_after=3)

            others += ' ' + df["reestablishmentCause"].iloc[i] + '.'
            scells = []

            c, _ = find_1st_before(i, 'scgFailureInformationNR-r15', 1)
            if c != None:
                others  += ' caused by scgfailure.'
                
            serv_cell, rlf_cell = df["PCI"].iloc[i], int(df['physCellId.3'].iloc[i])
            serv_freq = int(df['Freq'].iloc[i])
            
            # Type II & Type III
            if end1 is not None: 

                orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                nr_pci = 'O'
                _, idx = find_1st_before_with_special_value(i, 'PCI', rlf_cell, look_before=10)
                try:
                    rlf_freq = int(df['Freq'].iloc[idx])
                except:
                    rlf_freq = 0
                trans = f'({rlf_cell}, {rlf_freq}) -> ({serv_cell}, {serv_freq}) | {orig_serv} -> {nr_pci}'
                D['RLF_II'].append(HO(start=t,end=end1,others=others,trans=trans))

            elif b is not None and end2 is not None:
                
                orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                nr_pci = 'O'
                _, idx = find_1st_before_with_special_value(i, 'PCI', rlf_cell, look_before=10)
                try:
                    rlf_freq = int(df['Freq'].iloc[idx])
                except:
                    rlf_freq = 0

                _, idx = find_1st_after(i, "rrcConnectionRequest", 2)
                recon_cell, recon_freq = df['PCI'].iloc[idx], int(float(df['Freq'].iloc[idx]))
                
                trans = f'({rlf_cell}, {rlf_freq}) -> ({recon_cell}, {recon_freq}) | {orig_serv} -> {nr_pci}'
                D['RLF_III'].append(HO(start=t,end=end2,others=others,trans=trans))
                
            else:
                others+=' No end.'
                D['RLF_II'].append(HO(start=t,others=others))
                print('No end for RLF')

        if df["scgFailureInformationNR-r15"].iloc[i] == 1:

            others += ' ' + df["failureType-r15"].iloc[i] + '.'
            a, idx1 = find_1st_after(i, "rrcConnectionReestablishmentRequest", look_after=1)
            b, idx2 = find_1st_after(i, "lte-rrc.t304", look_after=10)

            if a is not None:

                end1, _ = find_1st_after(idx1, 'rrcConnectionReestablishmentComplete', look_after=1)
                b, _ = find_1st_after(idx1, 'rrcConnectionReestablishmentReject', look_after=1)
                end2 = find_1st_after(idx1, 'securityModeComplete',look_after=3)[0]

                others += ' Result in rrcReestablishment.'
                    
                # Type II & Type III Result
                if end1 is not None: 
                    D['SCG_RLF'].append(HO(start=t,end=end1,others=others))
                elif b is not None and end2 is not None: 
                    D['SCG_RLF'].append(HO(start=t,end=end2,others=others))
                else:
                    others += ' No end.'
                    D['SCG_RLF'].append(HO(start=t,others=others))
                    print('No end for scg failure result in rrcReestablishment.')

            elif b is not None:

                end, _ = find_1st_after(idx2, 'rrcConnectionReconfigurationComplete')
                serv_cell, target_cell = df["PCI"].iloc[idx2], df['lte_targetPhysCellId'].iloc[idx2]
                serv_freq, target_freq = int(df["Freq"].iloc[idx2]), df['dl-CarrierFreq'].iloc[idx2]
                others += ' Result in gNB release.'
                # We do not change nr_pci here. Instead, we will change it at gNB_Rel event.
                orig_serv = (nr_pci, nr_arfcn) if nr_pci != 'O' else 'O'
                trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> O'
                
                if serv_cell == target_cell and serv_freq == target_freq:
                    D['SCG_RLF'].append(HO(start=t,end=end,others=others,trans=trans))
                else:
                    others += ' Weird gNB release.'
                    print('Weird for scg failure result in gNb Release.')
                    D['SCG_RLF'].append(HO(start=t,end=end,others=others,trans=trans))                  

            else:

                print('No end for scg failure.')
                others += ' No end.'
                D['SCG_RLF'].append(HO(start=t,others=others))
        
        if df['SCellToAddMod-r10'].iloc[i] == 1 and df['physCellId-r10'].iloc[i] != 'nr or cqi report':

            others = ''
            pcis = str(df["physCellId-r10"].iloc[i]).split('@')
            freqs = str(df["dl-CarrierFreq-r10"].iloc[i]).split('@')
            orig_scells = scells
            scells = [(int(float(pci)), int(float(freq))) for pci, freq in zip(pcis, freqs)]

            others += f' Set up {len(scells)} SCell.'
            trans = f'{orig_scells} -> {scells}'

            end, _ = find_1st_after(i,'rrcConnectionReconfigurationComplete')
            
            a, _ = find_1st_before(i, "rrcConnectionReestablishmentRequest", 3)
            if a is not None:
                others += ' Near after RLF.'

            a = find_in_D_exact(['LTE_HO', 'MN_HO', 'MN_HO_to_eNB', 'SN_setup', 'SN_Rel'])
            if a is not None:
                others += f' With {a}.'

            D['Add_SCell'].append(HO(start=t,end=end,others=others, trans=trans))
    
    return D

# ************************************************* parse into readable dataframe *************************************************

def mi_parse_handover(df, tz=8, radical=True, endfill=False):
    
    def parse_trans(item):
        
        chunk = item.split(' | ')
        
        if len(chunk) == 1:
            s_src = np.nan
            s_tgt = np.nan
            if chunk[0] == '':
                m_src = np.nan
                m_tgt = np.nan
            elif chunk[0][0] == '?':
                m_src = np.nan
                m_tgt = chunk[0].split(' -> ')[1]
            else:
                m_src = chunk[0].split(' -> ')[0]
                m_tgt = chunk[0].split(' -> ')[1]
        else:
            if chunk[1] == 'O':
                s_src = np.nan
                s_tgt = np.nan
            else:
                chunk1 = chunk[1].split(' -> ')
                if len(chunk1) == 1:
                    s_src = chunk1[0]
                    s_tgt = np.nan
                else:
                    s_src = chunk1[0] if chunk1[0] != 'O' else np.nan
                    s_tgt = chunk1[1] if chunk1[1] != 'O' else np.nan
                
            chunk1 = chunk[0].split(' -> ')
            if len(chunk1) == 1:
                m_src = chunk1[0]
                m_tgt = np.nan
            else:
                m_src = chunk1[0]
                m_tgt = chunk1[1]
                
        return m_src, m_tgt, s_src, s_tgt
    
    key_mapping = {
        'Conn_Rel': 'CXNR',
        'Conn_Req': 'CXNS',
        'LTE_HO': 'LTEH',
        'MN_HO': 'MCGH',
        'MN_HO_to_eNB': 'SCGR-II',
        'SN_setup': 'SCGA',
        'SN_Rel': 'SCGR-I',
        'SN_HO': 'SCGM',
        'RLF_II': 'MCGF',
        'RLF_III': 'NASR',
        'SCG_RLF': 'SCGF',
        'Add_SCell': 'SCLA'
    }
    
    D = parse_mi_ho(df, tz)
    
    # rename as acronym
    new_D = {key_mapping.get(key, key): value for key, value in D.items()}
    
    if df.empty:
        selected_cols = ['m_src1', 'm_tgt1', 's_src1', 's_tgt1', 'PCI', 'Cell Identity', 'eNB_ID', 'next_eNB_ID', 'Band ID', 'next_BID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
        table = pd.DataFrame(columns=['type', 'start', 'end', 'others', 'm_src', 'm_tgt', 's_src', 's_tgt', 'category', 'inter-eNB', 'inter-gNB', 'inter-Freq', 'band_cng', 'inter-RAT', '4G_5G', 'cause', 'near_before_RLF', *selected_cols])
        print('Empty RRC File!!!')
        return table, new_D
    
    table = pd.DataFrame()
    for key, lst in new_D.items():
        table1 = pd.DataFrame(lst, index=[key]*len(lst)).reset_index(names='type')
        table = pd.concat([table, table1], ignore_index=True)
    
    if table.empty:
        selected_cols = ['m_src1', 'm_tgt1', 's_src1', 's_tgt1', 'PCI', 'Cell Identity', 'eNB_ID', 'next_eNB_ID', 'Band ID', 'next_BID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
        table = pd.DataFrame(columns=['type', 'start', 'end', 'others', 'm_src', 'm_tgt', 's_src', 's_tgt', 'category', 'inter-eNB', 'inter-gNB', 'inter-Freq', 'band_cng', 'inter-RAT', '4G_5G', 'cause', 'near_before_RLF', *selected_cols])
        print('Handover Not Found!!!')
        return table, new_D
    
    # add Cell Identity & eNB ID
    sc_info = df[df['type_id'] == 'LTE_RRC_Serv_Cell_Info'][['Timestamp', 'type_id', 'PCI', 'Cell Identity', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']].reset_index(drop=True).rename(columns={'Timestamp': 'start', 'type_id': 'type'})
    sc_info['eNB_ID'] = sc_info['Cell Identity'] // 256
    # sc_info['Cell_ID'] = sc_info['Cell Identity'] % 256
    sc_info = sc_info[['start', 'type', 'PCI', 'Cell Identity', 'eNB_ID', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']]

    table = pd.concat([table, sc_info], ignore_index=True).sort_values(by='start').reset_index(drop=True)

    is_not_start = True
    selected_cols = ['PCI', 'Cell Identity', 'eNB_ID', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
    for i, row in table.iterrows():
        if row['type'] == 'LTE_RRC_Serv_Cell_Info':
            is_not_start = False
            info_to_fill = row[selected_cols].to_list()
            continue
        if is_not_start:
            continue
        table.loc[i, selected_cols] = info_to_fill

    table = table[table['type'] != 'LTE_RRC_Serv_Cell_Info'].reset_index(drop=True)
    
    # parse source & target cells
    for i, row in table.iterrows():
        table.loc[i, ['m_src', 'm_tgt', 's_src', 's_tgt']] = parse_trans(row['trans'])
    
    # distinguish intra/inter-eNB HO
    table1 = table[np.in1d(table['type'], ['SCLA', 'SCGA', 'SCGR-I', 'SCGF'])]
    table = table[~np.in1d(table['type'], ['SCLA', 'SCGA', 'SCGR-I', 'SCGF'])].reset_index(drop=True)
    
    table['next_eNB'] = table['eNB_ID'].shift(-1)
    for i, row in table.iloc[:-1].iterrows():
        if row['eNB_ID'] != row['next_eNB'] and row['type'] not in ['CXNS', 'CXNR']:
            if row['others'] == '':
                table.at[i, 'others'] = 'Inter eNB HO.'
            else:
                table.at[i, 'others'] += ' Inter eNB HO.'
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # label SCG Addition near after SCG Failure
    table1 = table[~np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGR-II'])]
    table = table[np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGR-II'])].reset_index(drop=True)
    
    table['prev_cmt'] = table['others'].shift(1)
    for i, row in table.iloc[1:].iterrows():
        if row['type'] == 'SCGA':
            if 'Near after SN_Rel' in row['others'] and 'Caused by scg-failure' in row['prev_cmt']:
                table.at[i, 'others'] += ' Caused by scg-failure.'
    
    # with pd.option_context('display.max_rows', None): 
    #     display(table)
    
    # combine closed SCG Addition & Release pair (which are not caused by scg-failure or RLF) into SCG Change
    table['next_end'] = table['end'].shift(-1)
    table['next_cmt'] = table['others'].shift(-1)
    table['next_s_tgt'] = table['s_tgt'].shift(-1)
    indices_to_remove = []
    for i, row in table.iloc[:-1].iterrows():
        if row['type'] == 'SCGR-I' and 'Near after SN_Rel' in row['next_cmt'] and row['s_src'] != row['next_s_tgt']:
            table.at[i, 'end'] = row['next_end']
            table.at[i, 's_tgt'] = row['next_s_tgt']
            table.at[i, 'type'] = 'SCGC-I'
            indices_to_remove.append(i+1)
        if row['type'] == 'SCGR-II' and 'Near after MN_HO_to_eNB' in row['next_cmt'] and row['s_src'] != row['next_s_tgt']:
            table.at[i, 'end'] = row['next_end']
            table.at[i, 's_tgt'] = row['next_s_tgt']
            table.at[i, 'type'] = 'SCGC-II'
            indices_to_remove.append(i+1)
    table = table.drop(indices_to_remove)
    
    # with pd.option_context('display.max_rows', None): 
    #     display(table)
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # re-classify eNB HO & MeNB HO
    table.loc[np.in1d(table['type'], ['LTEH']) & table['others'].str.contains('Inter eNB HO'), 'type'] = 'ENBH'
    table.loc[np.in1d(table['type'], ['MCGH']) & table['others'].str.contains('Inter eNB HO'), 'type'] = 'MNBH'
    
    # add the next eNB ID when meeting inter-eNB HO
    table1 = table[~table['others'].str.contains('Inter eNB HO')]
    table = table[table['others'].str.contains('Inter eNB HO')].reset_index(drop=True)
    
    table['next_eNB_ID'] = table['eNB_ID'].shift(-1)
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # detect band change and add the next Band ID when meeting inter-Freq HO
    band_mapping = {}
    for i, row in table[~table.duplicated(subset=['DL frequency'])].dropna(subset=['DL frequency']).iterrows():
        band_mapping[int(row['DL frequency'])] = row['Band ID']
    
    print(band_mapping)
    
    table1 = table[~table['others'].str.contains('Inter frequency HO')]
    table = table[table['others'].str.contains('Inter frequency HO')].reset_index(drop=True)
    
    table['next_BID'] = table['Band ID'].shift(-1)
    try:
        table.at[len(table)-1, 'next_BID'] = band_mapping[ast.literal_eval(table.iloc[-1]['m_tgt'])[1]]
    except:
        pass
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # check whether RLF is near after an HO event
    table1 = table[np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])]
    table = table[~np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])].reset_index(drop=True)
    
    table['next_start'] = table['start'].shift(-1)
    table['next_type'] = table['type'].shift(-1)
    table['near_before_RLF'] = False
    for i, row in table.iloc[:-1].iterrows():
        # check whether an HO event is near before an RLF (in 3 seconds)
        if row['type'] in ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGR-II', 'SCGC-I', 'SCGC-II'] and \
            row['next_type'] in ['NASR', 'MCGF', 'SCGF']:
                if row['end'] > row['next_start'] - pd.Timedelta(seconds=1):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 1 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 1 sec.'
                        
                elif row['end'] > row['next_start'] - pd.Timedelta(seconds=2):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 2 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 2 sec.'
                        
                elif row['end'] > row['next_start'] - pd.Timedelta(seconds=3):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 3 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 3 sec.'
                    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # label (PCI, BSID)
    table1 = table[np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])]
    table = table[~np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])].reset_index(drop=True)
    
    for col in ['m_src', 's_src']:
        new_col = f'{col}1'
        filtered_table = table[table[col].isna()].copy()
        filtered_table[new_col] = np.nan
        
        # add BSID (eNB)
        filtered_table1 = table[table[col].notna()].copy()
        filtered_table1[new_col] = filtered_table1['m_src'].astype(str) + ', ' + filtered_table1['eNB_ID'].astype(str)
        
        table = pd.concat([filtered_table, filtered_table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    for col in ['m_tgt', 's_tgt']:
        new_col = f'{col}1'
        filtered_table = table[table[col].isna()].copy()
        filtered_table[new_col] = np.nan
        
        # add BSID (eNB)
        filtered_table1 = table[table[col].notna() & table['next_eNB_ID'].notna()].copy()
        filtered_table1[new_col] = filtered_table1['m_src'].astype(str) + ', ' + filtered_table1['next_eNB_ID'].astype(str)
        filtered_table2 = table[table[col].notna() & table['next_eNB_ID'].isna()].copy()
        filtered_table2[new_col] = filtered_table2['m_src'].astype(str) + ', ' + filtered_table2['eNB_ID'].astype(str)
        
        table = pd.concat([filtered_table, filtered_table1, filtered_table2], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # add category
    table['category'] = 'Others'
    table.loc[np.in1d(table['type'], ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II']), 'category'] = 'HO'
    table.loc[np.in1d(table['type'], ['MCGF', 'NASR', 'SCGF']), 'category'] = 'RLF'

    # add failure cause
    failure_cause = [
        'reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)',
        't310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)'
    ]
    
    for tag in failure_cause:
        table.loc[table['others'].str.contains(tag, regex=False), 'cause'] = tag
        table['others'] = table['others'].str.replace(f" {tag}.", "", regex=False)
        table['others'] = table['others'].str.replace(f"{tag}.", "", regex=False)
    
    # add Access Technology type
    table['4G_5G'] = '4G'
    table.loc[np.in1d(table['type'], ['SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGF']), '4G_5G'] = '5G'
    table.loc[np.in1d(table['type'], ['SCGR-II', 'SCGC-II']), '4G_5G'] = '4G_5G'
    
    # add more boolean columns
    table['inter-eNB'] = False
    table.loc[table['others'].str.contains('Inter eNB HO'), 'inter-eNB'] = True
    table['others'] = table['others'].str.replace(" Inter eNB HO.", "")
    table['others'] = table['others'].str.replace("Inter eNB HO.", "")
    
    table['inter-Freq'] = False
    table.loc[table['others'].str.contains('Inter frequency HO'), 'inter-Freq'] = True
    table['others'] = table['others'].str.replace(" Inter frequency HO.", "")
    table['others'] = table['others'].str.replace("Inter frequency HO.", "")
    
    table['band_cng'] = False
    table.loc[table['inter-Freq'] & (table['Band ID'] != table['next_BID']), 'band_cng'] = True
    
    table['inter-RAT'] = False
    table.loc[np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II']), 'inter-RAT'] = True
    
    table['inter-gNB'] = False
    table.loc[np.in1d(table['type'], ['SCGC-I', 'SCGC-II']), 'inter-gNB'] = True
    
    # find row na-"end" & fill with "start"
    if endfill:
        nan_end_rows = table[table['end'].isnull()]
        table.loc[nan_end_rows.index, 'end'] = nan_end_rows['start']
    
    # ignore CXNS, CXNR, SCLA
    table = table[~np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])].reset_index(drop=True)
    
    # remove SCG Addition, Release caused by SCG Failure or any other RLFs if needed (default: True)
    if radical:
        table = table[~((table['others'].str.contains('Caused by scg-failure') | table['others'].str.contains('Near after RLF')))].reset_index(drop=True)
    
    # select columns
    selected_cols = ['m_src1', 'm_tgt1', 's_src1', 's_tgt1', 'PCI', 'Cell Identity', 'eNB_ID', 'next_eNB_ID', 'Band ID', 'next_BID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
    table = table[['type', 'start', 'end', 'others', 'm_src', 'm_tgt', 's_src', 's_tgt', 'category', 'inter-eNB', 'inter-gNB', 'inter-Freq', 'band_cng', 'inter-RAT', '4G_5G', 'cause', 'near_before_RLF', *selected_cols]]
    
    return table, new_D

# %%
# ************************************************* label ho *************************************************

def handover_classify_labelling(df_ho, df_dl=None, df_ul=None, ratio=0.5, scope=None):
    
    if scope is None:
        scope = {
            'LTEH': (-4.0, 2.0, 0.018),
            'ENBH': (-4.0, 2.6, 0.019),
            'MCGH': (-3.0, 3.3, 0.019),
            'MNBH': (-3.2, 3.3, 0.02),
            'SCGM': (-4.2, 3.3, 0.017),
            'SCGA': (-1.2, 2.6, 0.027),
            'SCGR-I': (-3.1, 3.3, 0.04),
            'SCGC-I': (-3.0, 2.9, 0.37),
            'SCGR-II': (-2.0, 4.1, 0.034),
            'SCGC-II': (-2.0, 3.2, 0.396),
            'MCGF': (-5.8, 7.2, 0.078),
            'NASR': (-4.0, 6.5, 0.394),
            'SCGF': (-4.0, 4.6, 0.111)
        }
        
    def interp(x, y, ratio):
        """
        Args:
            x, y (datetime.datetime): x < y
            ratio (float): a decimal numeral in a range [0, 1]; 0 means break at x, 1 means break at y.
        Returns:
            (datetime.datetime): breakpoint of interpolation
        """
        return x + (y - x) * ratio

    Metrics = namedtuple('Metrics', ['dl_pkt', 'dl_lost', 'dl_excl', 'ul_pkt', 'ul_lost', 'ul_excl'])
    Duration = namedtuple('Duration', ['total', 'stable', 'unstable'])

    mcgf = [f'MCGF_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    nasr = [f'NASR_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    scgf = [f'SCGF_{suffix}' for suffix in ['t310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)']]

    E = { stage: { key: [] for key in [*scope.keys(), *mcgf, *nasr, *scgf] } for stage in ['before', 'during', 'after']}
    E['overview'] = {}

    selected_cols = ['stage', 'category', 'type', 'cause', 'index', 'inter-RAT', 'inter-eNB', 'inter-gNB', 'inter-Freq', 'band_cng']
    reset_values = ['-', 'stable', 'stable', '-', -1, False, False, False, False, False]
    
    dl_start_time, dl_end_time = pd.Timestamp.max, pd.Timestamp.min
    if df_dl is not None:
        dl_start_time, dl_end_time = df_dl.iloc[0]['Timestamp'] - pd.Timedelta(seconds=0.1), df_dl.iloc[-1]['Timestamp'] + pd.Timedelta(seconds=0.1)
        # df_dl = df_dl.reindex(columns=[*list(df_dl.columns), *selected_cols])
        # Reset the specified columns using a loop
        for col, reset_value in zip(selected_cols, reset_values):
            df_dl[col] = reset_value
    
    ul_start_time, ul_end_time = pd.Timestamp.max, pd.Timestamp.min
    if df_ul is not None:
        ul_start_time, ul_end_time = df_ul.iloc[0]['Timestamp'] - pd.Timedelta(seconds=0.1), df_ul.iloc[-1]['Timestamp'] + pd.Timedelta(seconds=0.1)
        # df_ul = df_ul.reindex(columns=[*list(df_ul.columns), *selected_cols])
        # Reset the specified columns using a loop
        for col, reset_value in zip(selected_cols, reset_values):
            df_ul[col] = reset_value
            
    start_time, end_time = min(dl_start_time, ul_start_time), max(dl_end_time, ul_end_time)
    stable_interval = P.open(start_time, end_time)
    for i, row in df_ho.iterrows():
        prior_row = df_ho.iloc[i-1] if i != 0 else None
        post_row = df_ho.iloc[i+1] if i != len(df_ho) - 1 else None
        
        # Peek the next event to avoid HO overlapping with handoverFailure (skip and set the next prior event)
        if i != len(df_ho) - 1 and pd.notna(row.end) and row.end > post_row.start:
            print('Overlapping event occurs!!')
            print(i, row['start'], row['end'], row['type'], row['cause'])
            print(i+1, post_row['start'], post_row['end'], post_row['type'], post_row['cause'])
            continue
        if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
            prior_row = df_ho.iloc[i-2] if i > 1 else None
        
        # Basic information
        tag = row['type']  # specific column name
        cause = row['cause']
        start, end = row['start'], row['end']  # handover start/end time
        intr = (end - start).total_seconds() if pd.notna(end) else 0  # handover interruption time
        ho_info = [row['category'], row['type'], row['cause'], i, row['inter-RAT'], row['inter-eNB'], row['inter-gNB'], row['inter-Freq'], row['band_cng']]
        
        # peri_interval
        if pd.isna(row.end):
            peri_interval = P.singleton(row.start)
        else:
            peri_interval = P.closed(row.start, row.end)

        # prior_interval
        C = row.start + pd.Timedelta(seconds=scope[tag][0])
        D = row.start
        prior_interval = P.closedopen(C, D)
        if ratio is not None and i != 0:
            prior_tag = prior_row['type']
            A = max(prior_row.start, prior_row.end)
            B = max(prior_row.start, prior_row.end) + pd.Timedelta(seconds=scope[prior_tag][1]-scope[prior_tag][2])
            if P.openclosed(A, B).overlaps(prior_interval):
                # print("Overlaps with the previous!")
                bkp = interp(C, B, ratio)
                bkp = max(bkp, A)  # avoid the breakpoint overlapping the previous event's duration
                # bkp = min(max(bkp, A), D)  # 我不侵犯到其他任何人，代表其他人也不會侵犯到我！可不加！
                prior_interval = P.closedopen(bkp, D)
                if A in prior_interval:
                    prior_interval = P.open(bkp, D)
        
        # post_interval
        C = row.end
        D = row.end + pd.Timedelta(seconds=scope[tag][1]-scope[tag][2])
        post_interval = P.openclosed(C, D)
        if ratio is not None and i != len(df_ho)-1:
            post_tag = post_row['type']
            A = min(post_row.start, post_row.end) + pd.Timedelta(seconds=scope[post_tag][0])
            B = min(post_row.start, post_row.end)
            if P.closedopen(A, B).overlaps(post_interval):
                # print("Overlaps with the following!")
                bkp = interp(A, D, ratio)
                bkp = min(bkp, B)  # avoid the breakpoint overlappint the following event's duration
                # bkp = max(min(bkp, B), C)  # 我不侵犯到其他任何人，代表其他人也不會侵犯到我！可不加！
                post_interval = P.open(C, bkp)
        
        # calculate lost & excl
        dl_pkt, dl_lost, dl_excl = [0, 0, 0], [0, 0, 0], [0, 0, 0]
        if df_dl is not None:
            for i, (stage, intv) in enumerate(zip(['before', 'during', 'after'], [prior_interval, peri_interval, post_interval])):
                if intv.empty:
                    continue
                filt = (df_dl['arr_time'] >= intv.lower) & (df_dl['arr_time'] < intv.upper)
                tmp = df_dl[filt].copy()
                dl_pkt[i] = len(tmp)
                dl_lost[i] = sum(tmp['lost'])
                dl_excl[i] = sum(~tmp['lost'] & tmp['excl'])
                df_dl.loc[filt, selected_cols] = [stage, *ho_info]
        
        ul_pkt, ul_lost, ul_excl = [0, 0, 0], [0, 0, 0], [0, 0, 0]
        if df_ul is not None:
            for i, (stage, intv) in enumerate(zip(['before', 'during', 'after'], [prior_interval, peri_interval, post_interval])):
                if intv.empty:
                    continue
                filt = (df_ul['xmit_time'] >= intv.lower) & (df_ul['xmit_time'] < intv.upper)
                tmp = df_ul[filt].copy()
                ul_pkt[i] = len(tmp)
                ul_lost[i] = sum(tmp['lost'])
                ul_excl[i] = sum(~tmp['lost'] & tmp['excl'])
                df_ul.loc[filt, selected_cols] = [stage, *ho_info]
        
        # fill in the blank
        for i, (stage, intv) in enumerate(zip(['before', 'during', 'after'], [prior_interval, peri_interval, post_interval])):
            E[stage][tag].append((intv, Metrics(dl_pkt[i], dl_lost[i], dl_excl[i], ul_pkt[i], ul_lost[i], ul_excl[i])))
            if tag in ['MCGF', 'NASR', 'SCGF']:
                E[stage][f'{tag}_{cause}'].append((intv, Metrics(dl_pkt[i], dl_lost[i], dl_excl[i], ul_pkt[i], ul_lost[i], ul_excl[i])))
        
        # update stable interval
        stable_interval = stable_interval - prior_interval - peri_interval - post_interval
    
    stable_dl_pkt, stable_dl_lost, stable_dl_excl = 0, 0, 0
    stable_ul_pkt, stable_ul_lost, stable_ul_excl = 0, 0, 0
    if df_dl is not None:
        tmp = df_dl[df_dl['category'] == 'stable'].copy()
        stable_dl_pkt = len(tmp)
        stable_dl_lost = sum(tmp['lost'])
        stable_dl_excl = sum(~tmp['lost'] & tmp['excl'])
    
    if df_ul is not None:
        tmp = df_ul[df_ul['category'] == 'stable'].copy()
        stable_ul_pkt = len(tmp)
        stable_ul_lost = sum(tmp['lost'])
        stable_ul_excl = sum(~tmp['lost'] & tmp['excl'])
    
    total_duration = (end_time - start_time).total_seconds()
    stable_duration = 0
    for intv in stable_interval:
        if intv.empty:
            continue
        stable_duration += (intv.upper - intv.lower).total_seconds()
    unstable_duration = total_duration - stable_duration
    
    E['overview']['stable_intv'] = (stable_interval, Metrics(stable_dl_pkt, stable_dl_lost, stable_dl_excl, stable_ul_pkt, stable_ul_lost, stable_ul_excl))
    E['overview']['duration'] = Duration(total_duration, stable_duration, unstable_duration)

    return E, df_dl, df_ul

# %%
def metrics_duration_into_dict(E):
    mcgf = [f'MCGF_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    nasr = [f'NASR_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    scgf = [f'SCGF_{suffix}' for suffix in ['t310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)']]

    A = { stage: { key: [] for key in ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II',
                                    'MCGF', 'NASR', 'SCGF', *mcgf, *nasr, *scgf] } for stage in ['before', 'during', 'after'] }
    A['overview'] = {}

    for stage in ['before', 'during', 'after']:
        for tag, lst in E[stage].items():
            for item in lst:
                A[stage][tag].append((item[0], item[1]._asdict()))
    A['overview']['stable_intv'] = (E['overview']['stable_intv'][0], E['overview']['stable_intv'][1]._asdict())
    A['overview']['duration'] = E['overview']['duration']._asdict()
    
    return A

def dict_into_metrics_duration(A):
    Metrics = namedtuple('Metrics', ['dl_pkt', 'dl_lost', 'dl_excl', 'ul_pkt', 'ul_lost', 'ul_excl'])
    Duration = namedtuple('Duration', ['total', 'stable', 'unstable'])

    mcgf = [f'MCGF_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    nasr = [f'NASR_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
    scgf = [f'SCGF_{suffix}' for suffix in ['t310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)']]

    B = { stage: { key: [] for key in ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II',
                                    'MCGF', 'NASR', 'SCGF', *mcgf, *nasr, *scgf] } for stage in ['before', 'during', 'after'] }
    B['overview'] = {}

    for stage in ['before', 'during', 'after']:
        for tag, lst in A[stage].items():
            for item in lst:
                B[stage][tag].append((item[0], Metrics(**item[1])))
    B['overview']['stable_intv'] = (A['overview']['stable_intv'][0], Metrics(**A['overview']['stable_intv'][1]))
    B['overview']['duration'] = Duration(**A['overview']['duration'])
    
    return B

# %% [markdown]
# # Collect Files

# %%
import os
import json

# Specify root directory
root_dir = "/Users/jackbedford/Desktop/MOXA/Code/data"

# Collect dates
dates = [s for s in sorted(os.listdir(root_dir)) if os.path.isdir(os.path.join(root_dir, s)) and s != 'backup']
date_dirs = [os.path.join(root_dir, s) for s in dates]

for date, date_dir in zip(dates, date_dirs):
    # Specify the path to your JSON file
    date = os.path.basename(date_dir)
    json_filepath = os.path.join(date_dir, f'{date}.json')
    
    # Read the JSON file and load its contents into a dictionary
    with open(json_filepath, 'r', encoding='utf-8') as json_file:
        my_dict = json.load(json_file)
    
    if not my_dict:
        continue
        
    print(date, len(my_dict))
    
    for expr, item in my_dict.items():
        print({expr: item})
# Out:
# 2023-03-16 1
# {'UDP_Bandlock_B1_B7_B8_RM500Q': {'route': 'BR', 'devices': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '萬芳醫院', '動物園', '19:23', ''], [2, '動物園', '萬芳醫院', '19:32', ''], [3, '萬芳醫院', '動物園', '19:39', ''], [4, '動物園', '萬芳醫院', '19:47', ''], [5, '萬芳醫院', '動物園', '19:55', ''], [6, '動物園', '萬芳醫院', '20:03', ''], [7, '萬芳醫院', '動物園', '20:09', ''], [8, '動物園', '萬芳醫院', '20:18', ''], [9, '萬芳醫院', '動物園', '20:27', ''], [10, '動物園', '萬芳醫院', '20:33', ''], [11, '萬芳醫院', '動物園', '20:42', ''], [12, '動物園', '萬芳醫院', '20:49', '']], 'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-03-26 1
# {'UDP_Bandlock_All_RM500Q': {'route': 'BR', 'devices': {'qc00': 'All', 'qc02': 'All', 'qc03': 'All'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '萬芳醫院', '動物園', '16:36', ''], [2, '動物園', '萬芳醫院', '16:46', ''], [3, '萬芳醫院', '動物園', '16:56', ''], [4, '動物園', '萬芳醫院', '17:25', '']], 'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-04-01 2
# {'UDP_Bandlock_B1_B3_B7_B8_RM500Q': {'route': 'BR', 'devices': {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '萬芳醫院', '動物園', '14:07', ''], [2, '動物園', '萬芳醫院', '14:21', ''], [3, '萬芳醫院', '動物園', '14:32', ''], [4, '動物園', '萬芳醫院', '14:45', ''], [5, '萬芳醫院', '動物園', '14:56', ''], [6, '動物園', '萬芳醫院', '15:06', '']], 'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# {'UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q': {'route': 'BR', 'devices': {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '萬芳醫院', '動物園', '15
 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '新店區公所', '松山', '14:24', '本來要在新店開始，但有點意外發生，不想回頭搭'], [2, '松山', '新店', '15:14', '']], 'stations': ['新店', '新店區公所', '七張', '大坪林', '景美', '萬隆', '公館', '台電大樓', '古亭', '中正紀念堂', '小南門', '西門', '北門', '中山', '松江南京', '南京復興', '台北小巨蛋', '南京三民', '松山'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-10-19 1
# {'UDP_Bandlock_9S_Phone_Red': {'route': 'R', 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '象山', '淡水', '14:37', ''], [2, '淡水', '象山', '15:54', '']], 'stations': ['象山', '台北101/世貿', '信義安和', '大安', '大安森林公園', '東門', '中正紀念堂', '台大醫院', '台北車站', '中山', '雙連', '民權西路', '圓山', '劍潭', '士林', '芝山', '明德', '石牌', '唭哩岸', '奇岩', '北投', '復興崗', '忠義', '關渡', '竹圍', '紅樹林', '淡水'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-10-26 1
# {'UDP_Bandlock_9S_Phone_Airport': {'route': 'A', 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '台北車站', '機場第二航廈', '13:30', '直達車'], [2, '機場第二航廈', '台北車站', '14:25', '直達車']], 'stations': ['台北車站', '三重', '新北產業園區', '新莊副都心', '泰山', '泰山貴和', '體育大學', '長庚醫院', '林口', '山鼻', '坑口', '機場第一航廈', '機場第二航廈'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-11-01 1
# {'UDP_Bandlock_9S_Phone_Airport': {'route': 'A', 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '台北車站', '機場第二航廈', '14:52', '普通車'], [2, '機場第二航廈', '台北車站', '16:04', '普通車']], 'stations': ['台北車站', '三重', '新北產業園區', '新莊副都心', '泰山', '泰山貴和', '體育大學', '長庚醫院', '林口', '山鼻', '坑口', '機場第一航廈', '機場第二航廈'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-11-02 1
# {'UDP_Bandlock_9S_Phone_Airport': {'route': 'A', 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '體育大學', '機場第二航廈', '16:45', '普通車'], [2, '機場第二航廈', '台北車站', '17:55', '直達車']], 'stations': ['台北車站', '三重', '新北產業園區', '新莊副都心', '泰山', '泰山貴和', '體育大學', '長庚醫院', '林口', '山鼻', '坑口', '機場第一航廈', '機場第二航廈'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}
# 2023-11-09 1
# {'UDP_Bandlock_9S_Phone_Brown': {'route': 'BR', 'devices': {'sm00': 'All', 'sm01': 'All', 'sm02': 'B3', 'sm03': 'B7', 'sm04': 'B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '木柵', '南港展覽館', '12:21', ''], [2, '南港展覽館', '動物園', '13:41', '']], 'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥', '麟光', '六張犁', '科技大樓', '大安', '忠孝復興', '南京復興', '中山國中', '松山機場', '大直', '劍南路', '西湖', '港墘', '文德', '內湖', '大湖公園', '葫洲', '東湖', '南港軟體園區', '南港展覽館'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}

# %%
# Select Dates
# sel_dates = [s for s in dates if s >= '2023-09-12']
# sel_dates = [s for s in dates if s < '2023-09-12']
# sel_dates = [s for s in dates if s >= '2023-08-16' and s < '2023-09-12']
# sel_dates = dates[:5]
# sel_dates = dates[-8:]
# sel_dates = ['2023-03-16']
sel_dates = dates[:]
# exc_dates = ['2023-06-12', '2023-06-13']
exc_dates = []
date_dirs = [os.path.join(root_dir, s) for s in sel_dates if s not in exc_dates]

# Select Experiment Names
# sel_exps = ['UDP_Bandlock_9S_Phone_Brown', 'UDP_Bandlock_9S_Phone_Airport']
sel_exps = []
exc_exps = ['Modem_Action_Test', 'Control_Group', 'Control_Group2', 'Control_Group3']
# exc_exps = []

# Select Routes
# sel_routes = ['BR']
sel_routes = []

# %%
# Collect Experiments
exps_dict = {}

for date_dir in date_dirs:
    date = os.path.basename(date_dir)
    
    # Specify the path to your JSON file
    json_filepath = os.path.join(date_dir, f'{date}.json')
    
    # Read the JSON file and load its contents into a dictionary
    with open(json_filepath, 'r', encoding='utf-8') as json_file:
        my_dict = json.load(json_file)
    
    if not my_dict:
        continue
    
    for i, (expr, item) in enumerate(my_dict.items()):
        if len(sel_exps) != 0 and expr not in sel_exps:
            continue
        
        if len(exc_exps) != 0 and expr in exc_exps:
            continue
        
        if len(sel_routes) != 0 and item['route'] not in sel_routes:
            continue
        
        try:
            exps_dict[date] = {**exps_dict[date], **{expr: item}}
        except:
            exps_dict[date] = {expr: item}

for date, exps in exps_dict.items():
    # print(date, len(exps), exps)
    print(date, len(exps))
    
    for expr, item in exps.items():
        print({expr: item})
# Out:
# 2023-03-16 1
# {'UDP_Bandlock_B1_B7_B8_RM500Q': {'route': 'BR', 'devices': {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '萬芳醫院', '動物園',
8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}, 'ods': [[0, 'Origin Station', 'Destination Station', 'Departure Time', 'Notes'], [1, '木柵', '南港展覽館', '12:21', ''], [2, '南港展覽館', '動物園', '13:41', '']], 'stations': ['動物園', '木柵', '萬芳社區', '萬芳醫院', '辛亥', '麟光', '六張犁', '科技大樓', '大安', '忠孝復興', '南京復興', '中山國中', '松山機場', '大直', '劍南路', '西湖', '港墘', '文德', '內湖', '大湖公園', '葫洲', '東湖', '南港軟體園區', '南港展覽館'], 'telecom': 'CHT', 'protocol': 'UDP', 'length': [250, 'byte'], 'bitrate': [1, 'Mbps'], 'notes': ''}}

# %%
filepaths = []

i = 0
for date, exps in exps_dict.items():
    # print(date, len(exps), exps)
    # print(date, len(exps))
    
    for name, expr in exps.items():
        for dev in expr['devices'].keys():
            for trip in expr['ods'][1:]:
                trip = '#{:02d}'.format(trip[0])
                data_dir = os.path.join(root_dir, date, name, dev, trip, 'data')
                # print(data_dir, os.path.isdir(data_dir))
                
                rrc_filepath = [os.path.join(data_dir, s) for s in os.listdir(data_dir) if s.endswith('rrc.csv')][0]
                dl_filepath = os.path.join(data_dir, 'udp_dnlk_loss_latency.csv')
                ul_filepath = os.path.join(data_dir, 'udp_uplk_loss_latency.csv')
                # print(rrc_filepath, os.path.isfile(rrc_filepath))
                # print(dl_filepath, os.path.isfile(dl_filepath))
                # print(ul_filepath, os.path.isfile(ul_filepath))
                
                filepaths.append((i, rrc_filepath, dl_filepath, ul_filepath))
                i += 1

pprint(filepaths, sort_dicts=False)
# Out:
# [(0,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (1,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (2,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#03/data/udp_uplk_loss_latency.csv'),
#  (3,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#04/data/udp_uplk_loss_latency.csv'),
#  (4,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#05/data/udp_uplk_loss_latency.csv'),
#  (5,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#06/data/udp_uplk_loss_latency.csv'),
#  (6,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#07/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#07/data/udp_uplk_loss_latency.csv'),
#  (7,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#08/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#08/data/udp_uplk_loss_latency.csv'),
#  (8,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#09/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#09/data/udp_uplk_loss_latency.csv'),
#  (9,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#10/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#10/data/udp_uplk_loss_latency.csv'),
#  (10,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#11/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#11/data/udp_uplk_loss_latency.csv'),
#  (11,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#12/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc00/#12/data/udp_uplk_loss_latency.csv'),
#  (12,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (13,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (14,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#03/data/udp_uplk_loss_latency.csv'),
#  (15,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#04/data/udp_uplk_loss_latency.csv'),
#  (16,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#05/data/udp_uplk_loss_latency.csv'),
#  (17,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#06/data/udp_uplk_loss_latency.csv'),
#  (18,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#07/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#07/data/udp_uplk_loss_latency.csv'),
#  (19,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#08/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#08/data/udp_uplk_loss_latency.csv'),
#  (20,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#09/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#09/data/udp_uplk_loss_latency.csv'),
#  (21,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#10/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#10/data/udp_uplk_loss_latency.csv'),
#  (22,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#11/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#11/data/udp_uplk_loss_latency.csv'),
#  (23,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#12/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc02/#12/data/udp_uplk_loss_latency.csv'),
#  (24,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (25,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (26,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#03/data/udp_uplk_loss_latency.csv'),
#  (27,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#04/data/udp_uplk_loss_latency.csv'),
#  (28,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#05/data/udp_uplk_loss_latency.csv'),
#  (29,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#06/data/udp_uplk_loss_latency.csv'),
#  (30,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#07/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#07/data/udp_uplk_loss_latency.csv'),
#  (31,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#08/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#08/data/udp_uplk_loss_latency.csv'),
#  (32,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#09/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#09/data/udp_uplk_loss_latency.csv'),
#  (33,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#10/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#10/data/udp_uplk_loss_latency.csv'),
#  (34,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#11/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#11/data/udp_uplk_loss_latency.csv'),
#  (35,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#12/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/UDP_Bandlock_B1_B7_B8_RM500Q/qc03/#12/data/udp_uplk_loss_latency.csv'),
#  (36,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-26_16-36-49_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (37,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-26_16-46-50_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (38,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-26_16-56-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#03/data/udp_uplk_loss_latency.csv'),
#  (39,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-26_17-25-57_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc00/#04/data/udp_uplk_loss_latency.csv'),
#  (40,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-26_16-36-49_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (41,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-26_16-46-50_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (42,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-26_16-56-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#03/data/udp_uplk_loss_latency.csv'),
#  (43,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-26_17-25-57_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc02/#04/data/udp_uplk_loss_latency.csv'),
#  (44,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-26_16-36-49_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (45,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-26_16-46-50_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (46,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-26_16-56-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#03/data/udp_uplk_loss_latency.csv'),
#  (47,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-26_17-25-57_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/UDP_Bandlock_All_RM500Q/qc03/#04/data/udp_uplk_loss_latency.csv'),
#  (48,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (49,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (50,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_uplk_loss_latency.csv'),
#  (51,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_uplk_loss_latency.csv'),
#  (52,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_uplk_loss_latency.csv'),
#  (53,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_uplk_loss_latency.csv'),
#  (54,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
#  (55,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_uplk_loss_latency.csv'),
#  (56,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_uplk_loss_latency.csv'),
#  (57,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_uplk_loss_latency.csv'),
#  (58,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_uplk_loss_latency.csv'),
#  (59,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_uplk_loss_latency.csv'),
#  (60,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (61,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (62,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_uplk_loss_latency.csv'),
#  (63,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_uplk_loss_latency.csv'),
#  (64,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_uplk_loss_latency.csv'),
#  (65,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_uplk_loss_latency.csv'),
#  (66,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (67,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (68,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_uplk_loss_latency.csv'),
#  (69,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_uplk_loss_latency.csv'),
#  (70,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_uplk_loss_latency.csv'),
#  (71,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_uplk_loss_latency.csv'),
#  (72,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (73,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (74,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#03/data/udp_uplk_loss_latency.csv'),
#  (75,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc00/#04/data/udp_uplk_loss_latency.csv'),
#  (76,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
#  (77,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#02/data/udp_uplk_loss_latency.csv'),
#  (78,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#03/data/udp_uplk_loss_latency.csv'),
#  (79,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc01/#04/data/udp_uplk_loss_latency.csv'),
#  (80,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (81,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (82,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#03/data/udp_uplk_loss_latency.csv'),
#  (83,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc02/#04/data/udp_uplk_loss_latency.csv'),
#  (84,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (85,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (86,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#03/data/udp_uplk_loss_latency.csv'),
#  (87,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/UDP_Bandlock_B1B3_B1B8_LTE_All_RM500Q/qc03/#04/data/udp_uplk_loss_latency.csv'),
#  (88,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (89,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (90,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
#  (91,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc01/#02/data/udp_uplk_loss_latency.csv'),
#  (92,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (93,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (94,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (95,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_All_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (96,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-10_15-45-32_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (97,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-10_16-06-58_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (98,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-10_15-45-32_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
#  (99,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-10_16-06-58_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_uplk_loss_latency.csv'),
#  (100,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-10_15-45-32_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (101,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-10_16-06-58_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (102,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-10_15-45-32_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (103,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-10_16-06-58_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (104,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-10_16-29-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (105,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-10_16-42-04_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (106,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-10_16-29-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
#  (107,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-10_16-42-04_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc01/#02/data/udp_uplk_loss_latency.csv'),
#  (108,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-10_16-29-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#01/data/udp_uplk_loss_latency.csv'),
#  (109,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-10_16-42-04_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc02/#02/data/udp_uplk_loss_latency.csv'),
#  (110,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-10_16-29-38_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#01/data/udp_uplk_loss_latency.csv'),
#  (111,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-10_16-42-04_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/UDP_Bandlock_LTE_All_B7B8_B7_RM500Q/qc03/#02/data/udp_uplk_loss_latency.csv'),
#  (112,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-15-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_uplk_loss_latency.csv'),
#  (113,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_14-24-04_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_uplk_loss_latency.csv'),
#  (114,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_14-35-41_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_uplk_loss_latency.csv'),
#  (115,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_14-44-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_uplk_loss_latency.csv'),
#  (116,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-15-10_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/UDP_Bandlock_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_uplk_loss_latency.csv'),
# ...
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/udp_uplk_loss_latency.csv'),
#  (929,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/diag_log_sm07_2023-11-01_16-04-39_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_uplk_loss_latency.csv'),
#  (930,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/diag_log_sm08_2023-11-01_14-52-49_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_uplk_loss_latency.csv'),
#  (931,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/diag_log_sm08_2023-11-01_16-04-39_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-01/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_uplk_loss_latency.csv'),
#  (932,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#01/data/diag_log_sm00_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#01/data/udp_uplk_loss_latency.csv'),
#  (933,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#02/data/diag_log_sm00_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm00/#02/data/udp_uplk_loss_latency.csv'),
#  (934,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#01/data/diag_log_sm01_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#01/data/udp_uplk_loss_latency.csv'),
#  (935,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#02/data/diag_log_sm01_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm01/#02/data/udp_uplk_loss_latency.csv'),
#  (936,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#01/data/diag_log_sm02_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#01/data/udp_uplk_loss_latency.csv'),
#  (937,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#02/data/diag_log_sm02_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm02/#02/data/udp_uplk_loss_latency.csv'),
#  (938,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#01/data/diag_log_sm03_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#01/data/udp_uplk_loss_latency.csv'),
#  (939,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#02/data/diag_log_sm03_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm03/#02/data/udp_uplk_loss_latency.csv'),
#  (940,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/diag_log_sm04_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/udp_uplk_loss_latency.csv'),
#  (941,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/diag_log_sm04_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/udp_uplk_loss_latency.csv'),
#  (942,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/diag_log_sm05_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/udp_uplk_loss_latency.csv'),
#  (943,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/diag_log_sm05_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/udp_uplk_loss_latency.csv'),
#  (944,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/diag_log_sm06_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/udp_uplk_loss_latency.csv'),
#  (945,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/diag_log_sm06_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/udp_uplk_loss_latency.csv'),
#  (946,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/diag_log_sm07_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/udp_uplk_loss_latency.csv'),
#  (947,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/diag_log_sm07_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_uplk_loss_latency.csv'),
#  (948,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/diag_log_sm08_2023-11-02_16-44-26_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_uplk_loss_latency.csv'),
#  (949,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/diag_log_sm08_2023-11-02_17-54-12_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_uplk_loss_latency.csv'),
#  (950,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/diag_log_sm00_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/udp_uplk_loss_latency.csv'),
#  (951,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/diag_log_sm00_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/udp_uplk_loss_latency.csv'),
#  (952,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/diag_log_sm01_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/udp_uplk_loss_latency.csv'),
#  (953,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/diag_log_sm01_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/udp_uplk_loss_latency.csv'),
#  (954,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/diag_log_sm02_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/udp_uplk_loss_latency.csv'),
#  (955,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/diag_log_sm02_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/udp_uplk_loss_latency.csv'),
#  (956,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/diag_log_sm03_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/udp_uplk_loss_latency.csv'),
#  (957,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/diag_log_sm03_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/udp_uplk_loss_latency.csv'),
#  (958,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/diag_log_sm04_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/udp_uplk_loss_latency.csv'),
#  (959,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#02/data/diag_log_sm04_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#02/data/udp_uplk_loss_latency.csv'),
#  (960,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#01/data/diag_log_sm05_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#01/data/udp_uplk_loss_latency.csv'),
#  (961,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#02/data/diag_log_sm05_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm05/#02/data/udp_uplk_loss_latency.csv'),
#  (962,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#01/data/diag_log_sm06_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#01/data/udp_uplk_loss_latency.csv'),
#  (963,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#02/data/diag_log_sm06_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm06/#02/data/udp_uplk_loss_latency.csv'),
#  (964,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#01/data/diag_log_sm07_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#01/data/udp_uplk_loss_latency.csv'),
#  (965,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#02/data/diag_log_sm07_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm07/#02/data/udp_uplk_loss_latency.csv'),
#  (966,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#01/data/diag_log_sm08_2023-11-09_12-20-44_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#01/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#01/data/udp_uplk_loss_latency.csv'),
#  (967,
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#02/data/diag_log_sm08_2023-11-09_13-40-46_rrc.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#02/data/udp_dnlk_loss_latency.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm08/#02/data/udp_uplk_loss_latency.csv')]

# %% [markdown]
# # Parsing

# %%
mcgf = [f'MCGF_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
nasr = [f'NASR_{suffix}' for suffix in ['reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)']]
scgf = [f'SCGF_{suffix}' for suffix in ['t310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)']]

evt_types = [
    'LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II',
    'MCGF', *mcgf,
    'NASR', *nasr,
    'SCGF', *scgf,
]

# record all traces' info in each type list
# D = {tag: [] for tag in evt_types}
# D['stable_mets'] = []
# D['duration'] = []

Metrics = namedtuple('Metrics', ['dl_pkt', 'dl_lost', 'dl_excl', 'ul_pkt', 'ul_lost', 'ul_excl'])
Stats = namedtuple('Stats', ['count', 'duration', 'metrics'])
Stage = namedtuple('Stage', ['before', 'during', 'after'])

for i, rrc_file, dl_file, ul_file in filepaths[940:]:
    ########### in for loop (iterating exprs) ##### start
    print(i, (rrc_file, dl_file, ul_file))
    df_ho, _ = mi_parse_handover(pd.read_csv(rrc_file), radical=True, endfill=True)
    df_ho.to_csv(os.path.join(os.path.dirname(rrc_file), 'handover_info_log.csv'), index=False)
    
    if df_ho.empty:
        continue
    
    df_dl = set_data(pd.read_csv(dl_file))
    df_ul = set_data(pd.read_csv(ul_file))
    E, df_dl, df_ul = handover_classify_labelling(df_ho, df_dl, df_ul)
    
    # store handover labelling to avoid parsing again and again
    df_dl.to_pickle(os.path.join(os.path.dirname(dl_file), 'udp_dnlk_loss_latency_ho.pkl'))
    df_ul.to_pickle(os.path.join(os.path.dirname(ul_file), 'udp_uplk_loss_latency_ho.pkl'))
    with open(os.path.join(os.path.dirname(rrc_file), 'single_radio_ho_stats.pkl'), 'wb') as f:
        pickle.dump(metrics_duration_into_dict(E), f)

    # for tag in evt_types:
    #     # print(tag)
    #     infos = []
    #     for i, stage in enumerate(['before', 'during', 'after']):
    #         # count
    #         count = len(E[stage][tag])
    #         # duration
    #         duration = 0
    #         intv_list = [item[0] for item in E[stage][tag]]
    #         for intv in intv_list:
    #             if intv.empty:
    #                 continue
    #             duration += (intv.upper - intv.lower).total_seconds()
    #         # metrics
    #         mets_list = [item[1] for item in E[stage][tag]]
    #         metrics = Metrics(sum([item.dl_pkt for item in mets_list]), sum([item.dl_lost for item in mets_list]), sum([item.dl_excl for item in mets_list]), sum([item.ul_pkt for item in mets_list]), sum([item.ul_lost for item in mets_list]), sum([item.ul_excl for item in mets_list]))
            
    #         # print(stage, count, duration, metrics)
    #         infos.append(Stats(count, duration, metrics))
    #     D[tag].append(Stage(*infos))
        
    # D['stable_mets'].append(E['overview']['stable_intv'][1])
    # D['duration'].append(E['overview']['duration'])
    ########## in for loop (iterating exprs) ##### end
    # break

# pprint(D, sort_dicts=False)
# Out:
# 940 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/diag_log_sm04_2023-11-02_16-44-26_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#01/data/udp_uplk_loss_latency.csv')
# Handover Not Found!!!
# 941 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/diag_log_sm04_2023-11-02_17-54-12_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm04/#02/data/udp_uplk_loss_latency.csv')
# {3650: 8.0, 3750: 8.0}
# Overlapping event occurs!!
# 47 2023-11-02 18:04:19.323781 2023-11-02 18:04:19.768391 MCGH nan
# 48 2023-11-02 18:04:19.612787 2023-11-02 18:04:19.682868 MCGF handoverFailure (1)
# Overlapping event occurs!!
# 77 2023-11-02 18:08:40.860443 2023-11-02 18:08:42.283077 SCGC-II nan
# 78 2023-11-02 18:08:41.275805 2023-11-02 18:08:41.295459 ENBH nan
# Overlapping event occurs!!
# 84 2023-11-02 18:08:47.376502 2023-11-02 18:08:48.390529 SCGC-II nan
# 85 2023-11-02 18:08:48.230666 2023-11-02 18:08:48.249421 LTEH nan
# Overlapping event occurs!!
# 225 2023-11-02 18:28:23.846389 2023-11-02 18:28:24.271650 MCGH nan
# 226 2023-11-02 18:28:24.137935 2023-11-02 18:28:24.210089 MCGF handoverFailure (1)
# Overlapping event occurs!!
# 228 2023-11-02 18:28:27.979511 2023-11-02 18:28:28.742679 SCGC-II nan
# 229 2023-11-02 18:28:28.290810 2023-11-02 18:28:28.308167 ENBH nan
# Overlapping event occurs!!
# 234 2023-11-02 18:28:44.409095 2023-11-02 18:28:45.042558 SCGC-I nan
# 235 2023-11-02 18:28:44.686860 2023-11-02 18:28:44.704247 ENBH nan
# Overlapping event occurs!!
# 257 2023-11-02 18:29:38.654252 2023-11-02 18:29:39.171316 SCGC-II nan
# 258 2023-11-02 18:29:39.027110 2023-11-02 18:29:39.048158 LTEH nan
# Overlapping event occurs!!
# 286 2023-11-02 18:30:54.432846 2023-11-02 18:30:55.005160 SCGC-II nan
# 287 2023-11-02 18:30:54.849345 2023-11-02 18:30:54.869019 ENBH nan
# Overlapping event occurs!!
# 288 2023-11-02 18:31:02.016557 2023-11-02 18:31:02.622949 SCGC-II nan
# 289 2023-11-02 18:31:02.330450 2023-11-02 18:31:02.380068 LTEH nan
# Overlapping event occurs!!
# 293 2023-11-02 18:31:13.165913 2023-11-02 18:31:13.739261 SCGC-II nan
# 294 2023-11-02 18:31:13.575899 2023-11-02 18:31:13.605023 LTEH nan
# Overlapping event occurs!!
# 296 2023-11-02 18:31:16.151279 2023-11-02 18:31:16.802937 SCGC-II nan
# 297 2023-11-02 18:31:16.525917 2023-11-02 18:31:16.545811 LTEH nan
# Overlapping event occurs!!
# 298 2023-11-02 18:31:18.376771 2023-11-02 18:31:19.793363 SCGC-II nan
# 299 2023-11-02 18:31:19.472101 2023-11-02 18:31:19.490756 ENBH nan
# 942 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/diag_log_sm05_2023-11-02_16-44-26_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#01/data/udp_uplk_loss_latency.csv')
# Handover Not Found!!!
# 943 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/diag_log_sm05_2023-11-02_17-54-12_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm05/#02/data/udp_uplk_loss_latency.csv')
# No end for RLF
# {3050: 7.0, 1750: 3.0, 1400: 3.0}
# 944 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/diag_log_sm06_2023-11-02_16-44-26_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#01/data/udp_uplk_loss_latency.csv')
# {3650: 8.0}
# 945 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/diag_log_sm06_2023-11-02_17-54-12_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm06/#02/data/udp_uplk_loss_latency.csv')
# {3650: 8.0, 1750: 3.0, 1400: 3.0}
# 946 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/diag_log_sm07_2023-11-02_16-44-26_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#01/data/udp_uplk_loss_latency.csv')
# Handover Not Found!!!
# 947 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/diag_log_sm07_2023-11-02_17-54-12_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm07/#02/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 3400: 7.0, 3650: 8.0}
# 948 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/diag_log_sm08_2023-11-02_16-44-26_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#01/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 1750: 3.0, 1400: 3.0, 3400: 7.0}
# 949 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/diag_log_sm08_2023-11-02_17-54-12_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-02/UDP_Bandlock_9S_Phone_Airport/sm08/#02/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 1750: 3.0, 1400: 3.0, 3400: 7.0}
# 950 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/diag_log_sm00_2023-11-09_12-20-44_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 1750: 3.0, 3650: 8.0, 1400: 3.0}
# 951 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/diag_log_sm00_2023-11-09_13-40-46_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm00/#02/data/udp_uplk_loss_latency.csv')
# {1750: 3.0, 1400: 3.0, 3650: 8.0, 3050: 7.0}
# Overlapping event occurs!!
# 113 2023-11-09 13:52:54.142049 2023-11-09 13:52:54.915901 SCGC-II nan
# 114 2023-11-09 13:52:54.737656 2023-11-09 13:52:54.768234 LTEH nan
# 952 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/diag_log_sm01_2023-11-09_12-20-44_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 1750: 3.0, 1400: 3.0}
# 953 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/diag_log_sm01_2023-11-09_13-40-46_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm01/#02/data/udp_uplk_loss_latency.csv')
# {1750: 3.0, 1400: 3.0, 3050: 7.0, 3650: 8.0, 3400: 7.0}
# 954 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/diag_log_sm02_2023-11-09_12-20-44_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/udp_uplk_loss_latency.csv')
# {1750: 3.0, 1400: 3.0}
# 955 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/diag_log_sm02_2023-11-09_13-40-46_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm02/#02/data/udp_uplk_loss_latency.csv')
# {1750: 3.0, 1400: 3.0}
# Overlapping event occurs!!
# 125 2023-11-09 13:52:54.900047 2023-11-09 13:52:55.508435 SCGC-II nan
# 126 2023-11-09 13:52:55.317134 2023-11-09 13:52:55.347119 LTEH nan
# 956 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/diag_log_sm03_2023-11-09_12-20-44_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 3400: 7.0}
# 957 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/diag_log_sm03_2023-11-09_13-40-46_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm03/#02/data/udp_uplk_loss_latency.csv')
# {3050: 7.0, 3400: 7.0}
# Overlapping event occurs!!
# 170 2023-11-09 14:04:30.863867 2023-11-09 14:04:31.334496 SCGC-II nan
# 171 2023-11-09 14:04:31.146542 2023-11-09 14:04:31.173226 LTEH nan
# 958 ('/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/diag_log_sm04_2023-11-09_12-20-44_rrc.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/udp_dnlk_loss_latency.csv', '/Users/jackbedford/Desktop/MOXA/Code/data/2023-11-09/UDP_Bandlock_9S_Phone_Brown/sm04/#01/data/udp_uplk_loss_latency.csv')
# /var/folders/vy/w6g3hxgj76s0gzty27t2d6gm0000gn/T/ipykernel_65870/2600368703.py:24: DtypeWarning: Columns (22,33,53,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ho, _ = mi_parse_handover(pd.read_csv(rrc_