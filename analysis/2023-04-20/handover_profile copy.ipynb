# %% [markdown]
# # Import Modules

# %%
import os, sys
import pandas as pd
import numpy as np
import datetime as dt
from pprint import pprint
import csv
import itertools as it
from prettytable import PrettyTable
import matplotlib.pylab as plt
import seaborn as sns
import portion as P
from collections import namedtuple
import math

DataFrame = namedtuple('DataFrame', 'filename, df', defaults=tuple([None]*2))

pdir = os.path.abspath(os.path.join(os.getcwd(), '..'))  # for jupyter-notebook
sys.path.insert(1, pdir)
from myutils import *

# %config InlineBackend.figure_format = 'retina'  # 提高 jupyter notebook 的圖形顯示解析度
# plt.style.use('ggplot')

pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 200)

def set_data(df):
    df['seq'] = df['seq'].astype('Int32')
    df['rpkg'] = df['rpkg'].astype('Int8')
    df['frame_id'] = df['frame_id'].astype('Int32')
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    df['xmit_time'] = pd.to_datetime(df['xmit_time'])
    df['arr_time'] = pd.to_datetime(df['arr_time'])
    df['Timestamp_epoch'] = df['Timestamp_epoch'].astype('float32')
    df['xmit_time_epoch'] = df['xmit_time_epoch'].astype('float32')
    df['arr_time_epoch'] = df['arr_time_epoch'].astype('float32')
    df['lost'] = df['lost'].astype('boolean')
    df['excl'] = df['excl'].astype('boolean')
    df['latency'] = df['latency'].astype('float32')
    return df

# %%
# dfs_ul = []
# for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
#     for trace in traces:
#         for j, (dev, schm) in enumerate(zip(devices, schemes)):
#             data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_uplk_loss_latency.csv')
#             print(data, os.path.isfile(data))
#             df = pd.read_csv(data)
#             df = set_data(df)
#             # dfs_ul.append(DataFrame(data, df.copy()))
#             dfs_ul.append(DataFrame(data, None))
# print(len(dfs_ul))

# dfs_dl = []
# for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
#     for trace in traces:
#         for j, (dev, schm) in enumerate(zip(devices, schemes)):
#             data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_dnlk_loss_latency.csv')
#             print(data, os.path.isfile(data))
#             df = pd.read_csv(data)
#             df = set_data(df)
#             # dfs_dl.append(DataFrame(data, df.copy()))
#             dfs_dl.append(DataFrame(data, None))
# print(len(dfs_dl))

# dfs_ho = []
# for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
#     for trace in traces:
#         for j, (dev, schm) in enumerate(zip(devices, schemes)):
#             path = os.path.join(datadir, exp, dev, trace, 'data')
#             data = os.path.join(path, [s for s in os.listdir(path) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
#             print(data, os.path.isfile(data))
#             df = pd.read_csv(data)
#             df, _, _ = mi_parse_ho(df, tz=8)
#             df['ho_type0'] = df['ho_type'].astype('string')
#             df.loc[df['cause'].notna(), 'ho_type0'] = df['ho_type'].astype('string') + '_' + df['cause'].astype('string')
#             df['ho_type0'] = df['ho_type0'].astype('category')
#             # dfs_ho.append(DataFrame(data, df.copy()))
#             dfs_ho.append(DataFrame(data, None))
# print(len(dfs_ho))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# 畫布大小
fig, ax = plt.subplots(figsize=(6, 4))

# 繪製長方形
rect1 = patches.Rectangle((-1, 0), 4, 5, ec=None, fc='r', alpha=0.5)  # 左下角座標點, 寬度, 高度, 邊界顏色, 填滿顏色
rect2 = patches.Rectangle((3, 0), 2, 4, ec=None, fc='b', alpha=0.5)
rect3 = patches.Rectangle((5, 0), 1, 2, ec=None, fc='g', alpha=0.5)

# 設定x、y軸範圍
plt.xlim(-2, 7)
plt.ylim(0, 6)

ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)

# 顯示圖形
plt.show()

# %% [markdown]
# # Go

# %%
ImpactScope = {
    'LTE_HO': (0.35, 0.55),
    'MN_HO': (1.25, 1.6),
    'SN_HO': (0.85, 1.25),
    'SN_Setup': (0.35, 1.5),
    'SN_Rel': (0.05, 0.1),
    'SN_Rel_MN_HO': (1.15, 0.7),
    'SCG_Failure_t310-Expiry (0)': (1.65, 1.2),
    'SCG_Failure_synchReconfigFailureSCG (3)': (0.05, 0.05),
    'MCG_Failure_reconfigurationFailure (0)': (2, 2),
    'MCG_Failure_handoverFailure (1)': (0.7, 1.25),
    'MCG_Failure_otherFailure (2)': (5.7, 1.25),
    'NAS_Recovery_otherFailure (2)': (0.75, 1.65)}

def setup_profile(df, tag, start, end, mode='ul', sec=1, left=pd.Timestamp.min, right=pd.Timestamp.max, fix=False):
    # print('hello1')
    if pd.notna(end):
        midpoint = start + (end - start) / 2
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(end+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=sec), left), min(end+pd.Timedelta(seconds=sec), right))
    else:
        midpoint = start
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(start+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=sec), left), min(start+pd.Timedelta(seconds=sec), right))
    
    # print(start, end, midpoint, sep='\n')
    # print(start, end, midpoint)
    # print('hello2')
    
    if mode == 'ul':
        df_plot = df.query('xmit_time >= @intv.lower & xmit_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['xmit_time'] - midpoint).dt.total_seconds()
    elif mode == 'dl':
        df_plot = df.query('arr_time >= @intv.lower & arr_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['arr_time'] - midpoint).dt.total_seconds()
    else: # 'pyl'
        df_plot = df.query('Timestamp >= @intv.lower & Timestamp <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['Timestamp'] - midpoint).dt.total_seconds()
    df_plot['cat_id'] = ((df_plot['rel_time'] + 0.005) // 0.01) * 0.01
    # display(df_plot)

    # print('hello3')
    ts_group = df_plot.groupby(['cat_id'])
    table = ts_group['lost'].agg(['count','sum','mean']).copy().reset_index()
    table = table.rename(columns={'count':'tx_count', 'sum':'lost', 'mean':'PLR'})
    table['PLR'] = table['PLR'] * 100
    # display(table)
    
    # print('hello4')
    return table, intv

def merge_profile(tables, intrs):
    intr = np.mean(intrs)
    table = pd.DataFrame(columns=['cat_id','tx_count','lost','PLR'])
    table['cat_id'] = table['cat_id'].astype('float32')
    table['tx_count'] = table['tx_count'].astype('Int32')
    table['lost'] = table['lost'].astype('Int32')
    table['PLR'] = table['PLR'].astype('float32')
    for i in range(len(tables)):
        _table = tables[i].copy()
        table = table.merge(_table, on=['cat_id'], how='outer').fillna(0)
        table['tx_count'] = table['tx_count_x'] + table['tx_count_y']
        table['lost'] = table['lost_x'] + table['lost_y']
        table['PLR'] = 0
        table = table[['cat_id','tx_count','lost','PLR']]
    table['PLR'] = table['lost'] / (table['tx_count'] + 1e-9) * 100
    table = table[['cat_id','tx_count','lost','PLR']].copy().sort_values(by=['cat_id']).reset_index(drop=True)
    return table, intr

def plot_profile(table, intr=0, title='', mode='lost', xlim=0, path='', flow='ul', stable_plr=0, plr=0, plr1=0):
    fig, ax = plt.subplots(figsize=(6, 4))
    if flow == 'ul':
        ax.set_title(f'Uplink: {title}')
    else: # 'dl'
        ax.set_title(f'Downlink: {title}')
    if xlim == 0:
        ax.set_xlim(table.iat[0, table.columns.get_loc('cat_id')], table.iat[-1, table.columns.get_loc('cat_id')])
    else:
        ax.set_xlim(-xlim, xlim)
    # ax.set_xlim([(intv.lower-midpoint).total_seconds(), (intv.upper-midpoint).total_seconds()])
    if mode == 'lost':
        ax.bar(table['cat_id'], table['lost'], width=0.01, alpha=0.97)
        ax.set_ylabel('Lost Number')
        ax.set_ylim(bottom=0)
    if mode == 'plr':
        ax.bar(table['cat_id'], table['PLR'], width=0.01, alpha=0.97)
        ax.set_ylabel('Packet Loss Rate (%)')
        ax.axhline(stable_plr, color='tab:pink', linestyle='--', label='Stable PLR')
        ax.axhline(plr1, color='tab:green', linestyle='--', label=f'{title} PLR')
        ax.text(-1.078*xlim, plr1, '{:.2f}'.format(plr1), ha='center', fontweight='bold', fontsize=10, color='tab:green')
        # ax.axhline(plr, color='tab:orange', linestyle='--', label=f'{title} PLR')
        # ax.text(-1.078*xlim, plr, '{:.2f}'.format(plr), ha='center', fontweight='bold', fontsize=10, color='tab:orange')
        ax.legend()
        bleft = -ImpactScope[title][0]
        bright = ImpactScope[title][1]
        rect1 = patches.Rectangle((bleft, 0), bright-bleft, plr, ec=None, fc='#ffbc00', alpha=0.5)  # 左下角座標點, 寬度, 高度, 邊界顏色, 填滿顏色
        ax.add_patch(rect1)
        # ax.set_ylim(top=105)
        ax.set_ylim(bottom=0)
    intr /= 2
    # ax.axvline((start-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    # ax.axvline((end-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    ax.axvline(-intr, color='tab:red', alpha=0.5)
    ax.axvline(intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    plt.gcf().autofmt_xdate()
    plt.savefig(os.path.join(path, f'{title}_{flow.upper()}_{mode}.png'), bbox_inches='tight', dpi=300)
    plt.show()

def plot_intrs(data, tag, path=''):
    data = [s*1000 for s in data]
    
    # Plot the violin plot
    fig, ax = plt.subplots(figsize=(6, 1.5))
    ax.violinplot(data, positions=None, vert=False, quantiles=[0.25, 0.5, 0.75])

    # Calculate and plot the mean and median values
    mean = np.mean(data)
    ax.axvline(mean, color='r', linestyle='--', label='Mean')
    ax.text(mean, 0.58, '{:.1f}'.format(mean), ha='center', fontweight='bold', fontsize=10, color='r')
    ax.set_xlim(left=0)
    ax.set_yticks([])
    ax.set_title(tag)
    ax.set_xlabel('Handover Interruption Time (ms)')

    # Add legend and title
    ax.legend()
    
    # Show the plot
    plt.savefig(os.path.join(path, f'{tag}_intr_dist.png'), bbox_inches='tight', dpi=300)
    plt.show()

# %%
wsize = 0.2

# %% [markdown]
# ## Downlink

# %% [markdown]
# ### Arrival Time

# %%
datadir = "/Users/jackbedford/Desktop/MOXA/Code/data"
exps = {
    "2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(12)],
    "2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(6)],
    "2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    # "2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(1)],
}
_devices = [
    ['qc00','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    # ['qc00'],
]
_schemes = [
    ['B1','B7','B8'],
    ['B1','B3','B7','B8'],
    ['B1B3','B1B8','LTE','All'],
    # ['B1B3'],
]

# %%
sorter = ['LTE_HO','MN_HO','SN_HO','MNSN_HO','SN_Rel','SN_Setup','SN_Rel_MN_HO','SN_Setup_MN_HO',
          'SCG_Failure_t310-Expiry (0)','SCG_Failure_randomAccessProblem (1)','SCG_Failure_rlc-MaxNumRetx (2)','SCG_Failure_synchReconfigFailureSCG (3)',
          'SCG_Failure_scg-ReconfigFailure (4)','SCG_Failure_srb3-IntegrityFailure (5)','SCG_Failure_other-r16 (6)',
          'MCG_Failure_reconfigurationFailure (0)','MCG_Failure_handoverFailure (1)','MCG_Failure_otherFailure (2)',
          'NAS_Recovery_reconfigurationFailure (0)','NAS_Recovery_handoverFailure (1)','NAS_Recovery_otherFailure (2)']

D = {}
for tag in sorter:
    D[tag] = {'tables': [], 'intrs': [], 'count': []}
stable_pkt = 0
stable_loss = 0
for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
    for trace in traces:
        for j, (dev, schm) in enumerate(zip(devices, schemes)):
            ## read downlink
            data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_dnlk_loss_latency.csv')
            print(data, os.path.isfile(data))
            df_dl = pd.read_csv(data)
            df_dl = set_data(df_dl)
            ## read handover
            path = os.path.join(datadir, exp, dev, trace, 'data')
            data = os.path.join(path, [s for s in os.listdir(path) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_csv(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type0
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### 
                table, intv = setup_profile(df_dl, tag, start, end, mode='dl', sec=wsize, left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
            ### count stable loss, pkt
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
                stable_pkt += len(df_tmp)
                stable_loss += sum(df_tmp['lost'])
                _intv = intv
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
            stable_pkt += len(df_tmp)
            stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                D[tag]['tables'].append(table)
                D[tag]['intrs'] = [*D[tag]['intrs'], *A[tag]['intrs']]
                D[tag]['count'].append(len(A[tag]['tables']))
            stable_plr = stable_loss / (stable_pkt + 1e-9) * 100
            print(stable_loss, stable_pkt, round(stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.csv True
# 0 118909 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.csv True
# 0 221289 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.csv True
# 0 318251 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.csv True
# 0 444289 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.csv True
# 0 544677 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.csv True
# 0 648139 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.csv True
# 0 780764 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.csv True
# 0 890028 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.csv True
# 0 1004825 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.csv True
# 0 1129761 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.csv True
# 0 1229580 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.csv True
# 0 1335988 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.csv True
# 0 1462610 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.csv True
# 0 1563402 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.csv True
# 0 1663409 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.csv True
# 0 1788298 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.csv True
# 3 1883921 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.csv True
# 3 1994489 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.csv True
# 3 2117379 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.csv True
# 90 2220338 0.004
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.csv True
# 90 2316288 0.004
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.csv True
# 90 2437323 0.004
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.csv True
# 90 2530091 0.004
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.csv True
# 90 2631886 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.csv True
# 90 2759925 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.csv True
# 90 2856606 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.csv True
# 90 2962506 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.csv True
# 90 3082894 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.csv True
# 90 3187985 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.csv True
# 90 3283054 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.csv True
# 90 3410602 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.csv True
# 91 3507217 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.csv True
# 91 3609048 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.csv True
# 91 3730260 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.csv True
# 91 3826323 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.csv True
# 91 3924412 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.csv True
# 92 4054184 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.csv True
# 92 4159277 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.csv True
# 94 4265850 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.csv True
# 95 4374405 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.csv True
# 97 4502849 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.csv True
# 97 4614331 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.csv True
# 98 4721207 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.csv True
# 102 4824946 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.csv True
# 105 4964911 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.csv True
# 105 5085235 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.csv True
# 111 5199453 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.csv True
# 115 5318447 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.csv True
# 620 5444900 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.csv True
# 621 5550334 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.csv True
# 28 2023-04-01 14:49:49.990450 2023-04-01 14:49:50.443961 MN_HO nan
# 29 2023-04-01 14:49:50.311569 2023-04-01 14:49:50.395569 MCG_Failure handoverFailure (1)
# 625 5656770 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.csv True
# 626 5764602 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.csv True
# 628 5904952 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.csv True
# 628 6021128 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.csv True
# 632 6134486 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.csv True
# 11 2023-04-01 14:57:54.316881 2023-04-01 14:57:54.704566 MN_HO nan
# 12 2023-04-01 14:57:54.550779 2023-04-01 14:57:54.617962 MCG_Failure handoverFailure (1)
# 632 6251057 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.csv True
# 636 6376007 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.csv True
# 636 6484288 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.csv True
# 637 6589188 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.csv True
# 638 6695439 0.01
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.csv True
# 642 6822850 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.csv True
# 642 6943613 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.csv True
# 642 7087217 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.csv True
# 645 7200092 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.csv True
# 646 7305432 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.csv True
# 648 7407512 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.csv True
# 844 7531319 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.csv True
# 849 7634960 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.csv True
# 853 7760809 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.csv True
# 946 7874744 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.csv True
# 948 8007269 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.csv True
# 949 8123068 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.csv True
# 971 8227732 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.csv True
# 973 8327951 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.csv True
# 973 8452086 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.csv True
# 974 8557434 0.011

# %%
datadir = "/Users/jackbedford/Desktop/MOXA/Code/data"
exps = {
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q": ['#{:02d}'.format(i+1) for i in range(2)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(2)],
}
_devices = [
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
]
_schemes = [
    ['All','LTE','B1B3','B3B7'],
    ['All','LTE','B1B7','B7B8'],
    ['All','LTE','B1B8','B3B8'],
    ['All0','LTE1','All2','LTE3'],
    ['All','LTE','B1','B3'],
    ['All','LTE','B7','B8'],
]

# %%
sorter = ['LTE_HO','MN_HO','SN_HO','MNSN_HO','SN_Rel','SN_Setup','SN_Rel_MN_HO','SN_Setup_MN_HO',
          'SCG_Failure_t310-Expiry (0)','SCG_Failure_randomAccessProblem (1)','SCG_Failure_rlc-MaxNumRetx (2)','SCG_Failure_synchReconfigFailureSCG (3)',
          'SCG_Failure_scg-ReconfigFailure (4)','SCG_Failure_srb3-IntegrityFailure (5)','SCG_Failure_other-r16 (6)',
          'MCG_Failure_reconfigurationFailure (0)','MCG_Failure_handoverFailure (1)','MCG_Failure_otherFailure (2)',
          'NAS_Recovery_reconfigurationFailure (0)','NAS_Recovery_handoverFailure (1)','NAS_Recovery_otherFailure (2)']

E = {}
for tag in sorter:
    E[tag] = {'tables': [], 'intrs': [], 'count': []}
stable_pkt = 0
stable_loss = 0
for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
    for trace in traces:
        for j, (dev, schm) in enumerate(zip(devices, schemes)):
            ## read downlink
            data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_dnlk_loss_latency.csv')
            print(data, os.path.isfile(data))
            df_dl = pd.read_csv(data)
            df_dl = set_data(df_dl)
            ## read handover
            path = os.path.join(datadir, exp, dev, trace, 'data')
            data = os.path.join(path, [s for s in os.listdir(path) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_csv(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type0
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### 
                wsize = math.ceil(max(ImpactScope[tag]))
                # print(wsize)
                # print(type(wsize))
                table, intv = setup_profile(df_dl, tag, start, end, mode='dl', sec=wsize, left=left, right=right, fix=True)
                # table, intv = setup_profile(df_dl, tag, start, end, mode='dl', sec=wsize, left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
            ### count stable loss, pkt
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
                stable_pkt += len(df_tmp)
                stable_loss += sum(df_tmp['lost'])
                _intv = intv
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
            stable_pkt += len(df_tmp)
            stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                E[tag]['tables'].append(table)
                E[tag]['intrs'] = [*E[tag]['intrs'], *A[tag]['intrs']]
                E[tag]['count'].append(len(A[tag]['tables']))
            stable_plr = stable_loss / (stable_pkt + 1e-9) * 100
            print(stable_loss, stable_pkt, round(stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-15-10_rrc.csv True
# 0 95477 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-15-10_rrc.csv True
# 0 202463 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-15-10_rrc.csv True
# 0 301594 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-15-10_rrc.csv True
# 0 395971 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_14-24-04_rrc.csv True
# 0 484376 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_14-24-04_rrc.csv True
# 0 590811 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_14-24-04_rrc.csv True
# 0 683590 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_14-24-04_rrc.csv True
# 0 774987 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_14-35-41_rrc.csv True
# 0 880684 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_14-35-41_rrc.csv True
# 0 1007592 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_14-35-41_rrc.csv True
# 1 1104545 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_14-35-41_rrc.csv True
# 700 1251560 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_14-44-10_rrc.csv True
# 700 1340421 0.052
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_14-44-10_rrc.csv True
# 700 1443097 0.049
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_14-44-10_rrc.csv True
# 700 1539357 0.045
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_14-44-10_rrc.csv True
# 835 1674384 0.05
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-55-50_rrc.csv True
# 836 1776775 0.047
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-55-50_rrc.csv True
# 836 1897221 0.044
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-55-50_rrc.csv True
# 836 1995618 0.042
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-55-50_rrc.csv True
# 836 2090190 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-04-11_rrc.csv True
# 836 2178508 0.038
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_15-04-11_rrc.csv True
# 836 2284718 0.037
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_15-04-11_rrc.csv True
# 837 2376203 0.035
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_15-04-11_rrc.csv True
# 839 2459937 0.034
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-10-33_rrc.csv True
# 839 2570508 0.033
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_15-10-33_rrc.csv True
# 839 2698284 0.031
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_15-10-33_rrc.csv True
# 839 2797154 0.03
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_15-10-33_rrc.csv True
# 839 2902632 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_15-19-12_rrc.csv True
# 839 2997655 0.028
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_15-19-12_rrc.csv True
# 839 3111211 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_15-19-12_rrc.csv True
# 839 3200317 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_15-19-12_rrc.csv True
# 839 3286628 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_15-25-52_rrc.csv True
# 839 3384379 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_15-25-52_rrc.csv True
# 839 3501201 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_15-25-52_rrc.csv True
# 839 3605073 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_15-25-52_rrc.csv True
# 839 3711668 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-34-15_rrc.csv True
# 841 3794770 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_15-34-15_rrc.csv True
# 841 3902339 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_15-34-15_rrc.csv True
# 841 3992088 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_15-34-15_rrc.csv True
# 841 4086627 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-40-52_rrc.csv True
# 841 4194563 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_15-40-52_rrc.csv True
# 841 4317942 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_15-40-52_rrc.csv True
# 841 4419159 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_15-40-52_rrc.csv True
# 841 4519534 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_15-49-16_rrc.csv True
# 841 4616633 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_15-49-16_rrc.csv True
# 841 4715724 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_15-49-16_rrc.csv True
# 841 4814973 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_15-49-16_rrc.csv True
# 841 4903198 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_16-17-28_rrc.csv True
# 841 4989954 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_16-17-28_rrc.csv True
# 841 5074541 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_16-17-28_rrc.csv True
# 841 5164245 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_16-17-28_rrc.csv True
# 841 5253084 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_16-35-58_rrc.csv True
# 841 5340595 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_16-35-58_rrc.csv True
# 841 5442482 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_16-35-58_rrc.csv True
# 841 5529667 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_16-35-58_rrc.csv True
# 841 5629497 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_16-43-43_rrc.csv True
# 841 5725420 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_16-43-43_rrc.csv True
# 841 5843129 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_16-43-43_rrc.csv True
# 841 5942449 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_16-43-43_rrc.csv True
# 841 6060653 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_16-51-18_rrc.csv True
# 841 6139307 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_16-51-18_rrc.csv True
# 841 6239420 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_16-51-18_rrc.csv True
# 842 6331803 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_16-51-18_rrc.csv True
# 842 6435202 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-01-08_rrc.csv True
# 842 6542181 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-01-08_rrc.csv True
# 842 6665970 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-01-08_rrc.csv True
# 842 6793920 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-01-08_rrc.csv True
# 842 6906686 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-09-48_rrc.csv True
# 843 6989097 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-09-48_rrc.csv True
# 843 7095803 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-09-48_rrc.csv True
# 843 7203968 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-09-48_rrc.csv True
# 844 7288397 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-18-15_rrc.csv True
# 844 7380519 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-18-15_rrc.csv True
# 844 7498009 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-18-15_rrc.csv True
# 844 7597805 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-18-15_rrc.csv True
# 844 7700256 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-27-58_rrc.csv True
# 845 7783793 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-27-58_rrc.csv True
# 845 7890563 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-27-58_rrc.csv True
# 846 7972232 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-27-58_rrc.csv True
# 846 8057808 0.01

# %%
for tag in sorter:
    if len(D[tag]['intrs']) == 0 or len(E[tag]['intrs']) == 0:
        continue
    print('===================================')
    print(tag)
    table, intr = merge_profile(D[tag]['tables'], D[tag]['intrs'])
    table1, intr1 = merge_profile(E[tag]['tables'], E[tag]['intrs'])
    # print('Avg Duration:', intr, 'seconds')
    # print('HO Count:', sum(D[tag]['count']))
    print('Avg Duration:', intr1, 'seconds')
    print('HO Count:', sum(E[tag]['count']))
    # display(table)
    # _table = table.query('PLR > @stable_plr').copy().reset_index(drop=True)
    _table = table.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr = lcount / (tcount + 1e-9) * 100
    _table = table1.query('PLR > @stable_plr').copy().reset_index(drop=True)
    # _table = table1.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr1 = lcount / (tcount + 1e-9) * 100
    print('Avg PLR:', plr1, '%')
    path = '/Users/jackbedford/Desktop/MOXA/2023-04-20/figure1/'
    # plot_intrs(D[tag]['intrs'], tag, path=path)
    plot_intrs(E[tag]['intrs'], tag, path=path)
    wsize = math.ceil(max(ImpactScope[tag]))
    plot_profile(table1, intr=intr1, title=tag, mode='lost', xlim=wsize, path=path, flow='dl')
    plot_profile(table1, intr=intr1, title=tag, mode='plr', xlim=wsize, path=path, flow='dl', stable_plr=stable_plr, plr=plr, plr1=plr1)
# Out:
# ===================================
# LTE_HO
# Avg Duration: 0.03226814965639159 seconds
# HO Count: 107
# Avg PLR: 6.582454513848396 %
# ===================================
# MN_HO
# Avg Duration: 0.019795016921012872 seconds
# HO Count: 828
# Avg PLR: 1.4849736075354532 %
# ===================================
# SN_HO
# Avg Duration: 0.01491855307164805 seconds
# HO Count: 895
# Avg PLR: 0.44969347066159926 %
# ===================================
# SN_Rel
# Avg Duration: 0.03163199995954832 seconds
# HO Count: 3
# Avg PLR: 0.0 %
# ===================================
# SN_Setup
# Avg Duration: 0.03260124673139755 seconds
# HO Count: 223
# Avg PLR: 14.931269839107292 %
# ===================================
# SN_Rel_MN_HO
# Avg Duration: 0.018021909063229098 seconds
# HO Count: 473
# Avg PLR: 2.2227202346996533 %
# ===================================
# SCG_Failure_synchReconfigFailureSCG (3)
# Avg Duration: 0.0 seconds
# HO Count: 2
# Avg PLR: 0.0 %
# ===================================
# MCG_Failure_handoverFailure (1)
# Avg Duration: 0.07857580035924912 seconds
# HO Count: 5
# Avg PLR: 99.24242424237725 %
# ===================================
# MCG_Failure_otherFailure (2)
# Avg Duration: 0.07910625225915684 seconds
# HO Count: 127
# Avg PLR: 35.3960879241007 %
# ===================================
# NAS_Recovery_otherFailure (2)
# Avg Duration: 0.1970453311999639 seconds
# HO Count: 3
# Avg PLR: 64.75770925095868 %

# %% [markdown]
# ## Uplink

# %% [markdown]
# ### Transmission Time

# %%
datadir = "/Users/jackbedford/Desktop/MOXA/Code/data"
exps = {
    "2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(12)],
    "2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(6)],
    "2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    # "2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(1)],
}
_devices = [
    ['qc00','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    # ['qc00'],
]
_schemes = [
    ['B1','B7','B8'],
    ['B1','B3','B7','B8'],
    ['B1B3','B1B8','LTE','All'],
    # ['B1B3'],
]

# %%
sorter = ['LTE_HO','MN_HO','SN_HO','MNSN_HO','SN_Rel','SN_Setup','SN_Rel_MN_HO','SN_Setup_MN_HO',
          'SCG_Failure_t310-Expiry (0)','SCG_Failure_randomAccessProblem (1)','SCG_Failure_rlc-MaxNumRetx (2)','SCG_Failure_synchReconfigFailureSCG (3)',
          'SCG_Failure_scg-ReconfigFailure (4)','SCG_Failure_srb3-IntegrityFailure (5)','SCG_Failure_other-r16 (6)',
          'MCG_Failure_reconfigurationFailure (0)','MCG_Failure_handoverFailure (1)','MCG_Failure_otherFailure (2)',
          'NAS_Recovery_reconfigurationFailure (0)','NAS_Recovery_handoverFailure (1)','NAS_Recovery_otherFailure (2)']

D = {}
for tag in sorter:
    D[tag] = {'tables': [], 'intrs': [], 'count': []}
stable_pkt = 0
stable_loss = 0
for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
    for trace in traces:
        for j, (dev, schm) in enumerate(zip(devices, schemes)):
            ## read downlink
            data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_dnlk_loss_latency.csv')
            print(data, os.path.isfile(data))
            df_ul = pd.read_csv(data)
            df_ul = set_data(df_ul)
            ## read handover
            path = os.path.join(datadir, exp, dev, trace, 'data')
            data = os.path.join(path, [s for s in os.listdir(path) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_csv(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type0
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### 
                table, intv = setup_profile(df_ul, tag, start, end, mode='ul', sec=wsize, left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
            ### count stable loss, pkt
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
                stable_pkt += len(df_tmp)
                stable_loss += sum(df_tmp['lost'])
                _intv = intv
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
            stable_pkt += len(df_tmp)
            stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                D[tag]['tables'].append(table)
                D[tag]['intrs'] = [*D[tag]['intrs'], *A[tag]['intrs']]
                D[tag]['count'].append(len(A[tag]['tables']))
            stable_plr = stable_loss / (stable_pkt + 1e-9) * 100
            print(stable_loss, stable_pkt, round(stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.csv True
# 0 119064 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.csv True
# 0 221381 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.csv True
# 0 318306 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.csv True
# 0 444338 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.csv True
# 0 544606 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.csv True
# 0 648076 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.csv True
# 0 781076 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.csv True
# 0 890196 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.csv True
# 0 1004989 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.csv True
# 0 1129931 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.csv True
# 0 1229719 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.csv True
# 0 1336129 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.csv True
# 0 1462769 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.csv True
# 0 1563448 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.csv True
# 0 1663453 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.csv True
# 0 1788337 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.csv True
# 1 1883795 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.csv True
# 1 1994380 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.csv True
# 1 2117304 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.csv True
# 67 2220194 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.csv True
# 67 2316151 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.csv True
# 67 2437205 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.csv True
# 67 2529773 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.csv True
# 67 2631530 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.csv True
# 67 2759627 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.csv True
# 67 2856159 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.csv True
# 67 2962063 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.csv True
# 67 3082464 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.csv True
# 67 3187461 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.csv True
# 67 3282516 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.csv True
# 67 3410158 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.csv True
# 67 3506469 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.csv True
# 67 3608302 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.csv True
# 67 3729553 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.csv True
# 67 3825514 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.csv True
# 67 3923605 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.csv True
# 68 4053397 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.csv True
# 68 4158485 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.csv True
# 69 4264949 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.csv True
# 70 4373485 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.csv True
# 72 4501926 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.csv True
# 72 4613410 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.csv True
# 73 4720137 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.csv True
# 77 4823873 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.csv True
# 80 4963811 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.csv True
# 80 5084166 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.csv True
# 86 5198211 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.csv True
# 90 5317190 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.csv True
# 94 5442373 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.csv True
# 98 5548006 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.csv True
# 28 2023-04-01 14:49:49.990450 2023-04-01 14:49:50.443961 MN_HO nan
# 29 2023-04-01 14:49:50.311569 2023-04-01 14:49:50.395569 MCG_Failure handoverFailure (1)
# 101 5654205 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.csv True
# 102 5762033 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.csv True
# 104 5902319 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.csv True
# 104 6018496 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.csv True
# 108 6131741 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.csv True
# 11 2023-04-01 14:57:54.316881 2023-04-01 14:57:54.704566 MN_HO nan
# 12 2023-04-01 14:57:54.550779 2023-04-01 14:57:54.617962 MCG_Failure handoverFailure (1)
# 108 6248284 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.csv True
# 112 6373238 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.csv True
# 112 6481508 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.csv True
# 113 6586187 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.csv True
# 114 6692423 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.csv True
# 118 6819830 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.csv True
# 118 6940587 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.csv True
# 118 7084184 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.csv True
# 121 7197047 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.csv True
# 122 7302350 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.csv True
# 124 7404418 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.csv True
# 126 7527435 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.csv True
# 131 7631038 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.csv True
# 135 7756916 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.csv True
# 228 7870873 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.csv True
# 230 8003411 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.csv True
# 231 8119187 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.csv True
# 249 8223834 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.csv True
# 250 8324007 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.csv True
# 250 8448147 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/_Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.csv True
# 251 8553480 0.003

# %%
datadir = "/Users/jackbedford/Desktop/MOXA/Code/data"
exps = {
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q": ['#{:02d}'.format(i+1) for i in range(4)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q": ['#{:02d}'.format(i+1) for i in range(2)],
    "2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q": ['#{:02d}'.format(i+1) for i in range(2)],
}
_devices = [
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
    ['qc00','qc01','qc02','qc03'],
]
_schemes = [
    ['All','LTE','B1B3','B3B7'],
    ['All','LTE','B1B7','B7B8'],
    ['All','LTE','B1B8','B3B8'],
    ['All0','LTE1','All2','LTE3'],
    ['All','LTE','B1','B3'],
    ['All','LTE','B7','B8'],
]

# %%
sorter = ['LTE_HO','MN_HO','SN_HO','MNSN_HO','SN_Rel','SN_Setup','SN_Rel_MN_HO','SN_Setup_MN_HO',
          'SCG_Failure_t310-Expiry (0)','SCG_Failure_randomAccessProblem (1)','SCG_Failure_rlc-MaxNumRetx (2)','SCG_Failure_synchReconfigFailureSCG (3)',
          'SCG_Failure_scg-ReconfigFailure (4)','SCG_Failure_srb3-IntegrityFailure (5)','SCG_Failure_other-r16 (6)',
          'MCG_Failure_reconfigurationFailure (0)','MCG_Failure_handoverFailure (1)','MCG_Failure_otherFailure (2)',
          'NAS_Recovery_reconfigurationFailure (0)','NAS_Recovery_handoverFailure (1)','NAS_Recovery_otherFailure (2)']

E = {}
for tag in sorter:
    E[tag] = {'tables': [], 'intrs': [], 'count': []}
stable_pkt = 0
stable_loss = 0
for (exp, traces), devices, schemes in zip(exps.items(), _devices, _schemes):
    for trace in traces:
        for j, (dev, schm) in enumerate(zip(devices, schemes)):
            ## read downlink
            data = os.path.join(datadir, exp, dev, trace, 'data', 'udp_dnlk_loss_latency.csv')
            print(data, os.path.isfile(data))
            df_ul = pd.read_csv(data)
            df_ul = set_data(df_ul)
            ## read handover
            path = os.path.join(datadir, exp, dev, trace, 'data')
            data = os.path.join(path, [s for s in os.listdir(path) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_csv(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type0
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### 
                wsize = math.ceil(max(ImpactScope[tag]))
                table, intv = setup_profile(df_ul, tag, start, end, mode='ul', sec=wsize, left=left, right=right, fix=True)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
            ### count stable loss, pkt
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
                stable_pkt += len(df_tmp)
                stable_loss += sum(df_tmp['lost'])
                _intv = intv
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
            stable_pkt += len(df_tmp)
            stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                E[tag]['tables'].append(table)
                E[tag]['intrs'] = [*E[tag]['intrs'], *A[tag]['intrs']]
                E[tag]['count'].append(len(A[tag]['tables']))
            stable_plr = stable_loss / (stable_pkt + 1e-9) * 100
            print(stable_loss, stable_pkt, round(stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-15-10_rrc.csv True
# 0 95483 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-15-10_rrc.csv True
# 0 202473 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-15-10_rrc.csv True
# 0 301594 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-15-10_rrc.csv True
# 0 395977 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_14-24-04_rrc.csv True
# 0 484385 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_14-24-04_rrc.csv True
# 0 590904 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_14-24-04_rrc.csv True
# 0 683684 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_14-24-04_rrc.csv True
# 0 775077 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_14-35-41_rrc.csv True
# 0 880754 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_14-35-41_rrc.csv True
# 0 1007615 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_14-35-41_rrc.csv True
# 1 1104582 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_14-35-41_rrc.csv True
# 700 1251598 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_14-44-10_rrc.csv True
# 700 1340469 0.052
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_14-44-10_rrc.csv True
# 700 1443138 0.049
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_14-44-10_rrc.csv True
# 700 1539394 0.045
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_14-44-10_rrc.csv True
# 835 1674424 0.05
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-55-50_rrc.csv True
# 836 1776824 0.047
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-55-50_rrc.csv True
# 836 1897263 0.044
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-55-50_rrc.csv True
# 836 1995659 0.042
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-55-50_rrc.csv True
# 836 2090254 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-04-11_rrc.csv True
# 836 2178574 0.038
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_15-04-11_rrc.csv True
# 836 2284789 0.037
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_15-04-11_rrc.csv True
# 837 2376290 0.035
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_15-04-11_rrc.csv True
# 839 2460031 0.034
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-10-33_rrc.csv True
# 839 2570596 0.033
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_15-10-33_rrc.csv True
# 839 2698380 0.031
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_15-10-33_rrc.csv True
# 839 2797231 0.03
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_15-10-33_rrc.csv True
# 839 2902719 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_15-19-12_rrc.csv True
# 839 2997725 0.028
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_15-19-12_rrc.csv True
# 839 3111302 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_15-19-12_rrc.csv True
# 839 3200407 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_15-19-12_rrc.csv True
# 839 3286702 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_15-25-52_rrc.csv True
# 839 3384432 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_15-25-52_rrc.csv True
# 839 3501271 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_15-25-52_rrc.csv True
# 839 3605132 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_15-25-52_rrc.csv True
# 839 3711729 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-34-15_rrc.csv True
# 841 3794829 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_15-34-15_rrc.csv True
# 841 3902403 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_15-34-15_rrc.csv True
# 841 3992167 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_15-34-15_rrc.csv True
# 841 4086717 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-40-52_rrc.csv True
# 841 4194647 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_15-40-52_rrc.csv True
# 841 4318027 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_15-40-52_rrc.csv True
# 841 4419270 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_15-40-52_rrc.csv True
# 841 4519676 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_15-49-16_rrc.csv True
# 841 4616764 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_15-49-16_rrc.csv True
# 841 4715824 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_15-49-16_rrc.csv True
# 841 4815079 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_15-49-16_rrc.csv True
# 841 4903276 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_16-17-28_rrc.csv True
# 841 4990009 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_16-17-28_rrc.csv True
# 841 5074444 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_16-17-28_rrc.csv True
# 841 5164147 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_16-17-28_rrc.csv True
# 841 5252997 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_16-35-58_rrc.csv True
# 841 5340515 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_16-35-58_rrc.csv True
# 841 5442449 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_16-35-58_rrc.csv True
# 841 5529642 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_16-35-58_rrc.csv True
# 841 5629464 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_16-43-43_rrc.csv True
# 841 5725385 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_16-43-43_rrc.csv True
# 841 5843096 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_16-43-43_rrc.csv True
# 841 5942404 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_16-43-43_rrc.csv True
# 841 6060674 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_16-51-18_rrc.csv True
# 841 6139338 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_16-51-18_rrc.csv True
# 841 6239454 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_16-51-18_rrc.csv True
# 842 6331839 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_16-51-18_rrc.csv True
# 842 6435226 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-01-08_rrc.csv True
# 842 6542205 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-01-08_rrc.csv True
# 842 6665999 0.013
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-01-08_rrc.csv True
# 842 6793961 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-01-08_rrc.csv True
# 842 6906748 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-09-48_rrc.csv True
# 843 6989165 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-09-48_rrc.csv True
# 843 7095871 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-09-48_rrc.csv True
# 843 7204033 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-09-48_rrc.csv True
# 844 7288467 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-18-15_rrc.csv True
# 844 7380603 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-18-15_rrc.csv True
# 844 7498096 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-18-15_rrc.csv True
# 844 7597909 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-18-15_rrc.csv True
# 844 7700379 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-27-58_rrc.csv True
# 845 7783924 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-27-58_rrc.csv True
# 845 7890722 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-27-58_rrc.csv True
# 846 7972383 0.011
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/_Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-27-58_rrc.csv True
# 846 8057957 0.01

# %%
for tag in sorter:
    if len(D[tag]['intrs']) == 0 or len(E[tag]['intrs']) == 0:
        continue
    print('===================================')
    print(tag)
    table, intr = merge_profile(D[tag]['tables'], D[tag]['intrs'])
    table1, intr1 = merge_profile(E[tag]['tables'], E[tag]['intrs'])
    # print('Avg Duration:', intr, 'seconds')
    # print('HO Count:', sum(D[tag]['count']))
    print('Avg Duration:', intr1, 'seconds')
    print('HO Count:', sum(E[tag]['count']))
    # display(table)
    # _table = table.query('PLR > @stable_plr').copy().reset_index(drop=True)
    _table = table.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr = lcount / (tcount + 1e-9) * 100
    _table = table1.query('PLR > @stable_plr').copy().reset_index(drop=True)
    # _table = table1.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr1 = lcount / (tcount + 1e-9) * 100
    print('Avg PLR:', plr1, '%')
    path = '/Users/jackbedford/Desktop/MOXA/2023-04-20/figure1/'
    # plot_intrs(D[tag]['intrs'], tag, path=path)
    plot_intrs(E[tag]['intrs'], tag, path=path)
    wsize = math.ceil(max(ImpactScope[tag]))
    plot_profile(table1, intr=intr1, title=tag, mode='lost', xlim=wsize, path=path, flow='ul')
    plot_profile(table1, intr=intr1, title=tag, mode='plr', xlim=wsize, path=path, flow='ul', stable_plr=stable_plr, plr=plr, plr1=plr1)
# Out:
# ===================================
# LTE_HO
# Avg Duration: 0.03226814965639159 seconds
# HO Count: 107
# Avg PLR: 6.852955693078444 %
# ===================================
# MN_HO
# Avg Duration: 0.019795016921012872 seconds
# HO Count: 828
# Avg PLR: 1.461316300896974 %
# ===================================
# SN_HO
# Avg Duration: 0.01491855307164805 seconds
# HO Count: 895
# Avg PLR: 0.4571421551162813 %
# ===================================
# SN_Rel
# Avg Duration: 0.03163199995954832 seconds
# HO Count: 3
# Avg PLR: 0.0 %
# ===================================
# SN_Setup
# Avg Duration: 0.03260124673139755 seconds
# HO Count: 223
# Avg PLR: 14.26894373480159 %
# ===================================
# SN_Rel_MN_HO
# Avg Duration: 0.018021909063229098 seconds
# HO Count: 473
# Avg PLR: 0.3856407191779214 %
# ===================================
# SCG_Failure_synchReconfigFailureSCG (3)
# Avg Duration: 0.0 seconds
# HO Count: 2
# Avg PLR: 0.0 %
# ===================================
# MCG_Failure_handoverFailure (1)
# Avg Duration: 0.07857580035924912 seconds
# HO Count: 5
# Avg PLR: 99.53959484341642 %
# ===================================
# MCG_Failure_otherFailure (2)
# Avg Duration: 0.07910625225915684 seconds
# HO Count: 127
# Avg PLR: 26.722027346266543 %
# ===================================
# NAS_Recovery_otherFailure (2)
# Avg Duration: 0.1970453311999639 seconds
# HO Count: 3
# Avg PLR: 65.11111111096642 %
