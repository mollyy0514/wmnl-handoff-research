# %% [markdown]
# # Functions Definition

# %%
import numpy as np
import pandas as pd
import datetime as dt
from collections import namedtuple
import ast, swifter

# ************************************************* Sheng-Ru Latest Version (09-25) add try except (10-27) *************************************************

def parse_mi_ho(df, tz=8):

    # df = pd.read_csv(f)
    df["Timestamp"] = df["Timestamp"].swifter.apply(lambda x: pd.to_datetime(x) + dt.timedelta(hours=tz))
    nr_pci = 'O'
    scells = []

    def NR_OTA(idx):

        if df["type_id"].iloc[idx] == "5G_NR_RRC_OTA_Packet": return True
        else: return False
    
    def LTE_SERV_INFO(idx):

        if df["type_id"].iloc[idx] == "LTE_RRC_Serv_Cell_Info": return True
        else: return False
    

    def find_1st_after(start_idx, target, look_after=1):
        for j in range(start_idx, len(df)):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t_ - t).total_seconds() > look_after:
                return None, None
            if df[target].iloc[j] not in [0,'0'] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_1st_before(start_idx, target, look_before=1):
        for j in range(start_idx, -1, -1):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t - t_).total_seconds() > look_before:
                return None, None
            if df[target].iloc[j] not in [0,'0'] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_1st_before_with_special_value(start_idx, target, target_value, look_before=1):
        for j in range(start_idx, -1, -1):
            t_ = df["Timestamp"].iloc[j]
            if NR_OTA(j) or LTE_SERV_INFO(j):
                continue
            if (t - t_).total_seconds() > look_before:
                return None, None
            if df[target].iloc[j] in [target_value] and not np.isnan(df[target].iloc[j]):
                return t_, j
        return None, None
    
    def find_in_D_exact(targets):

        l = []
        # In l : (second, ho_type)
        for target in targets:
            for ho in D[target]:
                l.append(((t - ho.start).total_seconds(), target))

        if len(l) != 0:
            for x in l:
                if (x[0]== 0):
                    return x[1]
        
        return None
    
    def find_in_D_first_before(targets, look_before=1):

        l = []
        # In l : (second, ho_type)
        for target in targets:
            for ho in D[target]:
                try:
                    l.append(((t - ho.end).total_seconds(), target, ho))
                except:
                    pass

        if len(l) != 0:
            closest = min(filter(lambda x: x[0] > 0, l), key=lambda x: x[0])
            if 0 <= closest[0] < look_before:
                return closest[1], closest[2]
        
        return None, None
    
    HO = namedtuple('HO',['start', 'end', 'others', 'trans'], defaults=[None,None,'',''])
    
    D = {
        'Conn_Rel':[], 
        'Conn_Req':[], # Setup
        'LTE_HO': [], # LTE -> newLTE
        'MN_HO': [], # LTE + NR -> newLTE + NR
        'MN_HO_to_eNB': [], # LTE + NR -> newLTE
        'SN_setup': [], # LTE -> LTE + NR => NR setup
        'SN_Rel': [], # LTE + NR -> LTE
        'SN_HO': [], # LTE + NR -> LTE + newNR  
        'RLF_II': [],
        'RLF_III': [],
        'SCG_RLF': [],
        'Add_SCell': [],
        }

    for i in range(len(df)):

        # Pass NR RRC packet. In NSA mode, LTE RRC packet include NR packet message.
        if NR_OTA(i) or LTE_SERV_INFO(i):
            continue

        others = ''
        t = df["Timestamp"].iloc[i]

        if df["rrcConnectionRelease"].iloc[i] == 1:
            D['Conn_Rel'].append(HO(start=t))
            nr_pci = 'O'

        if df["rrcConnectionRequest"].iloc[i] == 1:
            
            # Define end of rrcConnectionRequest to be rrcConnectionReconfigurationComplete or securityModeComplete.
            a = find_1st_after(i, 'rrcConnectionReconfigurationComplete',look_after=2)[0]
            b = find_1st_after(i, 'securityModeComplete',look_after=2)[0]
            if a is None and b is None: end = None
            elif a is None and b is not None: end = b
            elif a is not None and b is None: end = a 
            else: end = a if a > b else b
            
            serv_cell, serv_freq = df["PCI"].iloc[i], int(df["Freq"].iloc[i])
            trans = f'? -> ({serv_cell}, {serv_freq})'
            D['Conn_Req'].append(HO(start=t,end=end,trans=trans))
            nr_pci = 'O'
        
        if df["lte-rrc.t304"].iloc[i] == 1:
            
            end, _ = find_1st_after(i, 'rrcConnectionReconfigurationComplete')
            serv_cell, target_cell = df["PCI"].iloc[i], int(df['lte_targetPhysCellId'].iloc[i])
            serv_freq, target_freq = int(df["Freq"].iloc[i]), int(df['dl-CarrierFreq'].iloc[i])

            if df["SCellToAddMod-r10"].iloc[i] == 1:
                n =len(str(df["SCellIndex-r10.1"].iloc[i]).split('@'))
                others += f' Set up {n} SCell.'
            else:
                scells = []
            
            if serv_freq != target_freq:
                a,b = find_1st_before(i, "rrcConnectionReestablishmentRequest", 1)
                others += " Inter frequency HO."
                if a is not None:
                    others += " Near after RLF."
                
            if df["nr-rrc.t304"].iloc[i] == 1 and df["dualConnectivityPHR: setup (1)"].iloc[i] == 1:
                
                if serv_cell == target_cell and serv_freq == target_freq:

                    a, _ = find_1st_before(i, "rrcConnectionReestablishmentRequest", 2)
                    
                    if a is not None:

                        ho_type, ho = find_in_D_first_before(['RLF_II', 'RLF_III'], 2)
                        try:
                            others += f' Near after RLF of trans: {ho.trans}.'
                        except:
                            others += f' Near after RLF.'

                    else:
                        
                        ho_type, _ = find_in_D_first_before(['MN_HO_to_eNB', 'SN_Rel'], 2)
                        if ho_type is not None:
                            others += f' Near after {ho_type}.'

                    ori_serv = nr_pci
                    nr_pci = int(df['nr_physCellId'].iloc[i])
                    trans = f'({serv_cell}, {serv_freq}) | {ori_serv} -> {nr_pci}'
                    D['SN_setup'].append(HO(start=t, end=end, others=others, trans=trans))

                else:
                    
                    nr_pci = int(df['nr_physCellId'].iloc[i])
                    trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | {nr_pci}'
                    D['MN_HO'].append(HO(start=t, end=end, others=others, trans=trans))

            else:
                
                if serv_cell == target_cell and serv_freq == target_freq:

                    a, b = find_1st_before(i, "scgFailureInformationNR-r15")
                    if a is not None:
                        others += " Caused by scg-failure."
                    
                    orig_serv = nr_pci
                    nr_pci = 'O'
                    trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> {nr_pci}'
                    D['SN_Rel'].append(HO(start=t, end=end, others=others, trans=trans))
                    
                else:

                    a, _ = find_1st_before(i,"rrcConnectionSetup",3)
                    if a is not None:
                        others += ' Near After connection setup.'
                    if nr_pci == 'O':
                        trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | {nr_pci}'
                        D['LTE_HO'].append(HO(start=t, end=end, others=others, trans=trans))
                    else:
                        orig_serv = nr_pci
                        nr_pci = 'O'
                        trans = f'({serv_cell}, {serv_freq}) -> ({target_cell}, {target_freq}) | {orig_serv} -> {nr_pci}'
                        D['MN_HO_to_eNB'].append(HO(start=t, end=end, others=others, trans=trans))


        if df["nr-rrc.t304"].iloc[i] == 1 and not df["dualConnectivityPHR: setup (1)"].iloc[i] == 1:

            end, _ = find_1st_after(i,'rrcConnectionReconfigurationComplete')
        
            serv_cell, serv_freq = df["PCI"].iloc[i], int(df["Freq"].iloc[i])
            orig_serv = nr_pci
            nr_pci = int(df['nr_physCellId'].iloc[i])
            trans = f'({serv_cell}, {serv_freq}) | {orig_serv} -> {nr_pci}'
            D['SN_HO'].append(HO(start=t,end=end,trans=trans))


        if df["rrcConnectionReestablishmentRequest"].iloc[i] == 1:

            end1, _ = find_1st_after(i, 'rrcConnectionReestablishmentComplete', look_after=1)
            b, _ = find_1st_after(i, 'rrcConnectionReestablishmentReject', look_after=1)
            end2, _ = find_1st_after(i, 'securityModeComplete',look_after=3)

            others += ' ' + df["reestablishmentCause"].iloc[i] + '.'
            scells = []

            c, _ = find_1st_before(i, 'scgFailureInformationNR-r15', 1)
            if c != None:
                others  += ' caused by scgfailure.'
                
            serv_cell, rlf_cell = df["PCI"].iloc[i], int(df['physCellId.3'].iloc[i])
            serv_freq = int(df['Freq'].iloc[i])
            
            # Type II & Type III
            if end1 is not None: 

                orig_serv = nr_pci
                nr_pci = 'O'
                _, idx = find_1st_before_with_special_value(i, 'PCI', rlf_cell, look_before=10)
                try:
                    rlf_freq = int(df['Freq'].iloc[idx])
                except:
                    rlf_freq = 0
                trans = f'({rlf_cell}, {rlf_freq}) -> ({serv_cell}, {serv_freq}) | {orig_serv} -> {nr_pci}'
                D['RLF_II'].append(HO(start=t,end=end1,others=others,trans=trans))

            elif b is not None and end2 is not None:
                
                orig_serv = nr_pci
                nr_pci = 'O'
                _, idx = find_1st_before_with_special_value(i, 'PCI', rlf_cell, look_before=10)
                try:
                    rlf_freq = int(df['Freq'].iloc[idx])
                except:
                    rlf_freq = 0

                _, idx = find_1st_after(i, "rrcConnectionRequest", 2)
                recon_cell, recon_freq = df['PCI'].iloc[idx], int(float(df['Freq'].iloc[idx]))
                
                trans = f'({rlf_cell}, {rlf_freq}) -> ({recon_cell}, {recon_freq}) | {orig_serv} -> {nr_pci}'
                D['RLF_III'].append(HO(start=t,end=end2,others=others,trans=trans))
                
            else:
                others+=' No end.'
                D['RLF_II'].append(HO(start=t,others=others))
                print('No end for RLF')

        if df["scgFailureInformationNR-r15"].iloc[i] == 1:

            others += ' ' + df["failureType-r15"].iloc[i] + '.'
            a, idx1 = find_1st_after(i, "rrcConnectionReestablishmentRequest", look_after=1)
            b, idx2 = find_1st_after(i, "lte-rrc.t304", look_after=10)

            if a is not None:

                end1, _ = find_1st_after(idx1, 'rrcConnectionReestablishmentComplete', look_after=1)
                b, _ = find_1st_after(idx1, 'rrcConnectionReestablishmentReject', look_after=1)
                end2 = find_1st_after(idx1, 'securityModeComplete',look_after=3)[0]

                others += ' Result in rrcReestablishment.'
                    
                # Type II & Type III Result
                if end1 is not None: 
                    D['SCG_RLF'].append(HO(start=t,end=end1,others=others))
                elif b is not None and end2 is not None: 
                    D['SCG_RLF'].append(HO(start=t,end=end2,others=others))
                else:
                    others += ' No end.'
                    D['SCG_RLF'].append(HO(start=t,others=others))
                    print('No end for scg failure result in rrcReestablishment.')

            elif b is not None:

                end, _ = find_1st_after(idx2, 'rrcConnectionReconfigurationComplete')
                serv_cell, target_cell = df["PCI"].iloc[idx2], df['lte_targetPhysCellId'].iloc[idx2]
                serv_freq, target_freq = int(df["Freq"].iloc[idx2]), df['dl-CarrierFreq'].iloc[idx2]
                others += ' Result in gNB release.'
                # We do not change nr_pci here. Instead, we will change it at gNB_Rel event.
                trans = f'({serv_cell}, {serv_freq}) | {nr_pci} -> O'
                
                if serv_cell == target_cell and serv_freq == target_freq:
                    D['SCG_RLF'].append(HO(start=t,end=end,others=others,trans=trans))
                else:
                    others += ' Weird gNB release.'
                    print('Weird for scg failure result in gNb Release.')
                    D['SCG_RLF'].append(HO(start=t,end=end,others=others,trans=trans))                  

            else:

                print('No end for scg failure.')
                others += ' No end.'
                D['SCG_RLF'].append(HO(start=t,others=others))
        
        if df['SCellToAddMod-r10'].iloc[i] == 1 and df['physCellId-r10'].iloc[i] != 'nr or cqi report':

            others = ''
            pcis = str(df["physCellId-r10"].iloc[i]).split('@')
            freqs = str(df["dl-CarrierFreq-r10"].iloc[i]).split('@')
            orig_scells = scells
            scells = [(int(float(pci)), int(float(freq))) for pci, freq in zip(pcis, freqs)]

            others += f' Set up {len(scells)} SCell.'
            trans = f'{orig_scells} -> {scells}'

            end, _ = find_1st_after(i,'rrcConnectionReconfigurationComplete')
            
            a, _ = find_1st_before(i, "rrcConnectionReestablishmentRequest", 3)
            if a is not None:
                others += ' Near after RLF.'

            a = find_in_D_exact(['LTE_HO', 'MN_HO', 'MN_HO_to_eNB', 'SN_setup', 'SN_Rel'])
            if a is not None:
                others += f' With {a}.'

            D['Add_SCell'].append(HO(start=t,end=end,others=others, trans=trans))
    
    return D

# ************************************************* parse into readable dataframe *************************************************

def mi_parse_handover(df, tz=8, radical=True):
    
    def parse_trans(item):
        
        chunk = item.split(' | ')
        
        if len(chunk) == 1:
            s_src = np.nan
            s_tgt = np.nan
            if chunk[0] == '':
                m_src = np.nan
                m_tgt = np.nan
            elif chunk[0][0] == '?':
                m_src = np.nan
                m_tgt = chunk[0].split(' -> ')[1]
            else:
                m_src = chunk[0].split(' -> ')[0]
                m_tgt = chunk[0].split(' -> ')[1]
        else:
            if chunk[1] == 'O':
                s_src = np.nan
                s_tgt = np.nan
            else:
                chunk1 = chunk[1].split(' -> ')
                if len(chunk1) == 1:
                    s_src = chunk1[0]
                    s_tgt = np.nan
                else:
                    s_src = chunk1[0] if chunk1[0] != 'O' else np.nan
                    s_tgt = chunk1[1] if chunk1[1] != 'O' else np.nan
                
            chunk1 = chunk[0].split(' -> ')
            if len(chunk1) == 1:
                m_src = chunk1[0]
                m_tgt = np.nan
            else:
                m_src = chunk1[0]
                m_tgt = chunk1[1]
                
        return m_src, m_tgt, s_src, s_tgt
    
    key_mapping = {
        'Conn_Rel': 'CXNR',
        'Conn_Req': 'CXNS',
        'LTE_HO': 'LTEH',
        'MN_HO': 'MCGH',
        'MN_HO_to_eNB': 'SCGR-II',
        'SN_setup': 'SCGA',
        'SN_Rel': 'SCGR-I',
        'SN_HO': 'SCGM',
        'RLF_II': 'MCGF',
        'RLF_III': 'NASR',
        'SCG_RLF': 'SCGF',
        'Add_SCell': 'SCLA'
    }
    
    D = parse_mi_ho(df, tz)
    
    # rename as acronym
    new_D = {key_mapping.get(key, key): value for key, value in D.items()}
    
    if df.empty:
        selected_cols = ['PCI', 'Cell Identity', 'eNB_ID', 'next_eNB_ID', 'Band ID', 'next_BID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
        table = pd.DataFrame(columns=['type', 'start', 'end', 'others', 'm_src', 'm_tgt', 's_src', 's_tgt', 'category', 'inter-eNB', 'inter-Freq', 'band_cng', 'inter-RAT', '4G_5G', 'cause', 'near_before_RLF', *selected_cols])
        print('Empty RRC File!!!')
        return table, new_D
    
    table = pd.DataFrame()
    for key, lst in new_D.items():
        table1 = pd.DataFrame(lst, index=[key]*len(lst)).reset_index(names='type')
        table = pd.concat([table, table1], ignore_index=True)

    # add Cell Identity & eNB ID
    sc_info = df[df['type_id'] == 'LTE_RRC_Serv_Cell_Info'][['Timestamp', 'type_id', 'PCI', 'Cell Identity', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']].reset_index(drop=True).rename(columns={'Timestamp': 'start', 'type_id': 'type'})
    sc_info['eNB_ID'] = sc_info['Cell Identity'] // 256
    # sc_info['Cell_ID'] = sc_info['Cell Identity'] % 256
    sc_info = sc_info[['start', 'type', 'PCI', 'Cell Identity', 'eNB_ID', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']]

    table = pd.concat([table, sc_info], ignore_index=True).sort_values(by='start').reset_index(drop=True)

    is_not_start = True
    selected_cols = ['PCI', 'Cell Identity', 'eNB_ID', 'Band ID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
    for i, row in table.iterrows():
        if row['type'] == 'LTE_RRC_Serv_Cell_Info':
            is_not_start = False
            info_to_fill = row[selected_cols].to_list()
            continue
        if is_not_start:
            continue
        table.loc[i, selected_cols] = info_to_fill

    table = table[table['type'] != 'LTE_RRC_Serv_Cell_Info'].reset_index(drop=True)
    
    # parse source & target cells
    for i, row in table.iterrows():
        table.loc[i, ['m_src', 'm_tgt', 's_src', 's_tgt']] = parse_trans(row['trans'])
    
    # distinguish intra/inter-eNB HO
    table1 = table[np.in1d(table['type'], ['SCLA', 'SCGA', 'SCGR-I', 'SCGF'])]
    table = table[~np.in1d(table['type'], ['SCLA', 'SCGA', 'SCGR-I', 'SCGF'])].reset_index(drop=True)
    
    table['next_eNB'] = table['eNB_ID'].shift(-1)
    for i, row in table.iloc[:-1].iterrows():
        if row['eNB_ID'] != row['next_eNB'] and row['type'] not in ['CXNS', 'CXNR']:
            if row['others'] == '':
                table.at[i, 'others'] = 'Inter eNB HO.'
            else:
                table.at[i, 'others'] += ' Inter eNB HO.'
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # label SCG Addition near after SCG Failure
    table1 = table[~np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGR-II'])]
    table = table[np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGR-II'])].reset_index(drop=True)
    
    table['prev_cmt'] = table['others'].shift(1)
    for i, row in table.iloc[1:].iterrows():
        if row['type'] == 'SCGA':
            if 'Near after SN_Rel' in row['others'] and 'Caused by scg-failure' in row['prev_cmt']:
                table.at[i, 'others'] += ' Caused by scg-failure.'
    
    # combine closed SCG Addition & Release pair (which are not caused by scg-failure or RLF) into SCG Change
    table['next_end'] = table['end'].shift(-1)
    table['next_cmt'] = table['others'].shift(-1)
    table['next_s_tgt'] = table['s_tgt'].shift(-1)
    indices_to_remove = []
    for i, row in table.iloc[:-1].iterrows():
        if row['type'] == 'SCGR-I' and 'Near after SN_Rel' in row['next_cmt'] and row['s_src'] != row['next_s_tgt']:
            table.at[i, 'end'] = row['next_end']
            table.at[i, 's_tgt'] = row['next_s_tgt']
            table.at[i, 'type'] = 'SCGC-I'
            indices_to_remove.append(i+1)
        if row['type'] == 'SCGR-II' and 'Near after MN_HO_to_eNB' in row['next_cmt'] and row['s_src'] != row['next_s_tgt']:
            table.at[i, 'end'] = row['next_end']
            table.at[i, 's_tgt'] = row['next_s_tgt']
            table.at[i, 'type'] = 'SCGC-II'
            indices_to_remove.append(i+1)
    table = table.drop(indices_to_remove)
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # re-classify eNB HO & MeNB HO
    table.loc[np.in1d(table['type'], ['LTEH']) & table['others'].str.contains('Inter eNB HO'), 'type'] = 'ENBH'
    table.loc[np.in1d(table['type'], ['MCGH']) & table['others'].str.contains('Inter eNB HO'), 'type'] = 'MNBH'
    
    # add the next eNB ID when meeting inter-eNB HO
    table1 = table[~table['others'].str.contains('Inter eNB HO')]
    table = table[table['others'].str.contains('Inter eNB HO')].reset_index(drop=True)
    
    table['next_eNB_ID'] = table['eNB_ID'].shift(-1)
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # detect band change and add the next Band ID when meeting inter-Freq HO
    band_mapping = {}
    for i, row in table[~table.duplicated(subset=['DL frequency'])].dropna(subset=['DL frequency']).iterrows():
        band_mapping[int(row['DL frequency'])] = row['Band ID']
    
    print(band_mapping)
    
    table1 = table[~table['others'].str.contains('Inter frequency HO')]
    table = table[table['others'].str.contains('Inter frequency HO')].reset_index(drop=True)
    
    table['next_BID'] = table['Band ID'].shift(-1)
    try:
        table.at[len(table)-1, 'next_BID'] = band_mapping[ast.literal_eval(table.iloc[-1]['m_tgt'])[1]]
    except:
        pass
    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # check whether RLF is near after an HO event
    table1 = table[np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])]
    table = table[~np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])].reset_index(drop=True)
    
    table['next_start'] = table['start'].shift(-1)
    table['next_type'] = table['type'].shift(-1)
    table['near_before_RLF'] = False
    for i, row in table.iloc[:-1].iterrows():
        # check whether an HO event is near before an RLF (in 3 seconds)
        if row['type'] in ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGR-II', 'SCGC-I', 'SCGC-II'] and \
            row['next_type'] in ['NASR', 'MCGF', 'SCGF']:
                if row['end'] > row['next_start'] - pd.Timedelta(seconds=1):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 1 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 1 sec.'
                        
                elif row['end'] > row['next_start'] - pd.Timedelta(seconds=2):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 2 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 2 sec.'
                        
                elif row['end'] > row['next_start'] - pd.Timedelta(seconds=3):
                    table.at[i, 'near_before_RLF'] = True
                    next_type = row['next_type']
                    if row['others'] == '':
                        table.at[i, 'others'] = f'Near before {next_type} 3 sec.'
                    else:
                        table.at[i, 'others'] += f' Near before {next_type} 3 sec.'
                    
    table = pd.concat([table, table1], ignore_index=True).sort_values(by='start').reset_index(drop=True)
    
    # add category
    table['category'] = 'Others'
    table.loc[np.in1d(table['type'], ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II']), 'category'] = 'HO'
    table.loc[np.in1d(table['type'], ['MCGF', 'NASR', 'SCGF']), 'category'] = 'RLF'

    # add failure cause
    failure_cause = [
        'reconfigurationFailure (0)', 'handoverFailure (1)', 'otherFailure (2)',
        't310-Expiry (0)', 'randomAccessProblem (1)', 'rlc-MaxNumRetx (2)', 'synchReconfigFailureSCG (3)', 'scg-ReconfigFailure (4)', 'srb3-IntegrityFailure (5)', 'other-r16 (6)'
    ]
    
    for tag in failure_cause:
        table.loc[table['others'].str.contains(tag, regex=False), 'cause'] = tag
        table['others'] = table['others'].str.replace(f" {tag}.", "", regex=False)
        table['others'] = table['others'].str.replace(f"{tag}.", "", regex=False)
    
    # add Access Technology type
    table['4G_5G'] = '4G'
    table.loc[np.in1d(table['type'], ['SCGM', 'SCGA', 'SCGR-I', 'SCGC-I', 'SCGF']), '4G_5G'] = '5G'
    table.loc[np.in1d(table['type'], ['SCGR-II', 'SCGC-II']), '4G_5G'] = '4G_5G'
    
    # add more boolean columns
    table['inter-eNB'] = False
    table.loc[table['others'].str.contains('Inter eNB HO'), 'inter-eNB'] = True
    table['others'] = table['others'].str.replace(" Inter eNB HO.", "")
    table['others'] = table['others'].str.replace("Inter eNB HO.", "")
    
    table['inter-Freq'] = False
    table.loc[table['others'].str.contains('Inter frequency HO'), 'inter-Freq'] = True
    table['others'] = table['others'].str.replace(" Inter frequency HO.", "")
    table['others'] = table['others'].str.replace("Inter frequency HO.", "")
    
    table['band_cng'] = False
    table.loc[table['inter-Freq'] & (table['Band ID'] != table['next_BID']), 'band_cng'] = True
    
    table['inter-RAT'] = False
    table.loc[np.in1d(table['type'], ['SCGA', 'SCGR-I', 'SCGC-I', 'SCGR-II', 'SCGC-II']), 'inter-RAT'] = True
    
    table['inter-gNB'] = False
    table.loc[np.in1d(table['type'], ['SCGC-I', 'SCGC-II']), 'inter-gNB'] = True
    
    # ignore CXNS, CXNR, SCLA
    table = table[~np.in1d(table['type'], ['CXNS', 'CXNR', 'SCLA'])].reset_index(drop=True)
    
    # remove SCG Addition, Release caused by SCG Failure or any other RLFs if needed (default: True)
    if radical:
        table = table[~((table['others'].str.contains('Caused by scg-failure') | table['others'].str.contains('Near after RLF')))].reset_index(drop=True)
    
    # select columns
    selected_cols = ['PCI', 'Cell Identity', 'eNB_ID', 'next_eNB_ID', 'Band ID', 'next_BID', 'DL frequency', 'UL frequency', 'DL bandwidth', 'UL bandwidth', 'TAC', 'MCC', 'MNC']
    table = table[['type', 'start', 'end', 'others', 'm_src', 'm_tgt', 's_src', 's_tgt', 'category', 'inter-eNB', 'inter-Freq', 'band_cng', 'inter-gNB', 'inter-RAT', 'inter-gNB', '4G_5G', 'cause', 'near_before_RLF', *selected_cols]]
    
    return table, new_D

# %% [markdown]
# # Test Functions

# %%
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
import itertools as it
from tqdm.notebook import tqdm
from pprint import pprint

# Configure display options
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
# %config InlineBackend.figure_format = 'retina'

# Set plot style
# plt.style.use('ggplot')

# rrc_filename = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12_2/Bandlock_9_Schemes_Phone_UDP/sm06/#02/data/diag_log_sm06_2023-09-12_14-52-28_rrc.pkl"
rrc_filename = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12/Bandlock_UDP_9_Phone/sm00/#02/data/diag_log_sm00_2023-09-12_14-52-28_rrc.pkl"
# rrc_filename = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-06-12/Bandlock_8_Schemes_Phone/sm00/#03/data/diag_log_sm00_2023-06-12_16-51-11_rrc.pkl"
df = pd.read_pickle(rrc_filename)

# %%
table, D = mi_parse_handover(df)
# Out:
# {3050: 7.0, 1750: 3.0, 1400: 3.0}

# %%
D
# Out:
# {'CXNR': [HO(start=Timestamp('2023-09-12 14:23:04.085138'), end=None, others='', trans=''),
#   HO(start=Timestamp('2023-09-12 14:50:54.209027'), end=None, others='', trans='')],
#  'CXNS': [HO(start=Timestamp('2023-09-12 14:23:26.357728'), end=Timestamp('2023-09-12 14:23:26.516743'), others='', trans='? -> (434, 3050)'),
#   HO(start=Timestamp('2023-09-12 14:50:25.178025'), end=Timestamp('2023-09-12 14:50:25.288895'), others='', trans='? -> (357, 3050)'),
#   HO(start=Timestamp('2023-09-12 14:52:21.453346'), end=Timestamp('2023-09-12 14:52:21.698982'), others='', trans='? -> (357, 3050)'),
#   HO(start=Timestamp('2023-09-12 15:34:43.912141'), end=Timestamp('2023-09-12 15:34:44.004668'), others='', trans='? -> (186, 1400)')],
#  'LTEH': [HO(start=Timestamp('2023-09-12 14:54:04.906563'), end=Timestamp('2023-09-12 14:54:04.932975'), others=' Set up 3 SCell.', trans='(357, 3050) -> (349, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:54:25.995046'), end=Timestamp('2023-09-12 14:54:26.020014'), others=' Set up 3 SCell.', trans='(349, 3050) -> (65, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:55:00.839602'), end=Timestamp('2023-09-12 14:55:00.866520'), others=' Set up 3 SCell.', trans='(65, 3050) -> (302, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:55:02.236878'), end=Timestamp('2023-09-12 14:55:02.287779'), others=' Set up 3 SCell.', trans='(302, 3050) -> (294, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:56:14.560181'), end=Timestamp('2023-09-12 14:56:14.581827'), others=' Set up 3 SCell.', trans='(294, 3050) -> (308, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:56:15.757029'), end=Timestamp('2023-09-12 14:56:15.786629'), others=' Set up 3 SCell.', trans='(308, 3050) -> (277, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 14:56:21.630873'), end=Timestamp('2023-09-12 14:56:21.655687'), others=' Set up 3 SCell.', trans='(294, 1750) -> (277, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:56:25.309543'), end=Timestamp('2023-09-12 14:56:25.335715'), others=' Set up 3 SCell.', trans='(277, 1750) -> (346, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:56:29.724002'), end=Timestamp('2023-09-12 14:56:29.739614'), others=' Set up 3 SCell.', trans='(346, 1750) -> (261, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:57:28.684254'), end=Timestamp('2023-09-12 14:57:28.699192'), others=' Set up 3 SCell.', trans='(261, 1750) -> (245, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:57:35.378208'), end=Timestamp('2023-09-12 14:57:35.399238'), others=' Set up 3 SCell.', trans='(245, 1750) -> (346, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:57:54.042865'), end=Timestamp('2023-09-12 14:57:54.068812'), others=' Set up 3 SCell.', trans='(346, 1750) -> (354, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:58:13.637174'), end=Timestamp('2023-09-12 14:58:13.663907'), others=' Set up 3 SCell.', trans='(354, 1750) -> (426, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:58:19.065799'), end=Timestamp('2023-09-12 14:58:19.090426'), others=' Set up 3 SCell.', trans='(426, 1750) -> (328, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:59:14.916390'), end=Timestamp('2023-09-12 14:59:14.941879'), others=' Set up 3 SCell.', trans='(328, 1750) -> (92, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:59:18.320227'), end=Timestamp('2023-09-12 14:59:18.340224'), others=' Set up 1 SCell.', trans='(92, 1750) -> (126, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:59:33.187020'), end=Timestamp('2023-09-12 14:59:33.211615'), others=' Set up 3 SCell.', trans='(320, 1750) -> (348, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:59:54.410735'), end=Timestamp('2023-09-12 14:59:54.427865'), others=' Set up 3 SCell.', trans='(348, 1750) -> (489, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 14:59:57.484097'), end=Timestamp('2023-09-12 14:59:57.502926'), others=' Set up 3 SCell.', trans='(489, 1750) -> (348, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:07.265114'), end=Timestamp('2023-09-12 15:00:07.279595'), others=' Set up 3 SCell.', trans='(348, 1750) -> (118, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:10.629536'), end=Timestamp('2023-09-12 15:00:10.657187'), others=' Set up 2 SCell.', trans='(118, 1750) -> (399, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:19.574626'), end=Timestamp('2023-09-12 15:00:19.597007'), others=' Set up 2 SCell.', trans='(399, 1750) -> (322, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:23.008880'), end=Timestamp('2023-09-12 15:00:23.035189'), others=' Set up 2 SCell.', trans='(322, 1750) -> (399, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:25.598852'), end=Timestamp('2023-09-12 15:00:25.624186'), others=' Set up 3 SCell.', trans='(399, 1750) -> (33, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:35.178408'), end=Timestamp('2023-09-12 15:00:35.201989'), others=' Set up 2 SCell.', trans='(33, 1750) -> (399, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:36.887612'), end=Timestamp('2023-09-12 15:00:36.907595'), others=' Set up 2 SCell.', trans='(399, 1750) -> (183, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:38.006639'), end=Timestamp('2023-09-12 15:00:38.030850'), others=' Set up 2 SCell.', trans='(183, 1750) -> (322, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:44.841578'), end=Timestamp('2023-09-12 15:00:44.857538'), others=' Set up 2 SCell.', trans='(322, 1750) -> (330, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:51.875505'), end=Timestamp('2023-09-12 15:00:51.897169'), others=' Set up 3 SCell.', trans='(330, 1750) -> (118, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:00:57.658323'), end=Timestamp('2023-09-12 15:00:57.681868'), others=' Set up 2 SCell.', trans='(118, 1750) -> (399, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:01:00.633304'), end=Timestamp('2023-09-12 15:01:00.654639'), others=' Set up 2 SCell.', trans='(399, 1750) -> (134, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:01:03.065912'), end=Timestamp('2023-09-12 15:01:03.094577'), others=' Set up 2 SCell.', trans='(134, 1750) -> (407, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:01:47.921881'), end=Timestamp('2023-09-12 15:01:47.948988'), others=' Set up 3 SCell.', trans='(407, 1750) -> (168, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:01:57.851897'), end=Timestamp('2023-09-12 15:01:57.876521'), others=' Set up 3 SCell.', trans='(168, 1750) -> (319, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:02:13.040550'), end=Timestamp('2023-09-12 15:02:13.060520'), others=' Set up 1 SCell.', trans='(319, 1750) -> (81, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:02:31.355587'), end=Timestamp('2023-09-12 15:02:31.376473'), others=' Set up 3 SCell.', trans='(81, 1750) -> (357, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:02:36.279541'), end=Timestamp('2023-09-12 15:02:36.302853'), others='', trans='(357, 1750) -> (349, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:02:41.411557'), end=Timestamp('2023-09-12 15:02:41.433236'), others=' Set up 2 SCell.', trans='(349, 1750) -> (364, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:21.359017'), end=Timestamp('2023-09-12 15:03:21.382677'), others=' Set up 3 SCell.', trans='(364, 1750) -> (77, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:41.780504'), end=Timestamp('2023-09-12 15:03:41.801764'), others=' Set up 1 SCell.', trans='(77, 1750) -> (93, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:42.507852'), end=Timestamp('2023-09-12 15:03:42.528861'), others=' Set up 2 SCell.', trans='(93, 1750) -> (43, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:43.985101'), end=Timestamp('2023-09-12 15:03:44.010712'), others=' Set up 3 SCell.', trans='(43, 1750) -> (30, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:51.325018'), end=Timestamp('2023-09-12 15:03:51.345670'), others=' Set up 3 SCell.', trans='(30, 1750) -> (297, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:52.310113'), end=Timestamp('2023-09-12 15:03:52.355624'), others=' Set up 3 SCell.', trans='(297, 1750) -> (289, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:03:59.739554'), end=Timestamp('2023-09-12 15:03:59.754508'), others=' Set up 3 SCell.', trans='(289, 1750) -> (305, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:04:22.312711'), end=Timestamp('2023-09-12 15:04:22.334375'), others=' Set up 3 SCell.', trans='(305, 1750) -> (229, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:04:25.488396'), end=Timestamp('2023-09-12 15:04:25.510355'), others=' Set up 2 SCell.', trans='(229, 1750) -> (170, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:05:18.111818'), end=Timestamp('2023-09-12 15:05:18.128968'), others=' Set up 2 SCell.', trans='(170, 1750) -> (382, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:10:54.420779'), end=Timestamp('2023-09-12 15:10:54.442835'), others=' Set up 3 SCell.', trans='(169, 1750) -> (185, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:10:56.868978'), end=Timestamp('2023-09-12 15:10:56.890680'), others=' Set up 3 SCell.', trans='(185, 1750) -> (57, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:11:19.636543'), end=Timestamp('2023-09-12 15:11:19.658294'), others=' Set up 3 SCell.', trans='(57, 1750) -> (65, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:11:31.943210'), end=Timestamp('2023-09-12 15:11:31.965340'), others=' Set up 3 SCell.', trans='(65, 1750) -> (458, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:13:12.385456'), end=Timestamp('2023-09-12 15:13:12.407507'), others=' Set up 3 SCell.', trans='(458, 1750) -> (459, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:14:04.246872'), end=Timestamp('2023-09-12 15:14:04.261842'), others=' Set up 3 SCell.', trans='(459, 1750) -> (473, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:15:40.263031'), end=Timestamp('2023-09-12 15:15:40.278931'), others=' Set up 3 SCell.', trans='(473, 1750) -> (472, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:17:28.415049'), end=Timestamp('2023-09-12 15:17:28.430789'), others=' Set up 3 SCell.', trans='(472, 1750) -> (307, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:17:33.581867'), end=Timestamp('2023-09-12 15:17:33.602917'), others=' Set up 3 SCell.', trans='(307, 1750) -> (285, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:02.468774'), end=Timestamp('2023-09-12 15:18:02.490498'), others=' Set up 3 SCell.', trans='(285, 1750) -> (277, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:14.692526'), end=Timestamp('2023-09-12 15:18:14.707558'), others=' Set up 3 SCell.', trans='(277, 1750) -> (269, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:30.229361'), end=Timestamp('2023-09-12 15:18:30.244268'), others=' Set up 3 SCell.', trans='(269, 1750) -> (128, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:38.186419'), end=Timestamp('2023-09-12 15:18:38.208114'), others=' Set up 3 SCell.', trans='(128, 1750) -> (136, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:50.226323'), end=Timestamp('2023-09-12 15:18:50.247034'), others=' Set up 3 SCell.', trans='(136, 1750) -> (189, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:18:54.435691'), end=Timestamp('2023-09-12 15:18:54.459157'), others=' Set up 2 SCell.', trans='(189, 1750) -> (77, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:19:05.024259'), end=Timestamp('2023-09-12 15:19:05.048424'), others=' Set up 3 SCell.', trans='(77, 1750) -> (110, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:19:56.916682'), end=Timestamp('2023-09-12 15:19:56.941574'), others=' Set up 3 SCell.', trans='(110, 1750) -> (414, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:19:58.122749'), end=Timestamp('2023-09-12 15:19:58.143306'), others=' Set up 3 SCell.', trans='(414, 1750) -> (242, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:00.623418'), end=Timestamp('2023-09-12 15:20:00.638369'), others=' Set up 3 SCell.', trans='(242, 1750) -> (422, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:07.845464'), end=Timestamp('2023-09-12 15:20:07.861406'), others=' Set up 3 SCell.', trans='(422, 1750) -> (414, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:10.001576'), end=Timestamp('2023-09-12 15:20:10.016390'), others=' Set up 3 SCell.', trans='(414, 1750) -> (297, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:14.156597'), end=Timestamp('2023-09-12 15:20:14.171369'), others=' Set up 3 SCell.', trans='(297, 1750) -> (122, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:20.356702'), end=Timestamp('2023-09-12 15:20:20.372081'), others=' Set up 3 SCell.', trans='(122, 1750) -> (358, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:31.102128'), end=Timestamp('2023-09-12 15:20:31.116971'), others=' Set up 3 SCell.', trans='(358, 1750) -> (350, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:20:40.413145'), end=Timestamp('2023-09-12 15:20:40.427057'), others=' Set up 3 SCell.', trans='(350, 1750) -> (468, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:21:36.491630'), end=Timestamp('2023-09-12 15:21:36.508389'), others=' Set up 3 SCell.', trans='(468, 1750) -> (394, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:21:48.486517'), end=Timestamp('2023-09-12 15:21:48.502171'), others=' Set up 3 SCell.', trans='(394, 1750) -> (17, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:21:49.436549'), end=Timestamp('2023-09-12 15:21:49.452666'), others=' Set up 3 SCell.', trans='(17, 1750) -> (288, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:03.183388'), end=Timestamp('2023-09-12 15:22:03.205273'), others=' Set up 3 SCell.', trans='(288, 1750) -> (6, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:07.743254'), end=Timestamp('2023-09-12 15:22:07.770023'), others=' Set up 3 SCell.', trans='(6, 1750) -> (143, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:08.878162'), end=Timestamp('2023-09-12 15:22:08.902969'), others=' Set up 3 SCell.', trans='(143, 1750) -> (369, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:11.116287'), end=Timestamp('2023-09-12 15:22:11.142517'), others=' Set up 3 SCell.', trans='(369, 1750) -> (143, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:19.455235'), end=Timestamp('2023-09-12 15:22:19.470179'), others=' Set up 3 SCell.', trans='(143, 1750) -> (135, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:29.158110'), end=Timestamp('2023-09-12 15:22:29.182776'), others=' Set up 3 SCell.', trans='(135, 1750) -> (111, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:35.063120'), end=Timestamp('2023-09-12 15:22:35.092950'), others=' Set up 3 SCell.', trans='(135, 1750) -> (383, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:41.510699'), end=Timestamp('2023-09-12 15:22:41.536589'), others=' Set up 3 SCell.', trans='(383, 1750) -> (243, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:22:49.125672'), end=Timestamp('2023-09-12 15:22:49.150482'), others=' Set up 3 SCell.', trans='(243, 1750) -> (375, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:23:58.699226'), end=Timestamp('2023-09-12 15:23:58.721260'), others=' Set up 3 SCell.', trans='(375, 1750) -> (378, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:17.501891'), end=Timestamp('2023-09-12 15:24:17.525783'), others=' Set up 3 SCell.', trans='(378, 1750) -> (84, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:21.943088'), end=Timestamp('2023-09-12 15:24:21.969642'), others=' Set up 3 SCell.', trans='(84, 1750) -> (325, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:24.174089'), end=Timestamp('2023-09-12 15:24:24.200540'), others=' Set up 3 SCell.', trans='(325, 1750) -> (84, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:28.568826'), end=Timestamp('2023-09-12 15:24:28.591764'), others=' Set up 3 SCell.', trans='(84, 1750) -> (353, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:30.592657'), end=Timestamp('2023-09-12 15:24:30.612843'), others=' Set up 1 SCell.', trans='(353, 1750) -> (317, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:31.113964'), end=Timestamp('2023-09-12 15:24:31.134641'), others=' Set up 3 SCell.', trans='(317, 1750) -> (271, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:31.876712'), end=Timestamp('2023-09-12 15:24:31.897966'), others=' Set up 1 SCell.', trans='(271, 1750) -> (69, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:37.359613'), end=Timestamp('2023-09-12 15:24:37.381998'), others=' Set up 3 SCell.', trans='(69, 1750) -> (271, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:24:51.764559'), end=Timestamp('2023-09-12 15:24:51.790416'), others=' Set up 3 SCell.', trans='(271, 1750) -> (287, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:25:44.412064'), end=Timestamp('2023-09-12 15:25:44.436807'), others=' Set up 3 SCell.', trans='(287, 1750) -> (87, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:25:45.652045'), end=Timestamp('2023-09-12 15:25:45.671268'), others=' Set up 3 SCell.', trans='(87, 1750) -> (287, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:25:48.059244'), end=Timestamp('2023-09-12 15:25:48.078040'), others=' Set up 3 SCell.', trans='(287, 1750) -> (87, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:26:03.685111'), end=Timestamp('2023-09-12 15:26:03.706869'), others=' Set up 3 SCell.', trans='(87, 1750) -> (329, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:26:21.502927'), end=Timestamp('2023-09-12 15:26:21.525678'), others=' Set up 3 SCell.', trans='(329, 1750) -> (44, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:20.935444'), end=Timestamp('2023-09-12 15:27:20.957098'), others=' Set up 3 SCell.', trans='(44, 1750) -> (36, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:32.233234'), end=Timestamp('2023-09-12 15:27:32.254112'), others=' Set up 3 SCell.', trans='(36, 1750) -> (240, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:38.914045'), end=Timestamp('2023-09-12 15:27:38.940072'), others=' Set up 3 SCell.', trans='(240, 1750) -> (36, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:55.575741'), end=Timestamp('2023-09-12 15:27:55.603407'), others=' Set up 3 SCell.', trans='(36, 1750) -> (240, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:58.195065'), end=Timestamp('2023-09-12 15:27:58.209682'), others=' Set up 3 SCell.', trans='(240, 1750) -> (319, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:27:59.317962'), end=Timestamp('2023-09-12 15:27:59.338922'), others=' Set up 3 SCell.', trans='(319, 1750) -> (28, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:00.859040'), end=Timestamp('2023-09-12 15:28:00.873916'), others=' Set up 3 SCell.', trans='(28, 1750) -> (319, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:16.640704'), end=Timestamp('2023-09-12 15:28:16.662728'), others=' Set up 3 SCell.', trans='(319, 1750) -> (15, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:19.556814'), end=Timestamp('2023-09-12 15:28:19.578751'), others=' Set up 3 SCell.', trans='(15, 1750) -> (7, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:29.101590'), end=Timestamp('2023-09-12 15:28:29.127085'), others=' Set up 3 SCell.', trans='(7, 1750) -> (102, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:32.813043'), end=Timestamp('2023-09-12 15:28:32.832599'), others='', trans='(102, 1750) -> (118, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:43.739353'), end=Timestamp('2023-09-12 15:28:43.762882'), others=' Set up 3 SCell.', trans='(118, 1750) -> (331, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:28:57.797598'), end=Timestamp('2023-09-12 15:28:57.811367'), others=' Set up 3 SCell.', trans='(331, 1750) -> (315, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:29:02.440219'), end=Timestamp('2023-09-12 15:29:02.456333'), others=' Set up 3 SCell.', trans='(315, 1750) -> (331, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:29:04.977523'), end=Timestamp('2023-09-12 15:29:04.993152'), others=' Set up 3 SCell.', trans='(331, 1750) -> (315, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:30:06.647672'), end=Timestamp('2023-09-12 15:30:06.670578'), others=' Set up 3 SCell.', trans='(315, 1750) -> (140, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:30:20.142796'), end=Timestamp('2023-09-12 15:30:20.164407'), others=' Set up 3 SCell.', trans='(140, 1750) -> (67, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:30:49.028125'), end=Timestamp('2023-09-12 15:30:49.050283'), others=' Set up 3 SCell.', trans='(75, 1750) -> (360, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:31:32.138992'), end=Timestamp('2023-09-12 15:31:32.164413'), others=' Set up 3 SCell.', trans='(360, 1750) -> (376, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:31:46.356554'), end=Timestamp('2023-09-12 15:31:46.376671'), others=' Set up 1 SCell.', trans='(376, 1750) -> (117, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:31:49.710094'), end=Timestamp('2023-09-12 15:31:49.735182'), others=' Set up 3 SCell.', trans='(117, 1750) -> (382, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:32:41.232508'), end=Timestamp('2023-09-12 15:32:41.257897'), others=' Set up 3 SCell.', trans='(382, 1750) -> (392, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:32:52.565213'), end=Timestamp('2023-09-12 15:32:52.588009'), others=' Set up 3 SCell.', trans='(392, 1750) -> (43, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:33:07.279007'), end=Timestamp('2023-09-12 15:33:07.303762'), others=' Set up 3 SCell.', trans='(43, 1750) -> (27, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:34:03.375917'), end=Timestamp('2023-09-12 15:34:03.397927'), others=' Set up 1 SCell.', trans='(27, 1750) -> (152, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:34:18.249261'), end=Timestamp('2023-09-12 15:34:18.273845'), others=' Set up 3 SCell.', trans='(152, 1750) -> (27, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:34:41.243176'), end=Timestamp('2023-09-12 15:34:41.265177'), others=' Set up 3 SCell.', trans='(27, 1750) -> (266, 1750) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:21.328418'), end=Timestamp('2023-09-12 15:35:21.343853'), others=' Set up 3 SCell.', trans='(186, 1400) -> (178, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:23.046795'), end=Timestamp('2023-09-12 15:35:23.064534'), others=' Set up 3 SCell.', trans='(178, 1400) -> (186, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:24.470781'), end=Timestamp('2023-09-12 15:35:24.485633'), others=' Set up 3 SCell.', trans='(186, 1400) -> (394, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:47.448760'), end=Timestamp('2023-09-12 15:35:47.464357'), others=' Set up 3 SCell.', trans='(394, 1400) -> (21, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:59.017561'), end=Timestamp('2023-09-12 15:35:59.032152'), others=' Set up 3 SCell.', trans='(21, 1400) -> (394, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:35:59.788781'), end=Timestamp('2023-09-12 15:35:59.804272'), others=' Set up 3 SCell.', trans='(394, 1400) -> (21, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:36:02.311552'), end=Timestamp('2023-09-12 15:36:02.326427'), others=' Set up 3 SCell.', trans='(21, 1400) -> (122, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:36:23.526269'), end=Timestamp('2023-09-12 15:36:23.541256'), others=' Set up 3 SCell.', trans='(122, 1400) -> (130, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:36:35.676994'), end=Timestamp('2023-09-12 15:36:35.692978'), others=' Set up 3 SCell.', trans='(130, 1400) -> (19, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:36:36.535196'), end=Timestamp('2023-09-12 15:36:36.551338'), others=' Set up 3 SCell.', trans='(19, 1400) -> (130, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:36:42.236791'), end=Timestamp('2023-09-12 15:36:42.258991'), others=' Set up 3 SCell.', trans='(130, 1400) -> (11, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:37:07.630826'), end=Timestamp('2023-09-12 15:37:07.652732'), others=' Set up 3 SCell.', trans='(11, 1400) -> (188, 1400) | O'),
#   HO(start=Timestamp('2023-09-12 15:38:20.928037'), end=Timestamp('2023-09-12 15:38:20.956293'), others=' Set up 3 SCell. Inter frequency HO.', trans='(188, 1400) -> (188, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 15:38:28.726250'), end=Timestamp('2023-09-12 15:38:28.743978'), others=' Set up 3 SCell.', trans='(188, 3050) -> (180, 3050) | O'),
#   HO(start=Timestamp('2023-09-12 15:38:41.320900'), end=Timestamp('2023-09-12 15:38:41.350676'), others=' Set up 3 SCell.', trans='(180, 3050) -> (16, 3050) | O')],
#  'MCGH': [HO(start=Timestamp('2023-09-12 15:05:32.861724'), end=Timestamp('2023-09-12 15:05:32.877790'), others=' Set up 1 SCell.', trans='(382, 1750) -> (10, 1750) | 139'),
#   HO(start=Timestamp('2023-09-12 15:05:33.431366'), end=Timestamp('2023-09-12 15:05:33.465748'), others=' Set up 1 SCell.', trans='(10, 1750) -> (131, 1750) | 139'),
#   HO(start=Timestamp('2023-09-12 15:05:56.380588'), end=Timestamp('2023-09-12 15:05:56.396545'), others=' Set up 1 SCell.', trans='(301, 1750) -> (293, 1750) | 301'),
#   HO(start=Timestamp('2023-09-12 15:06:23.407615'), end=Timestamp('2023-09-12 15:06:23.423180'), others=' Set up 1 SCell.', trans='(309, 1750) -> (414, 1750) | 117'),
#   HO(start=Timestamp('2023-09-12 15:06:51.551438'), end=Timestamp('2023-09-12 15:06:51.566912'), others=' Set up 1 SCell.', trans='(414, 1750) -> (430, 1750) | 117'),
#   HO(start=Timestamp('2023-09-12 15:07:01.581559'), end=Timestamp('2023-09-12 15:07:01.597949'), others=' Set up 1 SCell.', trans='(430, 1750) -> (414, 1750) | 117'),
#   HO(start=Timestamp('2023-09-12 15:07:06.477902'), end=Timestamp('2023-09-12 15:07:06.493951'), others=' Set up 1 SCell.', trans='(414, 1750) -> (109, 1750) | 117'),
#   HO(start=Timestamp('2023-09-12 15:07:23.360855'), end=Timestamp('2023-09-12 15:07:23.376689'), others=' Set up 1 SCell.', trans='(337, 1750) -> (267, 1750) | 337'),
#   HO(start=Timestamp('2023-09-12 15:07:26.786454'), end=Timestamp('2023-09-12 15:07:26.817784'), others='', trans='(267, 1750) -> (6, 1750) | 267'),
#   HO(start=Timestamp('2023-09-12 15:07:34.790744'), end=Timestamp('2023-09-12 15:07:34.807724'), others=' Set up 1 SCell.', trans='(267, 1750) -> (36, 1750) | 297'),
#   HO(start=Timestamp('2023-09-12 15:08:38.979117'), end=Timestamp('2023-09-12 15:08:38.995088'), others=' Set up 1 SCell.', trans='(44, 1750) -> (202, 1750) | 44'),
#   HO(start=Timestamp('2023-09-12 15:09:06.335706'), end=Timestamp('2023-09-12 15:09:06.352778'), others=' Set up 1 SCell.', trans='(210, 1750) -> (127, 1750) | 210'),
#   HO(start=Timestamp('2023-09-12 15:09:06.824175'), end=Timestamp('2023-09-12 15:09:06.840651'), others=' Set up 1 SCell.', trans='(127, 1750) -> (135, 1750) | 210'),
#   HO(start=Timestamp('2023-09-12 15:09:15.949600'), end=Timestamp('2023-09-12 15:09:15.965610'), others=' Set up 1 SCell.', trans='(15, 1750) -> (23, 1750) | 23'),
#   HO(start=Timestamp('2023-09-12 15:09:23.797798'), end=Timestamp('2023-09-12 15:09:23.813399'), others=' Set up 1 SCell.', trans='(23, 1750) -> (7, 1750) | 7'),
#   HO(start=Timestamp('2023-09-12 15:09:24.767787'), end=Timestamp('2023-09-12 15:09:24.783370'), others=' Set up 1 SCell.', trans='(7, 1750) -> (338, 1750) | 7'),
#   HO(start=Timestamp('2023-09-12 15:09:29.844625'), end=Timestamp('2023-09-12 15:09:29.861538'), others=' Set up 1 SCell.', trans='(338, 1750) -> (419, 1750) | 419'),
#   HO(start=Timestamp('2023-09-12 15:09:31.878896'), end=Timestamp('2023-09-12 15:09:31.894393'), others=' Set up 1 SCell.', trans='(419, 1750) -> (169, 1750) | 419'),
#   HO(start=Timestamp('2023-09-12 15:09:36.877737'), end=Timestamp('2023-09-12 15:09:36.893315'), others=' Set up 1 SCell.', trans='(169, 1750) -> (419, 1750) | 419'),
#   HO(start=Timestamp('2023-09-12 15:09:55.420143'), end=Timestamp('2023-09-12 15:09:55.436383'), others=' Set up 1 SCell.', trans='(419, 1750) -> (169, 1750) | 115'),
#   HO(start=Timestamp('2023-09-12 15:39:02.800799'), end=Timestamp('2023-09-12 15:39:02.817680'), others=' Set up 1 SCell.', trans='(16, 3050) -> (73, 3050) | 73'),
#   HO(start=Timestamp('2023-09-12 15:39:53.336994'), end=Timestamp('2023-09-12 15:39:53.354137'), others=' Set up 1 SCell.', trans='(73, 3050) -> (362, 3050) | 370'),
#   HO(start=Timestamp('2023-09-12 15:39:53.737767'), end=Timestamp('2023-09-12 15:39:53.754159'), others=' Set up 1 SCell.', trans='(362, 3050) -> (73, 3050) | 370'),
#   HO(start=Timestamp('2023-09-12 15:39:55.983338'), end=Timestamp('2023-09-12 15:39:55.999093'), others=' Set up 1 SCell.', trans='(73, 3050) -> (362, 3050) | 370'),
#   HO(start=Timestamp('2023-09-12 15:40:41.320706'), end=Timestamp('2023-09-12 15:40:41.336635'), others=' Set up 1 SCell.', trans='(362, 3050) -> (378, 3050) | 350')],
#  'SCGR-II': [HO(start=Timestamp('2023-09-12 15:06:02.460611'), end=Timestamp('2023-09-12 15:06:02.496549'), others=' Set up 3 SCell.', trans='(293, 1750) -> (309, 1750) | 309 -> O'),
#   HO(start=Timestamp('2023-09-12 15:07:46.263259'), end=Timestamp('2023-09-12 15:07:46.297613'), others=' Set up 3 SCell.', trans='(36, 1750) -> (44, 1750) | 36 -> O'),
#   HO(start=Timestamp('2023-09-12 15:08:54.159044'), end=Timestamp('2023-09-12 15:08:54.193938'), others=' Set up 3 SCell.', trans='(202, 1750) -> (210, 1750) | 202 -> O')],
#  'SCGA': [HO(start=Timestamp('2023-09-12 14:23:28.933906'), end=Timestamp('2023-09-12 14:23:28.952567'), others=' Set up 3 SCell.', trans='(434, 3050) | O -> 434'),
#   HO(start=Timestamp('2023-09-12 14:23:31.651473'), end=Timestamp('2023-09-12 14:23:31.669312'), others=' Set up 3 SCell.', trans='(434, 3050) | O -> 434'),
#   HO(start=Timestamp('2023-09-12 14:23:34.533280'), end=Timestamp('2023-09-12 14:23:34.554373'), others=' Set up 3 SCell.', trans='(434, 3050) | O -> 434'),
#   HO(start=Timestamp('2023-09-12 14:50:25.482641'), end=Timestamp('2023-09-12 14:50:25.505173'), others=' Set up 1 SCell.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:26.133226'), end=Timestamp('2023-09-12 14:50:26.155135'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:27.437993'), end=Timestamp('2023-09-12 14:50:27.476581'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:28.398081'), end=Timestamp('2023-09-12 14:50:28.435343'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:29.718208'), end=Timestamp('2023-09-12 14:50:29.755482'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:30.370453'), end=Timestamp('2023-09-12 14:50:30.408374'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:31.058162'), end=Timestamp('2023-09-12 14:50:31.098378'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:32.937983'), end=Timestamp('2023-09-12 14:50:32.956854'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:33.578089'), end=Timestamp('2023-09-12 14:50:33.616422'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:34.237817'), end=Timestamp('2023-09-12 14:50:34.260040'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:34.905343'), end=Timestamp('2023-09-12 14:50:34.942543'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:35.563104'), end=Timestamp('2023-09-12 14:50:35.585011'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:50:36.798024'), end=Timestamp('2023-09-12 14:50:36.835416'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:22.327966'), end=Timestamp('2023-09-12 14:52:22.365525'), others=' Set up 1 SCell.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:22.979464'), end=Timestamp('2023-09-12 14:52:23.018766'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:23.623010'), end=Timestamp('2023-09-12 14:52:23.661547'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:24.957546'), end=Timestamp('2023-09-12 14:52:24.978087'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:25.606410'), end=Timestamp('2023-09-12 14:52:25.644493'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:26.517691'), end=Timestamp('2023-09-12 14:52:26.556736'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:27.160585'), end=Timestamp('2023-09-12 14:52:27.200597'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:53.517564'), end=Timestamp('2023-09-12 14:52:53.554354'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:54.317048'), end=Timestamp('2023-09-12 14:52:54.356511'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:54.977575'), end=Timestamp('2023-09-12 14:52:55.017631'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:55.897067'), end=Timestamp('2023-09-12 14:52:55.918958'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:56.538794'), end=Timestamp('2023-09-12 14:52:56.578341'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:57.200886'), end=Timestamp('2023-09-12 14:52:57.239310'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:57.842542'), end=Timestamp('2023-09-12 14:52:57.881450'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:58.490184'), end=Timestamp('2023-09-12 14:52:58.529370'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:59.166309'), end=Timestamp('2023-09-12 14:52:59.204279'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:52:59.825819'), end=Timestamp('2023-09-12 14:52:59.867140'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:00.482600'), end=Timestamp('2023-09-12 14:53:00.522534'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:01.137923'), end=Timestamp('2023-09-12 14:53:01.177504'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:01.778057'), end=Timestamp('2023-09-12 14:53:01.818254'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:02.425063'), end=Timestamp('2023-09-12 14:53:02.463189'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:03.436865'), end=Timestamp('2023-09-12 14:53:03.476459'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:04.083993'), end=Timestamp('2023-09-12 14:53:04.105689'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:04.729209'), end=Timestamp('2023-09-12 14:53:04.767159'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:05.623384'), end=Timestamp('2023-09-12 14:53:05.663240'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:06.265715'), end=Timestamp('2023-09-12 14:53:06.306617'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:06.945824'), end=Timestamp('2023-09-12 14:53:06.983264'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:07.619343'), end=Timestamp('2023-09-12 14:53:07.659299'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:08.265018'), end=Timestamp('2023-09-12 14:53:08.303301'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:08.917684'), end=Timestamp('2023-09-12 14:53:08.957520'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:09.826331'), end=Timestamp('2023-09-12 14:53:09.868433'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:10.476846'), end=Timestamp('2023-09-12 14:53:10.516344'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:11.121778'), end=Timestamp('2023-09-12 14:53:11.159195'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:12.461835'), end=Timestamp('2023-09-12 14:53:12.481708'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:13.108776'), end=Timestamp('2023-09-12 14:53:13.150348'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:13.763191'), end=Timestamp('2023-09-12 14:53:13.803216'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:14.436975'), end=Timestamp('2023-09-12 14:53:14.477523'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:15.077888'), end=Timestamp('2023-09-12 14:53:15.116449'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:15.728967'), end=Timestamp('2023-09-12 14:53:15.768306'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:16.645357'), end=Timestamp('2023-09-12 14:53:16.685417'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:17.277094'), end=Timestamp('2023-09-12 14:53:17.314242'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:17.927885'), end=Timestamp('2023-09-12 14:53:17.967128'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:18.597751'), end=Timestamp('2023-09-12 14:53:18.637118'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:19.922903'), end=Timestamp('2023-09-12 14:53:19.942783'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:20.577975'), end=Timestamp('2023-09-12 14:53:20.618325'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:21.225707'), end=Timestamp('2023-09-12 14:53:21.263011'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:21.885056'), end=Timestamp('2023-09-12 14:53:21.922993'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:22.517670'), end=Timestamp('2023-09-12 14:53:22.555889'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:23.157746'), end=Timestamp('2023-09-12 14:53:23.196254'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:23.797822'), end=Timestamp('2023-09-12 14:53:23.836269'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:24.437901'), end=Timestamp('2023-09-12 14:53:24.475931'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:25.078965'), end=Timestamp('2023-09-12 14:53:25.116825'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:25.725862'), end=Timestamp('2023-09-12 14:53:25.765261'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:26.377174'), end=Timestamp('2023-09-12 14:53:26.399456'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:27.018925'), end=Timestamp('2023-09-12 14:53:27.058084'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:27.673924'), end=Timestamp('2023-09-12 14:53:27.711911'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:28.317800'), end=Timestamp('2023-09-12 14:53:28.355898'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:28.968845'), end=Timestamp('2023-09-12 14:53:29.008065'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:29.636988'), end=Timestamp('2023-09-12 14:53:29.676311'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:30.583969'), end=Timestamp('2023-09-12 14:53:30.626996'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:31.357004'), end=Timestamp('2023-09-12 14:53:31.396261'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:32.005231'), end=Timestamp('2023-09-12 14:53:32.044062'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:32.665037'), end=Timestamp('2023-09-12 14:53:32.705184'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:33.545744'), end=Timestamp('2023-09-12 14:53:33.587111'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:34.178851'), end=Timestamp('2023-09-12 14:53:34.217036'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:34.837063'), end=Timestamp('2023-09-12 14:53:34.875924'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:35.745069'), end=Timestamp('2023-09-12 14:53:35.786859'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:36.405653'), end=Timestamp('2023-09-12 14:53:36.444074'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:37.041744'), end=Timestamp('2023-09-12 14:53:37.079112'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:38.836736'), end=Timestamp('2023-09-12 14:53:38.857638'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:39.865271'), end=Timestamp('2023-09-12 14:53:39.906914'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:40.537006'), end=Timestamp('2023-09-12 14:53:40.575869'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:41.177059'), end=Timestamp('2023-09-12 14:53:41.215832'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:42.078117'), end=Timestamp('2023-09-12 14:53:42.120013'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:42.725113'), end=Timestamp('2023-09-12 14:53:42.763076'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:43.378111'), end=Timestamp('2023-09-12 14:53:43.400446'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:45.116751'), end=Timestamp('2023-09-12 14:53:45.137579'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:45.758430'), end=Timestamp('2023-09-12 14:53:45.798043'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:46.406835'), end=Timestamp('2023-09-12 14:53:46.447021'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:47.305470'), end=Timestamp('2023-09-12 14:53:47.345846'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:48.216784'), end=Timestamp('2023-09-12 14:53:48.256947'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:48.963999'), end=Timestamp('2023-09-12 14:53:49.002981'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:49.605418'), end=Timestamp('2023-09-12 14:53:49.645772'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:50.265656'), end=Timestamp('2023-09-12 14:53:50.305895'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:51.005146'), end=Timestamp('2023-09-12 14:53:51.044009'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:51.688030'), end=Timestamp('2023-09-12 14:53:51.726857'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:52.357725'), end=Timestamp('2023-09-12 14:53:52.397976'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:53.165189'), end=Timestamp('2023-09-12 14:53:53.205765'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:53.944325'), end=Timestamp('2023-09-12 14:53:53.988028'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:54.597725'), end=Timestamp('2023-09-12 14:53:54.636897'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:55.259587'), end=Timestamp('2023-09-12 14:53:55.282186'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:55.904596'), end=Timestamp('2023-09-12 14:53:55.942843'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
#   HO(start=Timestamp('2023-09-12 14:53:56.578027'), end=Timestamp('2023-09-12 14:53:56.616839'), others=' Set up 1 SCell. Near after SN_Rel.', trans='(357, 3050) | O -> 357'),
# ...
#   HO(start=Timestamp('2023-09-12 15:27:32.233234'), end=Timestamp('2023-09-12 15:27:32.254112'), others=' Set up 3 SCell. With LTE_HO.', trans='[(36, 3050), (36, 3400), (36, 1400)] -> [(240, 3050), (240, 1400), (240, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:27:38.914045'), end=Timestamp('2023-09-12 15:27:38.940072'), others=' Set up 3 SCell. With LTE_HO.', trans='[(240, 3050), (240, 1400), (240, 3400)] -> [(36, 3050), (36, 3650), (36, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:27:55.575741'), end=Timestamp('2023-09-12 15:27:55.603407'), others=' Set up 3 SCell. With LTE_HO.', trans='[(36, 3050), (36, 3650), (36, 3400)] -> [(240, 3050), (240, 3400), (240, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:27:58.195065'), end=Timestamp('2023-09-12 15:27:58.209682'), others=' Set up 3 SCell. With LTE_HO.', trans='[(240, 3050), (240, 3400), (240, 1400)] -> [(319, 3050), (319, 3400), (319, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:27:59.317962'), end=Timestamp('2023-09-12 15:27:59.338922'), others=' Set up 3 SCell. With LTE_HO.', trans='[(319, 3050), (319, 3400), (319, 1400)] -> [(28, 3050), (28, 1400), (28, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:28:00.859040'), end=Timestamp('2023-09-12 15:28:00.873916'), others=' Set up 3 SCell. With LTE_HO.', trans='[(28, 3050), (28, 1400), (28, 3400)] -> [(319, 3050), (319, 1400), (319, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:28:16.640704'), end=Timestamp('2023-09-12 15:28:16.662728'), others=' Set up 3 SCell. With LTE_HO.', trans='[(319, 3050), (319, 1400), (319, 3400)] -> [(15, 3050), (15, 3400), (15, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:28:19.556814'), end=Timestamp('2023-09-12 15:28:19.578751'), others=' Set up 3 SCell. With LTE_HO.', trans='[(15, 3050), (15, 3400), (15, 1400)] -> [(7, 3050), (7, 3750), (7, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:28:29.101590'), end=Timestamp('2023-09-12 15:28:29.127085'), others=' Set up 3 SCell. With LTE_HO.', trans='[(7, 3050), (7, 3750), (7, 1400)] -> [(102, 3050), (102, 3400), (102, 3650)]'),
#   HO(start=Timestamp('2023-09-12 15:28:43.739353'), end=Timestamp('2023-09-12 15:28:43.762882'), others=' Set up 3 SCell. With LTE_HO.', trans='[] -> [(331, 3050), (331, 3750), (331, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:28:57.797598'), end=Timestamp('2023-09-12 15:28:57.811367'), others=' Set up 3 SCell. With LTE_HO.', trans='[(331, 3050), (331, 3750), (331, 1400)] -> [(315, 3050), (315, 3750), (315, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:29:02.440219'), end=Timestamp('2023-09-12 15:29:02.456333'), others=' Set up 3 SCell. With LTE_HO.', trans='[(315, 3050), (315, 3750), (315, 1400)] -> [(331, 3050), (331, 3650), (331, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:29:04.977523'), end=Timestamp('2023-09-12 15:29:04.993152'), others=' Set up 3 SCell. With LTE_HO.', trans='[(331, 3050), (331, 3650), (331, 1400)] -> [(315, 3050), (315, 3750), (315, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:30:06.647672'), end=Timestamp('2023-09-12 15:30:06.670578'), others=' Set up 3 SCell. With LTE_HO.', trans='[(315, 3050), (315, 3750), (315, 1400)] -> [(140, 3050), (140, 3400), (140, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:30:20.142796'), end=Timestamp('2023-09-12 15:30:20.164407'), others=' Set up 3 SCell. With LTE_HO.', trans='[(140, 3050), (140, 3400), (140, 1400)] -> [(67, 3050), (67, 1400), (67, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:30:31.904056'), end=Timestamp('2023-09-12 15:30:31.919326'), others=' Set up 3 SCell. Near after RLF.', trans='[] -> [(75, 3050), (75, 3400), (75, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:30:49.028125'), end=Timestamp('2023-09-12 15:30:49.050283'), others=' Set up 3 SCell. With LTE_HO.', trans='[(75, 3050), (75, 3400), (75, 1400)] -> [(360, 3050), (360, 1400), (360, 525)]'),
#   HO(start=Timestamp('2023-09-12 15:31:32.138992'), end=Timestamp('2023-09-12 15:31:32.164413'), others=' Set up 3 SCell. With LTE_HO.', trans='[(360, 3050), (360, 1400), (360, 525)] -> [(376, 3050), (376, 525), (376, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:31:46.356554'), end=Timestamp('2023-09-12 15:31:46.376671'), others=' Set up 1 SCell. With LTE_HO.', trans='[(376, 3050), (376, 525), (376, 3400)] -> [(117, 3650)]'),
#   HO(start=Timestamp('2023-09-12 15:31:49.710094'), end=Timestamp('2023-09-12 15:31:49.735182'), others=' Set up 3 SCell. With LTE_HO.', trans='[(117, 3650)] -> [(382, 3050), (382, 3400), (382, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:32:41.232508'), end=Timestamp('2023-09-12 15:32:41.257897'), others=' Set up 3 SCell. With LTE_HO.', trans='[(382, 3050), (382, 3400), (382, 1400)] -> [(392, 3050), (392, 3400), (392, 3750)]'),
#   HO(start=Timestamp('2023-09-12 15:32:52.565213'), end=Timestamp('2023-09-12 15:32:52.588009'), others=' Set up 3 SCell. With LTE_HO.', trans='[(392, 3050), (392, 3400), (392, 3750)] -> [(43, 3050), (43, 525), (43, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:33:07.279007'), end=Timestamp('2023-09-12 15:33:07.303762'), others=' Set up 3 SCell. With LTE_HO.', trans='[(43, 3050), (43, 525), (43, 3400)] -> [(27, 3050), (27, 3400), (27, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:34:03.375917'), end=Timestamp('2023-09-12 15:34:03.397927'), others=' Set up 1 SCell. With LTE_HO.', trans='[(27, 3050), (27, 3400), (27, 1400)] -> [(152, 3750)]'),
#   HO(start=Timestamp('2023-09-12 15:34:18.249261'), end=Timestamp('2023-09-12 15:34:18.273845'), others=' Set up 3 SCell. With LTE_HO.', trans='[(152, 3750)] -> [(27, 3050), (27, 3400), (27, 1400)]'),
#   HO(start=Timestamp('2023-09-12 15:34:41.243176'), end=Timestamp('2023-09-12 15:34:41.265177'), others=' Set up 3 SCell. With LTE_HO.', trans='[(27, 3050), (27, 3400), (27, 1400)] -> [(266, 3050), (266, 1400), (266, 525)]'),
#   HO(start=Timestamp('2023-09-12 15:34:44.022724'), end=Timestamp('2023-09-12 15:34:44.035772'), others=' Set up 3 SCell. Near after RLF.', trans='[] -> [(186, 3050), (186, 1750), (186, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:21.328418'), end=Timestamp('2023-09-12 15:35:21.343853'), others=' Set up 3 SCell. With LTE_HO.', trans='[(186, 3050), (186, 1750), (186, 3400)] -> [(178, 3050), (178, 1750), (178, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:23.046795'), end=Timestamp('2023-09-12 15:35:23.064534'), others=' Set up 3 SCell. With LTE_HO.', trans='[(178, 3050), (178, 1750), (178, 3400)] -> [(186, 3050), (186, 1750), (186, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:24.470781'), end=Timestamp('2023-09-12 15:35:24.485633'), others=' Set up 3 SCell. With LTE_HO.', trans='[(186, 3050), (186, 1750), (186, 3400)] -> [(394, 3050), (394, 1750), (394, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:47.448760'), end=Timestamp('2023-09-12 15:35:47.464357'), others=' Set up 3 SCell. With LTE_HO.', trans='[(394, 3050), (394, 1750), (394, 3400)] -> [(21, 3050), (21, 1750), (21, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:59.017561'), end=Timestamp('2023-09-12 15:35:59.032152'), others=' Set up 3 SCell. With LTE_HO.', trans='[(21, 3050), (21, 1750), (21, 3400)] -> [(394, 3050), (394, 1750), (394, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:35:59.788781'), end=Timestamp('2023-09-12 15:35:59.804272'), others=' Set up 3 SCell. With LTE_HO.', trans='[(394, 3050), (394, 1750), (394, 3400)] -> [(21, 3050), (21, 1750), (21, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:36:02.311552'), end=Timestamp('2023-09-12 15:36:02.326427'), others=' Set up 3 SCell. With LTE_HO.', trans='[(21, 3050), (21, 1750), (21, 3400)] -> [(122, 3050), (122, 1750), (122, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:36:23.526269'), end=Timestamp('2023-09-12 15:36:23.541256'), others=' Set up 3 SCell. With LTE_HO.', trans='[(122, 3050), (122, 1750), (122, 3400)] -> [(130, 3050), (130, 1750), (130, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:36:35.676994'), end=Timestamp('2023-09-12 15:36:35.692978'), others=' Set up 3 SCell. With LTE_HO.', trans='[(130, 3050), (130, 1750), (130, 3400)] -> [(19, 3050), (19, 1750), (19, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:36:36.535196'), end=Timestamp('2023-09-12 15:36:36.551338'), others=' Set up 3 SCell. With LTE_HO.', trans='[(19, 3050), (19, 1750), (19, 3400)] -> [(130, 3050), (130, 1750), (130, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:36:42.236791'), end=Timestamp('2023-09-12 15:36:42.258991'), others=' Set up 3 SCell. With LTE_HO.', trans='[(130, 3050), (130, 1750), (130, 3400)] -> [(11, 3050), (11, 1750), (11, 3750)]'),
#   HO(start=Timestamp('2023-09-12 15:37:07.630826'), end=Timestamp('2023-09-12 15:37:07.652732'), others=' Set up 3 SCell. With LTE_HO.', trans='[(11, 3050), (11, 1750), (11, 3750)] -> [(188, 3050), (188, 1750), (188, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:20.928037'), end=Timestamp('2023-09-12 15:38:20.956293'), others=' Set up 3 SCell. With LTE_HO.', trans='[(188, 3050), (188, 1750), (188, 3400)] -> [(188, 1750), (188, 1400), (188, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:21.086959'), end=Timestamp('2023-09-12 15:38:21.107150'), others=' Set up 1 SCell. With SN_setup.', trans='[(188, 1750), (188, 1400), (188, 3400)] -> [(188, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:21.394397'), end=Timestamp('2023-09-12 15:38:21.426623'), others=' Set up 3 SCell. With SN_Rel.', trans='[(188, 1750)] -> [(188, 1750), (188, 1400), (188, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:24.411583'), end=Timestamp('2023-09-12 15:38:24.432172'), others=' Set up 3 SCell. With SN_setup.', trans='[(188, 1750), (188, 1400), (188, 3400)] -> [(188, 1750), (188, 1400), (188, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:24.752742'), end=Timestamp('2023-09-12 15:38:24.776400'), others=' Set up 3 SCell. With SN_Rel.', trans='[(188, 1750), (188, 1400), (188, 3400)] -> [(188, 1750), (188, 1400), (188, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:28.726250'), end=Timestamp('2023-09-12 15:38:28.743978'), others=' Set up 3 SCell. With LTE_HO.', trans='[(188, 1750), (188, 1400), (188, 3400)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:31.431871'), end=Timestamp('2023-09-12 15:38:31.450343'), others=' Set up 3 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:31.774484'), end=Timestamp('2023-09-12 15:38:31.797047'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:33.171391'), end=Timestamp('2023-09-12 15:38:33.192006'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:33.471590'), end=Timestamp('2023-09-12 15:38:33.506457'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:33.812635'), end=Timestamp('2023-09-12 15:38:33.834112'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:34.122546'), end=Timestamp('2023-09-12 15:38:34.147966'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:34.465425'), end=Timestamp('2023-09-12 15:38:34.505066'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:34.775458'), end=Timestamp('2023-09-12 15:38:34.811449'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:35.360511'), end=Timestamp('2023-09-12 15:38:35.400870'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:35.672645'), end=Timestamp('2023-09-12 15:38:35.708233'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:36.012954'), end=Timestamp('2023-09-12 15:38:36.054036'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:36.322688'), end=Timestamp('2023-09-12 15:38:36.353759'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:36.675532'), end=Timestamp('2023-09-12 15:38:36.716844'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:36.974662'), end=Timestamp('2023-09-12 15:38:37.009298'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:37.571661'), end=Timestamp('2023-09-12 15:38:37.611869'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:37.872568'), end=Timestamp('2023-09-12 15:38:37.907184'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:38.225432'), end=Timestamp('2023-09-12 15:38:38.265014'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:38.536510'), end=Timestamp('2023-09-12 15:38:38.571404'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:38.885236'), end=Timestamp('2023-09-12 15:38:38.926865'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:39.186498'), end=Timestamp('2023-09-12 15:38:39.225336'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:39.940047'), end=Timestamp('2023-09-12 15:38:39.981825'), others=' Set up 1 SCell. With SN_setup.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(180, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:38:40.248778'), end=Timestamp('2023-09-12 15:38:40.277894'), others=' Set up 3 SCell. With SN_Rel.', trans='[(180, 1750)] -> [(180, 1750), (180, 1400), (180, 3400)]'),
#   HO(start=Timestamp('2023-09-12 15:38:41.320900'), end=Timestamp('2023-09-12 15:38:41.350676'), others=' Set up 3 SCell. With LTE_HO.', trans='[(180, 1750), (180, 1400), (180, 3400)] -> [(16, 1750), (16, 3400), (16, 3650)]'),
#   HO(start=Timestamp('2023-09-12 15:38:42.231521'), end=Timestamp('2023-09-12 15:38:42.273051'), others=' Set up 1 SCell. With SN_setup.', trans='[(16, 1750), (16, 3400), (16, 3650)] -> [(16, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:39:02.800799'), end=Timestamp('2023-09-12 15:39:02.817680'), others=' Set up 1 SCell. With MN_HO.', trans='[(16, 1750)] -> [(73, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:39:53.336994'), end=Timestamp('2023-09-12 15:39:53.354137'), others=' Set up 1 SCell. With MN_HO.', trans='[(73, 1750)] -> [(362, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:39:53.737767'), end=Timestamp('2023-09-12 15:39:53.754159'), others=' Set up 1 SCell. With MN_HO.', trans='[(362, 1750)] -> [(73, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:39:55.983338'), end=Timestamp('2023-09-12 15:39:55.999093'), others=' Set up 1 SCell. With MN_HO.', trans='[(73, 1750)] -> [(362, 1750)]'),
#   HO(start=Timestamp('2023-09-12 15:40:41.320706'), end=Timestamp('2023-09-12 15:40:41.336635'), others=' Set up 1 SCell. With MN_HO.', trans='[(362, 1750)] -> [(378, 1750)]')]}

# %%
evt_types = [
    'LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGR-II', 'SCGC-I', 'SCGC-II', # HO
    'MCGF', 'NASR', 'SCGF', # RLF
    'CXNS', 'CXNR', 'SCLA', # Others
]

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    # for evt in evt_types:
    #     print(evt)
    #     display(table[np.in1d(table['type'], [evt])])
    
    # display(table[table['inter-eNB']])
    # display(table[table['inter-Freq']])
    # display(table[table['band_cng']])
    # display(table[table['near_before_RLF']])
    # display(table[(table['others'].str.contains('Caused by scg-failure') | table['others'].str.contains('Near after RLF'))])
    
    # display(table[np.in1d(table['type'], ['MCGF', 'NASR', 'SCGF'])])
    display(table[np.in1d(table['type'], ['MCGF', 'NASR'])])
    # display(table[~np.in1d(table['type'], ['MCGF', 'NASR', 'SCGF'])])
    
    # display(table.iloc[234:-1])
    # display(table)
    pass
# Out:
#      type                      start                        end others  \
# 154  MCGF 2023-09-12 14:56:19.230895 2023-09-12 14:56:19.311847
# 215  MCGF 2023-09-12 14:59:20.829332 2023-09-12 14:59:20.911450
# 318  MCGF 2023-09-12 15:05:54.126790 2023-09-12 15:05:54.202840
# 329  MCGF 2023-09-12 15:07:11.485930 2023-09-12 15:07:11.561943
# 330  MCGF 2023-09-12 15:07:14.345163 2023-09-12 15:07:14.422955
# 336  MCGF 2023-09-12 15:07:30.015089 2023-09-12 15:07:30.146800
# 350  MCGF 2023-09-12 15:09:14.849048 2023-09-12 15:09:14.901390
# 399  MCGF 2023-09-12 15:22:33.326321 2023-09-12 15:22:33.407010
# 435  MCGF 2023-09-12 15:30:31.792731 2023-09-12 15:30:31.873420
# 446  NASR 2023-09-12 15:34:43.770315 2023-09-12 15:34:43.993140
#
#            m_src        m_tgt s_src s_tgt category  inter-eNB  inter-Freq  \
# 154  (277, 3050)  (294, 1750)   NaN   NaN      RLF       True       False
# 215  (126, 1750)  (320, 1750)   NaN   NaN      RLF       True       False
# 318  (131, 1750)  (301, 1750)   293   NaN      RLF       True       False
# 329  (109, 1750)  (234, 1750)   117   NaN      RLF       True       False
# 330  (234, 1750)  (337, 1750)   337   NaN      RLF       True       False
# 336    (6, 1750)  (267, 1750)   267   NaN      RLF       True       False
# 350  (135, 1750)   (15, 1750)    23   NaN      RLF       True       False
# 399  (111, 1750)  (135, 1750)   NaN   NaN      RLF       True       False
# 435   (67, 1750)   (75, 1750)   NaN   NaN      RLF      False       False
# 446  (266, 1750)  (186, 1400)   NaN   NaN      RLF       True       False
#
#      band_cng  inter-gNB  inter-RAT  inter-gNB 4G_5G             cause  \
# 154     False      False      False      False    4G  otherFailure (2)
# 215     False      False      False      False    4G  otherFailure (2)
# 318     False      False      False      False    4G  otherFailure (2)
# 329     False      False      False      False    4G  otherFailure (2)
# 330     False      False      False      False    4G  otherFailure (2)
# 336     False      False      False      False    4G  otherFailure (2)
# 350     False      False      False      False    4G  otherFailure (2)
# 399     False      False      False      False    4G  otherFailure (2)
# 435     False      False      False      False    4G  otherFailure (2)
# 446     False      False      False      False    4G  otherFailure (2)
#
#     near_before_RLF    PCI  Cell Identity    eNB_ID  next_eNB_ID  Band ID  \
# 154           False  277.0     29244450.0  114236.0     214880.0      7.0
# 215           False  126.0     57267293.0  223700.0     213543.0      3.0
# 318           False  131.0     54081825.0  211257.0     212790.0      3.0
# 329           False  109.0     54548759.0  213081.0     212525.0      3.0
# 330           False  234.0     54406433.0  212525.0     212788.0      3.0
# 336           False    6.0     57268011.0  223703.0     212104.0      3.0
# 350           False  135.0     54713367.0  213724.0     216859.0      3.0
# 399           False  111.0     54901261.0  214458.0     213396.0      3.0
# 435           False   67.0     55619597.0  217264.0          NaN      3.0
# 446           False  266.0     54472471.0  212783.0     213133.0      3.0
#
#      next_BID  DL frequency  UL frequency DL bandwidth UL bandwidth      TAC  \
# 154       NaN        3050.0       21050.0       20 MHz       20 MHz  11800.0
# 215       NaN        1750.0       19750.0       20 MHz       20 MHz  11800.0
# 318       NaN        1750.0       19750.0       20 MHz       20 MHz  11800.0
# 329       NaN        1750.0       19750.0       20 MHz       20 MHz  11801.0
# 330       NaN        1750.0       19750.0       20 MHz       20 MHz  11801.0
# 336       NaN        1750.0       19750.0       20 MHz       20 MHz  11801.0
# 350       NaN        1750.0       19750.0       20 MHz       20 MHz  11801.0
# 399       NaN        1750.0       19750.0       20 MHz       20 MHz  11400.0
# 435       NaN        1750.0       19750.0       20 MHz       20 MHz  11200.0
# 446       NaN        1750.0       19750.0       20 MHz       20 MHz  11200.0
#
#        MCC   MNC
# 154  466.0  92.0
# 215  466.0  92.0
# 318  466.0  92.0
# 329  466.0  92.0
# 330  466.0  92.0
# 336  466.0  92.0
# 350  466.0  92.0
# 399  466.0  92.0
# 435  466.0  92.0
# 446  466.0  92.0

# %% [markdown]
# # Parse Transition

# %%
print('Add_SCell', '[] -> [(362, 1750), (362, 3400), (362, 1400)]'.split(' | '))
print('Add_SCell', '[(81, 1400)] -> [(319, 3050), (319, 1400), (319, 3400)]'.split(' | '))
print('Conn_REL', ''.split(' | '))
print('Conn_SU', '? -> (362, 3050)'.split(' | '))
print('LTE_HO', '(294, 1750) -> (73, 1750) | O'.split(' | '))
print('MN_HO', '(277, 1750) -> (308, 1750) | 346'.split(' | '))
print('MN_HO_SN_REL', '(346, 1750) -> (245, 1750) | 245 -> O'.split(' | '))
print('SN_SU', '(362, 3050) | O -> 362'.split(' | '))
print('SN_REL', '(44, 1750) | 44 -> O'.split(' | '))
print('SN_HO', '(277, 1750) | 277 -> 346'.split(' | '))
print('SCG_FAIL', '(188, 1750) | 188 -> O'.split(' | '))
print('MCG_FAIL', '(261, 1750) -> (346, 1750) | 346 -> O'.split(' | '))
print('MCG_FAIL', '(109, 1750) -> (414, 1750) | O -> O'.split(' | '))
print('NAS_REC')
# Out:
# Add_SCell ['[] -> [(362, 1750), (362, 3400), (362, 1400)]']
# Add_SCell ['[(81, 1400)] -> [(319, 3050), (319, 1400), (319, 3400)]']
# Conn_REL ['']
# Conn_SU ['? -> (362, 3050)']
# LTE_HO ['(294, 1750) -> (73, 1750)', 'O']
# MN_HO ['(277, 1750) -> (308, 1750)', '346']
# MN_HO_SN_REL ['(346, 1750) -> (245, 1750)', '245 -> O']
# SN_SU ['(362, 3050)', 'O -> 362']
# SN_REL ['(44, 1750)', '44 -> O']
# SN_HO ['(277, 1750)', '277 -> 346']
# SCG_FAIL ['(188, 1750)', '188 -> O']
# MCG_FAIL ['(261, 1750) -> (346, 1750)', '346 -> O']
# MCG_FAIL ['(109, 1750) -> (414, 1750)', 'O -> O']
# NAS_REC

# %% [markdown]
# # Find NAS RECOV (Recovery)

# %%
root = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12_2/Bandlock_9_Schemes_Phone_UDP"
rrc_files = []
devices = [f'sm{i:02d}' for i in range(9)]
# trips = [f'#{i+1:02d}' for i in range(2)]

for dev in devices:
    trips = [os.path.join(root, dev, s) for s in os.listdir(os.path.join(root, dev)) if os.path.isdir(os.path.join(root, dev, s))]
    for tr in trips:
        rrc_files.append([os.path.join(root, dev, tr, 'data', s) for s in os.listdir(os.path.join(root, dev, tr, 'data')) if s.startswith('diag') and s.endswith('rrc.pkl')][0])

# pprint(rrc_files)
for filename in rrc_files:
    df = pd.read_pickle(filename)
    if sum((df['rrcConnectionReestablishmentReject'] == '1') | (df['rrcConnectionReestablishmentReject'] == 1)) > 0:
        print(sum((df['rrcConnectionReestablishmentReject'] == '1') | (df['rrcConnectionReestablishmentReject'] == 1)), filename)
# Out:
# 1 /Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12_2/Bandlock_9_Schemes_Phone_UDP/sm00/#02/data/diag_log_sm00_2023-09-12_14-52-28_rrc.pkl

# %%
root = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-04/Bandlock_8_Schemes_Phone"
rrc_files = []
devices = [f'sm{i:02d}' for i in range(8)]
# trips = [f'#{i+1:02d}' for i in range(2)]

for dev in devices:
    trips = [os.path.join(root, dev, s) for s in os.listdir(os.path.join(root, dev)) if os.path.isdir(os.path.join(root, dev, s))]
    for tr in trips:
        rrc_files.append([os.path.join(root, dev, tr, 'data', s) for s in os.listdir(os.path.join(root, dev, tr, 'data')) if s.startswith('diag') and s.endswith('rrc.pkl')][0])

# pprint(rrc_files)
for filename in rrc_files:
    df = pd.read_pickle(filename)
    if sum((df['rrcConnectionReestablishmentReject'] == '1') | (df['rrcConnectionReestablishmentReject'] == 1)) > 0:
        print(sum((df['rrcConnectionReestablishmentReject'] == '1') | (df['rrcConnectionReestablishmentReject'] == 1)), filename)
# Out:
# 1 /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-04/Bandlock_8_Schemes_Phone/sm03/#04/data/diag_log_sm03_2023-05-04_14-24-14_rrc.pkl
