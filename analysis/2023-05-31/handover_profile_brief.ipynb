# %%
import os
import sys
import ast
import pandas as pd
import numpy as np
import datetime as dt
from pprint import pprint
import csv
import itertools as it
from prettytable import PrettyTable
import matplotlib.pylab as plt
import seaborn as sns
import portion as P
from collections import namedtuple
import math

pdir = os.path.abspath(os.path.join(os.getcwd(), '..'))  # for jupyter-notebook
sys.path.insert(1, pdir)
from myutils import *

# %config InlineBackend.figure_format = 'retina'  # 提高 jupyter notebook 的圖形顯示解析度
# plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 200)

DataFrame = namedtuple('DataFrame', 'filename, df', defaults=tuple([None]*2))

def set_data(df, mode='pcap', tz=0):
    if mode == 'pcap':
        df['seq'] = df['seq'].astype('Int32')
        # df['rpkg'] = df['rpkg'].astype('Int8')
        df['frame_id'] = df['frame_id'].astype('Int32')
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df['xmit_time'] = pd.to_datetime(df['xmit_time'])
        df['arr_time'] = pd.to_datetime(df['arr_time'])
        df['Timestamp_epoch'] = df['Timestamp_epoch'].astype('float32')
        df['xmit_time_epoch'] = df['xmit_time_epoch'].astype('float32')
        df['arr_time_epoch'] = df['arr_time_epoch'].astype('float32')
        df['lost'] = df['lost'].astype('boolean')
        df['excl'] = df['excl'].astype('boolean')
        df['latency'] = df['latency'].astype('float32')
    # E-UTRA & NR
    def nr_serv_cel(row):
        pos = row.serv_cel_pos
        if pos == 255:
            return 65535, -160, -50
        else:
            return row[f'PCI{pos}'], row[f'RSRP{pos}'], row[f'RSRQ{pos}']
    if mode == 'lte':
        df = df.rename(columns={
            'RSRP(dBm)': 'RSRP',
            'RSRQ(dB)': 'RSRQ',
            'Serving Cell Index': 'serv_cel_index',
            'Number of Neighbor Cells': 'num_neigh_cels',
            'Number of Detected Cells': 'num_cels',
            }).reindex(['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                        'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0',
                        *df.columns.to_list()[df.columns.get_loc('PCI1'):]], axis=1)
        df.loc[df['serv_cel_index'] == '(MI)Unknown', 'serv_cel_index'] = '3_SCell'
        df['num_cels'] = df['num_neigh_cels'] + 1
        ## set dtypes
        df['Timestamp'] = pd.to_datetime(df['Timestamp']) + pd.Timedelta(hours=tz)
        df['type_id'] = df['type_id'].astype('category')
        df['serv_cel_index'] = df['serv_cel_index'].astype('category')
        df['EARFCN'] = df['EARFCN'].astype('Int32')
        df['NR_ARFCN'] = df['NR_ARFCN'].astype('Int32')
        df['num_cels'] = df['num_cels'].astype('UInt8')
        df['num_neigh_cels'] = df['num_neigh_cels'].astype('UInt8')
        df['serv_cel_pos'] = df['serv_cel_pos'].astype('UInt8')
        for tag in df.columns:
            if tag.startswith('PCI'):
                df[tag] = df[tag].astype('Int32')
            if tag.startswith(('RSRP','RSRQ')):
                df[tag] = df[tag].astype('float32')
    if mode == 'nr':
        if df.empty:
            df = pd.DataFrame(columns=['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                                       'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0'])
        else:
            df = df.rename(columns={
                'Raster ARFCN': 'NR_ARFCN',
                'Serving Cell Index': 'serv_cel_pos',
                'Num Cells': 'num_cels',
                }).reindex(['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                            'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0',
                            *df.columns.to_list()[df.columns.get_loc('PCI1'):]], axis=1)
            df.loc[df['serv_cel_pos'] != 255, 'serv_cel_index'] = 'PSCell'
            df[['PCI','RSRP','RSRQ']] = df.apply(nr_serv_cel, axis=1, result_type='expand')
            df.loc[df['serv_cel_pos'] == 255, 'num_neigh_cels'] = df['num_cels']
            df.loc[df['serv_cel_pos'] != 255, 'num_neigh_cels'] = df['num_cels'] - 1
        ## set dtypes
        df['Timestamp'] = pd.to_datetime(df['Timestamp']) + pd.Timedelta(hours=tz)
        df['type_id'] = df['type_id'].astype('category')
        df['serv_cel_index'] = df['serv_cel_index'].astype('category')
        df['EARFCN'] = df['EARFCN'].astype('Int32')
        df['NR_ARFCN'] = df['NR_ARFCN'].astype('Int32')
        df['num_cels'] = df['num_cels'].astype('UInt8')
        df['num_neigh_cels'] = df['num_neigh_cels'].astype('UInt8')
        df['serv_cel_pos'] = df['serv_cel_pos'].astype('UInt8')
        for tag in df.columns:
            if tag.startswith('PCI'):
                df[tag] = df[tag].astype('Int32')
            if tag.startswith(('RSRP','RSRQ')):
                df[tag] = df[tag].astype('float32')
    return df

# %%
def setup_profile(df, tag, start, end, mode='ul', left=pd.Timestamp.min, right=pd.Timestamp.max, fix=False, wsize=1):
    if pd.notna(end):
        # midpoint = start + (end - start) / 2
        midpoint = start
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(end+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=wsize), left), min(end+pd.Timedelta(seconds=wsize), right))
    else:
        midpoint = start
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(start+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=wsize), left), min(start+pd.Timedelta(seconds=wsize), right))
    
    if mode == 'ul':
        df_plot = df.query('xmit_time >= @intv.lower & xmit_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['xmit_time'] - midpoint).dt.total_seconds()
    elif mode == 'dl':
        df_plot = df.query('arr_time >= @intv.lower & arr_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['arr_time'] - midpoint).dt.total_seconds()
    else: # 'pyl'
        df_plot = df.query('Timestamp >= @intv.lowe/r & Timestamp <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['Timestamp'] - midpoint).dt.total_seconds()
    df_plot['cat_id'] = ((df_plot['rel_time'] + 0.005) // 0.01) * 0.01
    
    ts_group = df_plot.groupby(['cat_id'])
    table = ts_group['lost'].agg(['count','sum','mean']).copy().reset_index()
    table = table.rename(columns={'count':'tx_count', 'sum':'lost', 'mean':'PLR'})
    table['PLR'] = table['PLR'] * 100
    # display(table)
    return table, intv

def merge_profile(tables, intrs):
    intr = np.mean(intrs)
    table = pd.DataFrame(columns=['cat_id','tx_count','lost','PLR'])
    table['cat_id'] = table['cat_id'].astype('float32')
    table['tx_count'] = table['tx_count'].astype('Int32')
    table['lost'] = table['lost'].astype('Int32')
    table['PLR'] = table['PLR'].astype('float32')
    for i in range(len(tables)):
        _table = tables[i].copy()
        table = table.merge(_table, on=['cat_id'], how='outer').fillna(0)
        table['tx_count'] = table['tx_count_x'] + table['tx_count_y']
        table['lost'] = table['lost_x'] + table['lost_y']
        table['PLR'] = 0
        table = table[['cat_id','tx_count','lost','PLR']]
    table['PLR'] = table['lost'] / (table['tx_count'] + 1e-9) * 100
    table = table[['cat_id','tx_count','lost','PLR']].copy().sort_values(by=['cat_id']).reset_index(drop=True)
    return table, intr

def plot_profile(table, intr=0, title='', mode='lost', xlim=0, path='', flow='ul', stable_plr=0, plr=0, plr1=0):
    fig, ax = plt.subplots(figsize=(6, 4))
    if flow == 'ul':
        ax.set_title(f'Uplink: {title}')
    else: # 'dl'
        ax.set_title(f'Downlink: {title}')
    if xlim == 0:
        ax.set_xlim(table.iat[0, table.columns.get_loc('cat_id')], table.iat[-1, table.columns.get_loc('cat_id')])
    else:
        ax.set_xlim(-xlim, xlim)
    if mode == 'lost':
        ax.bar(table['cat_id'], table['lost'], width=0.01, alpha=0.97)
        ax.set_ylabel('Lost Number')
        ax.set_ylim(bottom=0)
    if mode == 'plr':
        ax.bar(table['cat_id'], table['PLR'], width=0.01, alpha=0.97)
        ax.set_ylabel('Packet Loss Rate (%)')
        ax.axhline(stable_plr, color='tab:pink', linestyle='--', label='Stable PLR')
        ax.axhline(plr1, color='tab:green', linestyle='--', label=f'{title} PLR')
        ax.text(-1.078*xlim, plr1, '{:.2f}'.format(plr1), ha='center', fontweight='bold', fontsize=10, color='tab:green')
        # ax.axhline(plr, color='tab:orange', linestyle='--', label=f'{title} PLR')
        # ax.text(-1.078*xlim, plr, '{:.2f}'.format(plr), ha='center', fontweight='bold', fontsize=10, color='tab:orange')
        ax.legend()
        bleft = -ImpactScope[title][0]
        bright = ImpactScope[title][1]
        rect1 = patches.Rectangle((bleft, 0), bright-bleft, plr, ec=None, fc='#ffbc00', alpha=0.5)  # 左下角座標點, 寬度, 高度, 邊界顏色, 填滿顏色
        ax.add_patch(rect1)
        # ax.set_ylim(top=105)
        ax.set_ylim(bottom=0)
    intr /= 2
    # ax.axvline((start-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    # ax.axvline((end-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    ax.axvline(-intr, color='tab:red', alpha=0.5)
    ax.axvline(intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    plt.gcf().autofmt_xdate()
    plt.savefig(os.path.join(path, f'{title}_{flow.upper()}_{mode}.png'), bbox_inches='tight', dpi=300)
    plt.show()

def plot_intrs(data, tag, path='', count=0):
    data = [s*1000 for s in data]
    
    # Plot the violin plot
    fig, ax = plt.subplots(figsize=(6, 1.5))
    ax.violinplot(data, vert=False, quantiles=[0.25, 0.5, 0.75])

    # Calculate and plot the mean and median values
    mean = np.mean(data)
    ax.axvline(mean, color='r', linestyle='--', label='Mean')
    ax.text(mean, 0.58, '{:.1f}'.format(mean), ha='center', fontweight='bold', fontsize=10, color='r')
    ax.set_xlim(left=0)
    ax.set_yticks([])
    ax.set_title(f'{tag} ({count} ct.)')
    ax.set_xlabel('Handover Interruption Time (ms)')

    # Add legend and title
    ax.legend()
    
    # Show the plot
    plt.savefig(os.path.join(path, f'{tag}_intr_dist.png'), bbox_inches='tight', dpi=300)
    plt.show()

# %%
# root = '/home/wmnlab/D/database'
root = '/Users/jackbedford/Desktop/MOXA/Code/data'
paths = [s for s in os.listdir(root) if s.startswith('202') and os.path.isdir(os.path.join(root, s))]

md_files = []

for date_dir in paths:
    datedir = os.path.join(root, date_dir)
    md_file = [os.path.join(datedir, s) for s in os.listdir(datedir) if s.endswith('.md')]
    md_files += md_file

md_files = sorted(md_files)

# Select dates
# md_files = md_files[:-1]
# md_files = [md_files[2]]
md_files = [s for s in md_files if '05-04' not in s and '05-07' not in s]
# md_files = md_files[:5]

pprint(md_files)
# Out:
# ['/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/2023-03-16.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/2023-03-26.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/2023-04-01.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/2023-04-10.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/2023-04-17.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/2023-05-15.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/2023-05-24.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/2023-05-26.md']

# %%
class Experiment():
    
    def __init__(self, dir_name, setting):
        
        self.dir_name = dir_name
        self.setting = setting
        
    def __repr__(self):
        return f'{self.dir_name} -> {self.setting}'

exp_list = []

for md_file in md_files:
    
    md_f = open(md_file, 'r')
    lines = []
    l = md_f.readline()[:-1]
    
    while l:
        
        if l == '#endif':
            break
        lines.append(l)
        l = md_f.readline()[:-1]
        
    md_f.close()
    
    for exp, dic in zip(lines[::2], lines[1::2]):
        
        dictionary = ast.literal_eval(dic)
        parent_dir = os.path.dirname(md_file)
        experiment = Experiment(dir_name = os.path.join(parent_dir, exp), setting=dictionary)
        exp_list.append(experiment)
        
pprint(exp_list)
# Out:
# [/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q -> {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q -> {'qc00': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q -> {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q -> {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1 -> {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2 -> {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3 -> {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1', 'qc03': 'B3'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}]

# %% [markdown]
# ## Downlink

# %%
## Downlink
ImpactScope = {
    'LTE_HO': (5, 5),   # LTE_HO, MN_HO, SN_Rel_MN_HO
    'NR_HO': (7, 7),    # SN_HO, SN_Rel
    'RLF': (7, 7),      # SCG_Failure, MCG_Failure, NAS_Recovery
    'NR_Setup': (3, 3), # SN_Setup
}

# %%
sorter = ['LTE_HO',
          'NR_HO',
          'RLF',
          'NR_Setup',
]

# sorter1 = ['LTE_HO','MN_HO','SN_Rel_MN_HO',
#           'SN_HO','SN_Rel',
#           'SCG_Failure','MCG_Failure','NAS_Recovery',
#           'SN_Setup',
# ]

D = {}
for tag in sorter:
    D[tag] = {'tables': [], 'intrs': [], 'count': []}
dl_stable_pkt = 0
dl_stable_loss = 0

for exp in exp_list:
    dir_name = exp.dir_name
    devices = sorted(exp.setting.keys())
    for dev in devices:
        dev_folder = os.path.join(dir_name, dev)
        for trace in sorted(os.listdir(dev_folder)):
            if '#' not in trace:
                continue
            trace_folder = os.path.join(dev_folder, trace, 'data')
            ## read downlink
            data = os.path.join(trace_folder, 'udp_dnlk_loss_latency.pkl')
            print(data, os.path.isfile(data))
            df_dl = pd.read_pickle(data)
            df_dl = set_data(df_dl)
            ## read handover
            data = os.path.join(trace_folder, [s for s in os.listdir(trace_folder) if s.startswith('diag_log_') and s.endswith('_rrc.pkl')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_pickle(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### re-classify
                if tag in ['LTE_HO','MN_HO','SN_Rel_MN_HO']:
                    tag = 'LTE_HO'
                elif tag in ['SN_HO','SN_Rel']:
                    tag = 'NR_HO'
                elif tag in ['SCG_Failure','MCG_Failure','NAS_Recovery']:
                    tag = 'RLF'
                elif tag in ['SN_Setup']:
                    tag = 'NR_Setup'
                else:
                    pass
                ### Setup profile
                table, intv = setup_profile(df_dl, tag, start, end, mode='dl', left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
                ### count stable loss, pkt (1)
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
                dl_stable_pkt += len(df_tmp)
                dl_stable_loss += sum(df_tmp['lost'])
                _intv = intv
            ### count stable loss, pkt (2)
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
            dl_stable_pkt += len(df_tmp)
            dl_stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                D[tag]['tables'].append(table)
                D[tag]['intrs'] = [*D[tag]['intrs'], *A[tag]['intrs']]
                D[tag]['count'].append(len(A[tag]['tables']))
            dl_stable_plr = dl_stable_loss / (dl_stable_pkt + 1e-9) * 100
            print(dl_stable_loss, dl_stable_pkt, round(dl_stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.pkl True
# 0 78631 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.pkl True
# 0 168624 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.pkl True
# 0 266215 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.pkl True
# 0 357309 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.pkl True
# 0 448089 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.pkl True
# 0 537919 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.pkl True
# 0 626722 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.pkl True
# 0 714160 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.pkl True
# 0 806901 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.pkl True
# 0 885120 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.pkl True
# 0 978471 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.pkl True
# 0 1067139 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.pkl True
# 0 1114285 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.pkl True
# 0 1157435 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.pkl True
# 0 1216251 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.pkl True
# 0 1265720 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.pkl True
# 0 1325456 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.pkl True
# 0 1362379 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.pkl True
# 0 1422992 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.pkl True
# 0 1460028 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.pkl True
# 0 1514411 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.pkl True
# 0 1572054 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.pkl True
# 0 1625225 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.pkl True
# 0 1672081 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.pkl True
# 0 1719129 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.pkl True
# 0 1769814 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.pkl True
# 0 1841666 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.pkl True
# 0 1901118 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.pkl True
# 0 1952190 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.pkl True
# 0 2006872 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.pkl True
# 0 2056967 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.pkl True
# 0 2109739 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.pkl True
# 0 2159956 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.pkl True
# 0 2204839 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.pkl True
# 0 2258638 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.pkl True
# 0 2303997 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-26_16-36-49_rrc.pkl True
# 0 2377571 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-26_16-46-50_rrc.pkl True
# 0 2434132 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-26_16-56-26_rrc.pkl True
# 0 2479742 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-26_17-25-57_rrc.pkl True
# 0 2531966 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-26_16-36-49_rrc.pkl True
# 0 2593626 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-26_16-46-50_rrc.pkl True
# 0 2640555 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-26_16-56-26_rrc.pkl True
# 1 2690549 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-26_17-25-57_rrc.pkl True
# 3 2738255 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-26_16-36-49_rrc.pkl True
# 4 2801235 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-26_16-46-50_rrc.pkl True
# 5 2864200 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-26_16-56-26_rrc.pkl True
# 7 2901013 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-26_17-25-57_rrc.pkl True
# 7 2954044 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.pkl True
# 10 3030790 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.pkl True
# 10 3085543 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.pkl True
# 10 3154092 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.pkl True
# 10 3212013 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.pkl True
# 10 3279058 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.pkl True
# 12 3323921 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.pkl True
# 12 3374067 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.pkl True
# 12 3427891 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.pkl True
# 12 3537014 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.pkl True
# 14 3609254 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.pkl True
# 14 3687415 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.pkl True
# 14 3758999 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.pkl True
# 15 3811810 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.pkl True
# 16 3862495 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.pkl True
# 17 3922796 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.pkl True
# 17 3967529 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.pkl True
# 18 4063056 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.pkl True
# 19 4154448 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.pkl True
# 21 4260456 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.pkl True
# 24 4345983 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.pkl True
# 24 4449235 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.pkl True
# 27 4536601 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.pkl True
# 27 4585827 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.pkl True
# 27 4645318 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.pkl True
# 27 4712780 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.pkl True
# 27 4764022 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.pkl True
# 27 4811626 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.pkl True
# 27 4869487 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.pkl True
# 27 4921390 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.pkl True
# 28 4978255 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.pkl True
# 32 5043797 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.pkl True
# 28 2023-04-01 14:49:49.990450 2023-04-01 14:49:50.443961 MN_HO nan
# 29 2023-04-01 14:49:50.311569 2023-04-01 14:49:50.395569 MCG_Failure handoverFailure (1)
# 35 5097751 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.pkl True
# 37 5155023 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.pkl True
# 38 5211020 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.pkl True
# 39 5265912 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.pkl True
# 41 5320580 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.pkl True
# 42 5376716 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.pkl True
# 43 5429599 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.pkl True
# 11 2023-04-01 14:57:54.316881 2023-04-01 14:57:54.704566 MN_HO nan
# 12 2023-04-01 14:57:54.550779 2023-04-01 14:57:54.617962 MCG_Failure handoverFailure (1)
# 43 5488485 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.pkl True
# 44 5539913 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_rrc.pkl True
# 48 5599733 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_rrc.pkl True
# 50 5659473 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_rrc.pkl True
# 50 5703197 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_rrc.pkl True
# 50 5751007 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_rrc.pkl True
# 51 5810431 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_rrc.pkl True
# 52 5864170 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_rrc.pkl True
# 52 5932203 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_rrc.pkl True
# 52 5993772 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/diag_log_qc00_2023-04-10_15-45-32_rrc.pkl True
# 104 6099622 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/diag_log_qc00_2023-04-10_16-06-58_rrc.pkl True
# 104 6189168 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/diag_log_qc01_2023-04-10_15-45-32_rrc.pkl True
# 104 6265943 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/diag_log_qc01_2023-04-10_16-06-58_rrc.pkl True
# 104 6327696 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/diag_log_qc02_2023-04-10_15-45-32_rrc.pkl True
# 104 6393518 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/diag_log_qc02_2023-04-10_16-06-58_rrc.pkl True
# 104 6448509 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/diag_log_qc03_2023-04-10_15-45-32_rrc.pkl True
# 104 6496508 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/diag_log_qc03_2023-04-10_16-06-58_rrc.pkl True
# 104 6533012 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/diag_log_qc00_2023-04-10_16-29-38_rrc.pkl True
# 104 6612191 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/diag_log_qc00_2023-04-10_16-42-04_rrc.pkl True
# 104 6685715 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/diag_log_qc01_2023-04-10_16-29-38_rrc.pkl True
# 104 6747359 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/diag_log_qc01_2023-04-10_16-42-04_rrc.pkl True
# 104 6784522 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/diag_log_qc02_2023-04-10_16-29-38_rrc.pkl True
# 104 6849948 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/diag_log_qc02_2023-04-10_16-42-04_rrc.pkl True
# 104 6895778 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/diag_log_qc03_2023-04-10_16-29-38_rrc.pkl True
# 104 6959881 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/diag_log_qc03_2023-04-10_16-42-04_rrc.pkl True
# 104 7005717 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_16-17-28_rrc.pkl True
# 104 7056441 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_16-35-58_rrc.pkl True
# 104 7112890 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_16-43-43_rrc.pkl True
# 104 7165954 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_16-51-18_rrc.pkl True
# 104 7203817 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_16-17-28_rrc.pkl True
# 104 7258250 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_16-35-58_rrc.pkl True
# 104 7332435 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_16-43-43_rrc.pkl True
# 104 7424010 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_16-51-18_rrc.pkl True
# 104 7486672 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_16-17-28_rrc.pkl True
# 104 7541154 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_16-35-58_rrc.pkl True
# 104 7597358 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_16-43-43_rrc.pkl True
# 104 7659466 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_16-51-18_rrc.pkl True
# 105 7723947 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_16-17-28_rrc.pkl True
# 105 7778094 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_16-35-58_rrc.pkl True
# 105 7843489 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_16-43-43_rrc.pkl True
# 105 7932538 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_16-51-18_rrc.pkl True
# 105 8004884 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-01-08_rrc.pkl True
# 105 8073942 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-09-48_rrc.pkl True
# 106 8117743 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-01-08_rrc.pkl True
# 106 8219409 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-09-48_rrc.pkl True
# 106 8298655 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-01-08_rrc.pkl True
# 106 8403764 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-09-48_rrc.pkl True
# 106 8491686 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-01-08_rrc.pkl True
# 106 8567907 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-09-48_rrc.pkl True
# 107 8620642 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-18-15_rrc.pkl True
# 107 8665890 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-27-58_rrc.pkl True
# 107 8709732 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-18-15_rrc.pkl True
# 107 8793315 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-27-58_rrc.pkl True
# 107 8871747 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-18-15_rrc.pkl True
# 107 8924984 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-27-58_rrc.pkl True
# 108 8970406 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-18-15_rrc.pkl True
# 108 9027085 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-27-58_rrc.pkl True
# 108 9073881 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-15-10_rrc.pkl True
# 108 9131212 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_14-24-04_rrc.pkl True
# 108 9182822 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_14-35-41_rrc.pkl True
# 108 9251110 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_14-44-10_rrc.pkl True
# 108 9299989 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-15-10_rrc.pkl True
# 108 9375268 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_14-24-04_rrc.pkl True
# 108 9443031 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_14-35-41_rrc.pkl True
# 108 9553531 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_14-44-10_rrc.pkl True
# 108 9635267 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-15-10_rrc.pkl True
# 108 9693823 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_14-24-04_rrc.pkl True
# 108 9744934 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_14-35-41_rrc.pkl True
# 109 9805177 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_14-44-10_rrc.pkl True
# 109 9860227 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-15-10_rrc.pkl True
# 109 9913293 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_14-24-04_rrc.pkl True
# 109 9962724 0.001
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_14-35-41_rrc.pkl True
# 808 10106740 0.008
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_14-44-10_rrc.pkl True
# 943 10233773 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-55-50_rrc.pkl True
# 944 10296407 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-04-11_rrc.pkl True
# 944 10341410 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-10-33_rrc.pkl True
# 944 10413652 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_15-19-12_rrc.pkl True
# 944 10467314 0.009
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.pkl True
# ...
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#04/data/diag_log_sm02_2023-05-26_14-01-18_rrc.pkl True
# 5857 19736736 0.03
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#05/data/diag_log_sm02_2023-05-26_14-15-00_rrc.pkl True
# 5857 19790662 0.03
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#06/data/diag_log_sm02_2023-05-26_14-31-19_rrc.pkl True
# 5858 19853557 0.03
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#07/data/diag_log_sm02_2023-05-26_14-55-22_rrc.pkl True
# 5859 19931838 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#08/data/diag_log_sm02_2023-05-26_15-06-23_rrc.pkl True
# 5862 19985424 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#09/data/diag_log_sm02_2023-05-26_15-20-22_rrc.pkl True
# 5862 20034975 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm02/#10/data/diag_log_sm02_2023-05-26_15-31-24_rrc.pkl True
# 5862 20093087 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#01/data/diag_log_sm03_2023-05-26_13-27-02_rrc.pkl True
# 5862 20155093 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#02/data/diag_log_sm03_2023-05-26_13-36-22_rrc.pkl True
# 5862 20209729 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#03/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#03/data/diag_log_sm03_2023-05-26_13-51-12_rrc.pkl True
# 5862 20276779 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#04/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#04/data/diag_log_sm03_2023-05-26_14-01-18_rrc.pkl True
# 5862 20317315 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#05/data/diag_log_sm03_2023-05-26_14-15-00_rrc.pkl True
# 5862 20390908 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#06/data/diag_log_sm03_2023-05-26_14-31-19_rrc.pkl True
# 5862 20442137 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#07/data/diag_log_sm03_2023-05-26_14-55-22_rrc.pkl True
# 5904 20508205 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#08/data/diag_log_sm03_2023-05-26_15-06-23_rrc.pkl True
# 5910 20561766 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#09/data/diag_log_sm03_2023-05-26_15-20-22_rrc.pkl True
# 5910 20624029 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm03/#10/data/diag_log_sm03_2023-05-26_15-31-24_rrc.pkl True
# 5910 20669611 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm04/#01/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm04/#01/data/diag_log_sm04_2023-05-26_13-27-02_rrc.pkl True
# 5911 20737788 0.029
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm04/#02/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm04/
0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#05/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#05/data/diag_log_sm07_2023-05-26_14-15-00_rrc.pkl True
# 5962 22978794 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#06/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#06/data/diag_log_sm07_2023-05-26_14-31-19_rrc.pkl True
# 5962 23043983 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#07/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#07/data/diag_log_sm07_2023-05-26_14-55-22_rrc.pkl True
# 5962 23111425 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#08/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#08/data/diag_log_sm07_2023-05-26_15-06-23_rrc.pkl True
# 5969 23197419 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#09/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#09/data/diag_log_sm07_2023-05-26_15-20-22_rrc.pkl True
# 5969 23298964 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#10/data/udp_dnlk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#10/data/diag_log_sm07_2023-05-26_15-31-24_rrc.pkl True
# 5969 23374362 0.026

# %% [markdown]
# ### Plot

# %%
## Downlink
ImpactScope = {
    'LTE_HO': (2, 2),   # LTE_HO, MN_HO, SN_Rel_MN_HO
    'NR_HO': (3.5, 4),    # SN_HO, SN_Rel
    'RLF': (5.5, 2),      # SCG_Failure, MCG_Failure, NAS_Recovery
    'NR_Setup': (0.5, 2), # SN_Setup
}

## Downlink
# ImpactScope = {
#     'LTE_HO': (5, 5),   # LTE_HO, MN_HO, SN_Rel_MN_HO
#     'NR_HO': (7, 7),    # SN_HO, SN_Rel
#     'RLF': (7, 7),      # SCG_Failure, MCG_Failure, NAS_Recovery
#     'NR_Setup': (3, 3), # SN_Setup
# }

# %%
import warnings

def heaviside(x, left, right):
    if x < left:
        return 0
    elif x > right:
        return 0
    else:
        return 1

coef_dl = pd.DataFrame(columns=['lower_bd', 'upper_bd', *list(range(71))])
for tag in sorter:
    if len(D[tag]['intrs']) == 0:
        continue
    print('===================================')
    print(tag)
    table, intr = merge_profile(D[tag]['tables'], D[tag]['intrs'])
    print('HO Count:', sum(D[tag]['count']))
    print('Average Duration:', intr, 'seconds')
    # display(table)
    
    _table = table.query('PLR > @dl_stable_plr').copy().reset_index(drop=True)
    # _table = table.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr = lcount / (tcount + 1e-9) * 100
    print('Average PLR:', plr, '%')
    print('Stable PLR:', dl_stable_plr, '%')
    
    path = './temp'
    plot_intrs(D[tag]['intrs'], tag, path=path, count=sum(D[tag]['count']))
    
    xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_title(f'Downlink: {tag}')
    ax.set_xlim(-xlim, xlim)
    ax.bar(table['cat_id'], table['lost'], width=0.009, alpha=0.9)
    ax.set_ylabel('Lost Number')
    ax.set_ylim(bottom=0)
    _intr = intr / 2
    ax.axvline(-_intr, color='tab:red', alpha=0.5)
    ax.axvline(_intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    plt.gcf().autofmt_xdate()
    # plt.savefig(os.path.join(path, f'{tag}_DL_lost.png'), bbox_inches='tight', dpi=300)
    plt.show()
    
    
    # xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    # plot_profile(table1, intr=intr1, title=tag, mode='plr', xlim=wsize, path=path, flow='dl', stable_plr=stable_plr, plr=plr, plr1=plr1)
    xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_title(f'Downlink: {tag}')
    ax.set_xlim(-xlim, xlim)
    ax.bar(table['cat_id'], table['PLR'], width=0.009, alpha=0.9)
    ax.set_ylabel('Packet Loss Rate (%)')
    ax.set_ylim(bottom=0)
    if ax.get_ylim()[1] < 1:
        ax.set_ylim(top=1.05)
    
    ax.axhline(dl_stable_plr, color='tab:pink', linestyle='--', label='Stable PLR')
    ax.text(-1.078*xlim, dl_stable_plr, '{:.2f}'.format(dl_stable_plr), ha='center', fontweight='bold', fontsize=10, color='tab:pink')
    ax.axhline(plr, color='tab:green', linestyle='--', label=f'{tag} PLR')
    ax.text(-1.078*xlim, plr, '{:.2f}'.format(plr), ha='center', fontweight='bold', fontsize=10, color='tab:green')
    ax.legend()
    bleft = -ImpactScope[tag][0]
    bright = ImpactScope[tag][1]
    
    _intr = intr / 2
    # ax.axvline(-_intr, color='tab:red', alpha=0.5)
    # ax.axvline(_intr, color='tab:red', alpha=0.5)
    ax.axvline(0, color='tab:red', alpha=0.5)
    ax.axvline(intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    
    x = np.asarray(table['cat_id'], dtype=np.float64)
    y = np.asarray(table['PLR'], dtype=np.float64)
    with warnings.catch_warnings():
        warnings.simplefilter('ignore', np.RankWarning)
        z = np.polyfit(x, y, 70)
        p = np.poly1d(z)
    xp = np.linspace(table['cat_id'].iloc[0], table['cat_id'].iloc[-1], 1000)
    
    coef = list(p.coefficients)
    if len(coef) < 71:
        coef += [0]*(71-len(coef))
    coef_dl.loc[tag] = [bleft, bright, *coef]
    
    ax.plot(xp, np.clip(p(xp)*np.vectorize(heaviside)(xp, bleft, bright), a_min=0, a_max=100), '-', c='tab:orange', lw=0.5)
    ax.fill_between(xp, np.clip(p(xp)*np.vectorize(heaviside)(xp, bleft, bright), a_min=0, a_max=100), color='tab:orange', alpha=0.3)
    
    plt.gcf().autofmt_xdate()
    plt.savefig(os.path.join(path, f'{tag}_DL_PLR.png'), bbox_inches='tight', dpi=300)
    plt.show()
# Out:
# ===================================
# LTE_HO
# HO Count: 6611
# Average Duration: 0.020145122219914477 seconds
# Average PLR: 0.8434844798314695 %
# Stable PLR: 0.02553652587394685 %
# ===================================
# NR_HO
# HO Count: 4993
# Average Duration: 0.015954905064042003 seconds
# Average PLR: 0.37434015532770487 %
# Stable PLR: 0.02553652587394685 %
# ===================================
# RLF
# HO Count: 646
# Average Duration: 0.07891214554177903 seconds
# Average PLR: 18.9534728359665 %
# Stable PLR: 0.02553652587394685 %
# ===================================
# NR_Setup
# HO Count: 1196
# Average Duration: 0.0323787399584795 seconds
# Average PLR: 7.0513123566706595 %
# Stable PLR: 0.02553652587394685 %

# %% [markdown]
# ## Uplink

# %%
## Uplink
ImpactScope = {
    'LTE_HO': (5, 5),   # LTE_HO, MN_HO, SN_Rel_MN_HO
    'NR_HO': (7, 7),    # SN_HO, SN_Rel
    'RLF': (7, 7),      # SCG_Failure, MCG_Failure, NAS_Recovery
    'NR_Setup': (3, 3), # SN_Setup
}

# %%
sorter = ['LTE_HO',
          'NR_HO',
          'RLF',
          'NR_Setup',
]

# sorter1 = ['LTE_HO','MN_HO','SN_Rel_MN_HO',
#           'SN_HO','SN_Rel',
#           'SCG_Failure','MCG_Failure','NAS_Recovery',
#           'SN_Setup',
# ]

U = {}
for tag in sorter:
    U[tag] = {'tables': [], 'intrs': [], 'count': []}
ul_stable_pkt = 0
ul_stable_loss = 0

for exp in exp_list:
    dir_name = exp.dir_name
    devices = sorted(exp.setting.keys())
    for dev in devices:
        dev_folder = os.path.join(dir_name, dev)
        for trace in sorted(os.listdir(dev_folder)):
            if '#' not in trace:
                continue
            trace_folder = os.path.join(dev_folder, trace, 'data')
            ## read downlink
            data = os.path.join(trace_folder, 'udp_uplk_loss_latency.pkl')
            print(data, os.path.isfile(data))
            df_ul = pd.read_pickle(data)
            df_ul = set_data(df_ul)
            ## read handover
            data = os.path.join(trace_folder, [s for s in os.listdir(trace_folder) if s.startswith('diag_log_') and s.endswith('_rrc.pkl')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_pickle(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### re-classify
                if tag in ['LTE_HO','MN_HO','SN_Rel_MN_HO']:
                    tag = 'LTE_HO'
                elif tag in ['SN_HO','SN_Rel']:
                    tag = 'NR_HO'
                elif tag in ['SCG_Failure','MCG_Failure','NAS_Recovery']:
                    tag = 'RLF'
                elif tag in ['SN_Setup']:
                    tag = 'NR_Setup'
                else:
                    pass
                ### Setup profile
                table, intv = setup_profile(df_ul, tag, start, end, mode='ul', left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
                ### count stable loss, pkt (1)
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
                ul_stable_pkt += len(df_tmp)
                ul_stable_loss += sum(df_tmp['lost'])
                _intv = intv
            ### count stable loss, pkt (2)
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_ul.query('xmit_time > @lower & xmit_time <= @upper').copy().reset_index(drop=True)
            ul_stable_pkt += len(df_tmp)
            ul_stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                U[tag]['tables'].append(table)
                U[tag]['intrs'] = [*U[tag]['intrs'], *A[tag]['intrs']]
                U[tag]['count'].append(len(A[tag]['tables']))
            ul_stable_plr = ul_stable_loss / (ul_stable_pkt + 1e-9) * 100
            print(ul_stable_loss, ul_stable_pkt, round(ul_stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.pkl True
# 0 78501 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.pkl True
# 0 168484 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.pkl True
# 0 266110 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.pkl True
# 0 357197 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.pkl True
# 0 447983 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.pkl True
# 2 537812 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.pkl True
# 2 626622 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.pkl True
# 2 714050 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.pkl True
# 2 806791 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.pkl True
# 3 885112 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.pkl True
# 3 978465 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.pkl True
# 3 1067216 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.pkl True
# 5 1114363 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.pkl True
# 5 1157437 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.pkl True
# 6 1216164 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.pkl True
# 6 1265622 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.pkl True
# 6 1325360 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.pkl True
# 6 1362132 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.pkl True
# 6 1422741 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.pkl True
# 6 1459774 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.pkl True
# 6 1514047 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.pkl True
# 6 1571792 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.pkl True
# 6 1624966 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.pkl True
# 6 1671892 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.pkl True
# 6 1718814 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.pkl True
# 6 1769497 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.pkl True
# 6 1841292 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.pkl True
# 6 1900825 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.pkl True
# 6 1951769 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.pkl True
# 6 2006443 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.pkl True
# 6 2056705 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.pkl True
# 6 2109476 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.pkl True
# 6 2159577 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.pkl True
# 6 2204452 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.pkl True
# 6 2258242 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.pkl True
# 6 2303691 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-26_16-36-49_rrc.pkl True
# 6 2377266 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-26_16-46-50_rrc.pkl True
# 6 2433992 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-26_16-56-26_rrc.pkl True
# 6 2479527 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-26_17-25-57_rrc.pkl True
# 6 2531968 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-26_16-36-49_rrc.pkl True
# 6 2593530 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-26_16-46-50_rrc.pkl True
# 6 2640465 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-26_16-56-26_rrc.pkl True
# 6 2690375 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-26_17-25-57_rrc.pkl True
# 6 2738077 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-26_16-36-49_rrc.pkl True
# 6 2800961 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-26_16-46-50_rrc.pkl True
# 6 2863922 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-26_16-56-26_rrc.pkl True
# 6 2900737 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-26_17-25-57_rrc.pkl True
# 6 2954003 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.pkl True
# 8 3030665 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.pkl True
# 9 3085304 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.pkl True
# 9 3153778 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.pkl True
# 15 3211705 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.pkl True
# 1927 3278672 0.059
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.pkl True
# 3146 3323529 0.095
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.pkl True
# 3149 3373589 0.093
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.pkl True
# 3149 3427409 0.092
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.pkl True
# 3152 3536455 0.089
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.pkl True
# 3152 3608696 0.087
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.pkl True
# 3152 3686852 0.085
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.pkl True
# 3152 3758456 0.084
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.pkl True
# 3154 3811186 0.083
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.pkl True
# 3154 3861905 0.082
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.pkl True
# 3154 3922120 0.08
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.pkl True
# 3154 3966763 0.08
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.pkl True
# 3154 4062292 0.078
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.pkl True
# 3154 4153690 0.076
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.pkl True
# 3154 4259704 0.074
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.pkl True
# 3154 4345226 0.073
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.pkl True
# 3154 4448480 0.071
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.pkl True
# 3154 4535848 0.07
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.pkl True
# 3157 4585063 0.069
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.pkl True
# 4876 4644549 0.105
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.pkl True
# 4876 4712018 0.103
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.pkl True
# 4876 4763259 0.102
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.pkl True
# 4881 4810789 0.101
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.pkl True
# 4881 4868651 0.1
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.pkl True
# 4881 4920654 0.099
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.pkl True
# 4881 4977523 0.098
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.pkl True
# 4881 5043067 0.097
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.pkl True
# 28 2023-04-01 14:49:49.990450 2023-04-01 14:49:50.443961 MN_HO nan
# 29 2023-04-01 14:49:50.311569 2023-04-01 14:49:50.395569 MCG_Failure handoverFailure (1)
# 4884 5096930 0.096
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.pkl True
# 4884 5154124 0.095
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.pkl True
# 4884 5210132 0.094
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.pkl True
# 4884 5265026 0.093
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.pkl True
# 4884 5319700 0.092
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.pkl True
# 4884 5375770 0.091
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.pkl True
# 4884 5428643 0.09
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.pkl True
# 11 2023-04-01 14:57:54.316881 2023-04-01 14:57:54.704566 MN_HO nan
# 12 2023-04-01 14:57:54.550779 2023-04-01 14:57:54.617962 MCG_Failure handoverFailure (1)
# 4884 5487619 0.089
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.pkl True
# 4884 5539136 0.088
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_rrc.pkl True
# 4885 5598953 0.087
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_rrc.pkl True
# 4887 5658798 0.086
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_rrc.pkl True
# 4888 5702408 0.086
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_rrc.pkl True
# 6171 5750132 0.107
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_rrc.pkl True
# 6173 5809473 0.106
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_rrc.pkl True
# 6174 5863214 0.105
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_rrc.pkl True
# 6178 5931148 0.104
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_rrc.pkl True
# 6179 5992716 0.103
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/diag_log_qc00_2023-04-10_15-45-32_rrc.pkl True
# 6179 6098563 0.101
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/diag_log_qc00_2023-04-10_16-06-58_rrc.pkl True
# 6182 6188103 0.1
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/diag_log_qc01_2023-04-10_15-45-32_rrc.pkl True
# 6184 6264770 0.099
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/diag_log_qc01_2023-04-10_16-06-58_rrc.pkl True
# 7873 6326525 0.124
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/diag_log_qc02_2023-04-10_15-45-32_rrc.pkl True
# 7876 6392356 0.123
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/diag_log_qc02_2023-04-10_16-06-58_rrc.pkl True
# 7876 6447264 0.122
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/diag_log_qc03_2023-04-10_15-45-32_rrc.pkl True
# 7878 6495165 0.121
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/diag_log_qc03_2023-04-10_16-06-58_rrc.pkl True
# 7878 6531667 0.121
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/diag_log_qc00_2023-04-10_16-29-38_rrc.pkl True
# 7878 6610845 0.119
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/diag_log_qc00_2023-04-10_16-42-04_rrc.pkl True
# 7878 6684462 0.118
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/diag_log_qc01_2023-04-10_16-29-38_rrc.pkl True
# 7879 6746019 0.117
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/diag_log_qc01_2023-04-10_16-42-04_rrc.pkl True
# 7879 6783279 0.116
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/diag_log_qc02_2023-04-10_16-29-38_rrc.pkl True
# 7879 6848622 0.115
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/diag_log_qc02_2023-04-10_16-42-04_rrc.pkl True
# 7879 6894541 0.114
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/diag_log_qc03_2023-04-10_16-29-38_rrc.pkl True
# 7879 6958639 0.113
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/diag_log_qc03_2023-04-10_16-42-04_rrc.pkl True
# 7879 7004478 0.112
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_16-17-28_rrc.pkl True
# 7883 7055061 0.112
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_16-35-58_rrc.pkl True
# 7883 7111510 0.111
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_16-43-43_rrc.pkl True
# 7883 7164712 0.11
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_16-51-18_rrc.pkl True
# 7883 7202659 0.109
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_16-17-28_rrc.pkl True
# 9479 7257051 0.131
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_16-35-58_rrc.pkl True
# 11573 7331223 0.158
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_16-43-43_rrc.pkl True
# 11574 7422795 0.156
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_16-51-18_rrc.pkl True
# 11585 7485558 0.155
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_16-17-28_rrc.pkl True
# 11631 7540041 0.154
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_16-35-58_rrc.pkl True
# 11631 7596251 0.153
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_16-43-43_rrc.pkl True
# 11633 7658368 0.152
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_16-51-18_rrc.pkl True
# 11637 7722817 0.151
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_16-17-28_rrc.pkl True
# 11637 7777177 0.15
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_16-35-58_rrc.pkl True
# 11640 7842671 0.148
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_16-43-43_rrc.pkl True
# 11640 7931863 0.147
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_16-51-18_rrc.pkl True
# 11641 8004305 0.145
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-01-08_rrc.pkl True
# 11641 8073369 0.144
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-09-48_rrc.pkl True
# 11642 8117163 0.143
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-01-08_rrc.pkl True
# 11666 8218825 0.142
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-09-48_rrc.pkl True
# 11674 8298177 0.141
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-01-08_rrc.pkl True
# 11674 8403291 0.139
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-09-48_rrc.pkl True
# 11676 8491317 0.138
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-01-08_rrc.pkl True
# 11676 8567538 0.136
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-09-48_rrc.pkl True
# 11679 8620384 0.135
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-18-15_rrc.pkl True
# 11679 8665462 0.135
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-27-58_rrc.pkl True
# 11680 8709311 0.134
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-18-15_rrc.pkl True
# 11694 8792912 0.133
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-27-58_rrc.pkl True
# 13787 8871349 0.155
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-18-15_rrc.pkl True
# 13787 8924434 0.154
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-27-58_rrc.pkl True
# 13787 8969843 0.154
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17
data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#02/data/diag_log_sm07_2023-05-26_13-36-22_rrc.pkl True
# 29249 22719483 0.129
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#03/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#03/data/diag_log_sm07_2023-05-26_13-51-12_rrc.pkl True
# 29249 22812439 0.128
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#04/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#04/data/diag_log_sm07_2023-05-26_14-01-18_rrc.pkl True
# 29249 22884282 0.128
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#05/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#05/data/diag_log_sm07_2023-05-26_14-15-00_rrc.pkl True
# 29249 22983574 0.127
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#06/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#06/data/diag_log_sm07_2023-05-26_14-31-19_rrc.pkl True
# 29249 23048946 0.127
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#07/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#07/data/diag_log_sm07_2023-05-26_14-55-22_rrc.pkl True
# 29250 23116374 0.127
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#08/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#08/data/diag_log_sm07_2023-05-26_15-06-23_rrc.pkl True
# 29250 23202546 0.126
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#09/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#09/data/diag_log_sm07_2023-05-26_15-20-22_rrc.pkl True
# 29250 23304088 0.126
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#10/data/udp_uplk_loss_latency.pkl True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone/sm07/#10/data/diag_log_sm07_2023-05-26_15-31-24_rrc.pkl True
# 29250 23379484 0.125

# %% [markdown]
# ### Plot

# %%
## Uplink
ImpactScope = {
    'LTE_HO': (2, 2),   # LTE_HO, MN_HO, SN_Rel_MN_HO
    'NR_HO': (2, 2),    # SN_HO, SN_Rel
    'RLF': (4.5, 3),      # SCG_Failure, MCG_Failure, NAS_Recovery
    'NR_Setup': (0.5, 2), # SN_Setup
}

## Uplink
# ImpactScope = {
#     'LTE_HO': (5, 5),   # LTE_HO, MN_HO, SN_Rel_MN_HO
#     'NR_HO': (7, 7),    # SN_HO, SN_Rel
#     'RLF': (7, 7),      # SCG_Failure, MCG_Failure, NAS_Recovery
#     'NR_Setup': (3, 3), # SN_Setup
# }

# %%
import warnings

def heaviside(x, left, right):
    if x < left:
        return 0
    elif x > right:
        return 0
    else:
        return 1

coef_ul = pd.DataFrame(columns=['lower_bd', 'upper_bd', *list(range(71))])
for tag in sorter:
    if len(U[tag]['intrs']) == 0:
        continue
    print('===================================')
    print(tag)
    table, intr = merge_profile(U[tag]['tables'], U[tag]['intrs'])
    print('HO Count:', sum(U[tag]['count']))
    print('Average Duration:', intr, 'seconds')
    # display(table)
    
    _table = table.query('PLR > @ul_stable_plr').copy().reset_index(drop=True)
    # _table = table.copy().reset_index(drop=True)
    tcount = sum(_table['tx_count'])
    lcount = sum(_table['lost'])
    plr = lcount / (tcount + 1e-9) * 100
    print('Average PLR:', plr, '%')
    print('Stable PLR:', ul_stable_plr, '%')
    
    path = './temp'
    plot_intrs(U[tag]['intrs'], tag, path=path, count=sum(U[tag]['count']))
    
    xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_title(f'Uplink: {tag}')
    ax.set_xlim(-xlim, xlim)
    ax.bar(table['cat_id'], table['lost'], width=0.009, alpha=0.9)
    ax.set_ylabel('Lost Number')
    ax.set_ylim(bottom=0)
    _intr = intr / 2
    ax.axvline(-_intr, color='tab:red', alpha=0.5)
    ax.axvline(_intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    plt.gcf().autofmt_xdate()
    # plt.savefig(os.path.join(path, f'{tag}_UL_lost.png'), bbox_inches='tight', dpi=300)
    plt.show()
    
    
    # xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    # plot_profile(table1, intr=intr1, title=tag, mode='plr', xlim=wsize, path=path, flow='dl', stable_plr=stable_plr, plr=plr, plr1=plr1)
    xlim = math.ceil(max([s*2 for s in ImpactScope[tag]])) / 2
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_title(f'Uplink: {tag}')
    ax.set_xlim(-xlim, xlim)
    ax.bar(table['cat_id'], table['PLR'], width=0.009, alpha=0.9)
    ax.set_ylabel('Packet Loss Rate (%)')
    ax.set_ylim(bottom=0)
    if ax.get_ylim()[1] < 1:
        ax.set_ylim(top=1.05)
    
    ax.axhline(ul_stable_plr, color='tab:pink', linestyle='--', label='Stable PLR')
    ax.text(-1.078*xlim, ul_stable_plr, '{:.2f}'.format(ul_stable_plr), ha='center', fontweight='bold', fontsize=10, color='tab:pink')
    ax.axhline(plr, color='tab:green', linestyle='--', label=f'{tag} PLR')
    ax.text(-1.078*xlim, plr, '{:.2f}'.format(plr), ha='center', fontweight='bold', fontsize=10, color='tab:green')
    ax.legend()
    bleft = -ImpactScope[tag][0]
    bright = ImpactScope[tag][1]
    
    _intr = intr / 2
    # ax.axvline(-_intr, color='tab:red', alpha=0.5)
    # ax.axvline(_intr, color='tab:red', alpha=0.5)
    ax.axvline(0, color='tab:red', alpha=0.5)
    ax.axvline(intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    
    x = np.asarray(table['cat_id'], dtype=np.float64)
    y = np.asarray(table['PLR'], dtype=np.float64)
    with warnings.catch_warnings():
        warnings.simplefilter('ignore', np.RankWarning)
        z = np.polyfit(x, y, 70)
        p = np.poly1d(z)
    xp = np.linspace(table['cat_id'].iloc[0], table['cat_id'].iloc[-1], 1000)
    
    coef = list(p.coefficients)
    if len(coef) < 71:
        coef += [0]*(71-len(coef))
    coef_ul.loc[tag] = [bleft, bright, *list(coef)]
    
    ax.plot(xp, np.clip(p(xp)*np.vectorize(heaviside)(xp, bleft, bright), a_min=0, a_max=100), '-', c='tab:orange', lw=0.5)
    ax.fill_between(xp, np.clip(p(xp)*np.vectorize(heaviside)(xp, bleft, bright), a_min=0, a_max=100), color='tab:orange', alpha=0.3)
    
    plt.gcf().autofmt_xdate()
    plt.savefig(os.path.join(path, f'{tag}_UL_PLR.png'), bbox_inches='tight', dpi=300)
    plt.show()
# Out:
# ===================================
# LTE_HO
# HO Count: 6611
# Average Duration: 0.020145122219914477 seconds
# Average PLR: 0.24528329185258368 %
# Stable PLR: 0.12510969018820092 %
# ===================================
# NR_HO
# HO Count: 4993
# Average Duration: 0.015954905064042003 seconds
# Average PLR: 0.1719294293213361 %
# Stable PLR: 0.12510969018820092 %
# ===================================
# RLF
# HO Count: 646
# Average Duration: 0.07891214554177903 seconds
# Average PLR: 1.7327816087706167 %
# Stable PLR: 0.12510969018820092 %
# ===================================
# NR_Setup
# HO Count: 1196
# Average Duration: 0.0323787399584795 seconds
# Average PLR: 1.2504370775283278 %
# Stable PLR: 0.12510969018820092 %

# %% [markdown]
# ## Output coefficients

# %%
display(coef_dl)
pd.to_pickle(coef_dl, './coef_dl.pkl')
# Out:
