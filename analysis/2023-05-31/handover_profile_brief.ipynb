# %%
import os
import sys
import ast
import pandas as pd
import numpy as np
import datetime as dt
from pprint import pprint
import csv
import itertools as it
from prettytable import PrettyTable
import matplotlib.pylab as plt
import seaborn as sns
import portion as P
from collections import namedtuple
import math

pdir = os.path.abspath(os.path.join(os.getcwd(), '..'))  # for jupyter-notebook
sys.path.insert(1, pdir)
from myutils import *

# %config InlineBackend.figure_format = 'retina'  # 提高 jupyter notebook 的圖形顯示解析度
# plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 200)

DataFrame = namedtuple('DataFrame', 'filename, df', defaults=tuple([None]*2))

def set_data(df, mode='pcap', tz=0):
    if mode == 'pcap':
        df['seq'] = df['seq'].astype('Int32')
        # df['rpkg'] = df['rpkg'].astype('Int8')
        df['frame_id'] = df['frame_id'].astype('Int32')
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df['xmit_time'] = pd.to_datetime(df['xmit_time'])
        df['arr_time'] = pd.to_datetime(df['arr_time'])
        df['Timestamp_epoch'] = df['Timestamp_epoch'].astype('float32')
        df['xmit_time_epoch'] = df['xmit_time_epoch'].astype('float32')
        df['arr_time_epoch'] = df['arr_time_epoch'].astype('float32')
        df['lost'] = df['lost'].astype('boolean')
        df['excl'] = df['excl'].astype('boolean')
        df['latency'] = df['latency'].astype('float32')
    # E-UTRA & NR
    def nr_serv_cel(row):
        pos = row.serv_cel_pos
        if pos == 255:
            return 65535, -160, -50
        else:
            return row[f'PCI{pos}'], row[f'RSRP{pos}'], row[f'RSRQ{pos}']
    if mode == 'lte':
        df = df.rename(columns={
            'RSRP(dBm)': 'RSRP',
            'RSRQ(dB)': 'RSRQ',
            'Serving Cell Index': 'serv_cel_index',
            'Number of Neighbor Cells': 'num_neigh_cels',
            'Number of Detected Cells': 'num_cels',
            }).reindex(['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                        'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0',
                        *df.columns.to_list()[df.columns.get_loc('PCI1'):]], axis=1)
        df.loc[df['serv_cel_index'] == '(MI)Unknown', 'serv_cel_index'] = '3_SCell'
        df['num_cels'] = df['num_neigh_cels'] + 1
        ## set dtypes
        df['Timestamp'] = pd.to_datetime(df['Timestamp']) + pd.Timedelta(hours=tz)
        df['type_id'] = df['type_id'].astype('category')
        df['serv_cel_index'] = df['serv_cel_index'].astype('category')
        df['EARFCN'] = df['EARFCN'].astype('Int32')
        df['NR_ARFCN'] = df['NR_ARFCN'].astype('Int32')
        df['num_cels'] = df['num_cels'].astype('UInt8')
        df['num_neigh_cels'] = df['num_neigh_cels'].astype('UInt8')
        df['serv_cel_pos'] = df['serv_cel_pos'].astype('UInt8')
        for tag in df.columns:
            if tag.startswith('PCI'):
                df[tag] = df[tag].astype('Int32')
            if tag.startswith(('RSRP','RSRQ')):
                df[tag] = df[tag].astype('float32')
    if mode == 'nr':
        if df.empty:
            df = pd.DataFrame(columns=['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                                       'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0'])
        else:
            df = df.rename(columns={
                'Raster ARFCN': 'NR_ARFCN',
                'Serving Cell Index': 'serv_cel_pos',
                'Num Cells': 'num_cels',
                }).reindex(['Timestamp','type_id','PCI','RSRP','RSRQ','serv_cel_index','EARFCN','NR_ARFCN',
                            'num_cels','num_neigh_cels','serv_cel_pos','PCI0','RSRP0','RSRQ0',
                            *df.columns.to_list()[df.columns.get_loc('PCI1'):]], axis=1)
            df.loc[df['serv_cel_pos'] != 255, 'serv_cel_index'] = 'PSCell'
            df[['PCI','RSRP','RSRQ']] = df.apply(nr_serv_cel, axis=1, result_type='expand')
            df.loc[df['serv_cel_pos'] == 255, 'num_neigh_cels'] = df['num_cels']
            df.loc[df['serv_cel_pos'] != 255, 'num_neigh_cels'] = df['num_cels'] - 1
        ## set dtypes
        df['Timestamp'] = pd.to_datetime(df['Timestamp']) + pd.Timedelta(hours=tz)
        df['type_id'] = df['type_id'].astype('category')
        df['serv_cel_index'] = df['serv_cel_index'].astype('category')
        df['EARFCN'] = df['EARFCN'].astype('Int32')
        df['NR_ARFCN'] = df['NR_ARFCN'].astype('Int32')
        df['num_cels'] = df['num_cels'].astype('UInt8')
        df['num_neigh_cels'] = df['num_neigh_cels'].astype('UInt8')
        df['serv_cel_pos'] = df['serv_cel_pos'].astype('UInt8')
        for tag in df.columns:
            if tag.startswith('PCI'):
                df[tag] = df[tag].astype('Int32')
            if tag.startswith(('RSRP','RSRQ')):
                df[tag] = df[tag].astype('float32')
    return df

# %%
def setup_profile(df, tag, start, end, mode='ul', left=pd.Timestamp.min, right=pd.Timestamp.max, fix=False, wsize=1):
    if pd.notna(end):
        # midpoint = start + (end - start) / 2
        midpoint = start
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(end+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=wsize), left), min(end+pd.Timedelta(seconds=wsize), right))
    else:
        midpoint = start
        intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(start+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
        if fix:
            intv = P.closed(max(start-pd.Timedelta(seconds=wsize), left), min(start+pd.Timedelta(seconds=wsize), right))
    
    if mode == 'ul':
        df_plot = df.query('xmit_time >= @intv.lower & xmit_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['xmit_time'] - midpoint).dt.total_seconds()
    elif mode == 'dl':
        df_plot = df.query('arr_time >= @intv.lower & arr_time <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['arr_time'] - midpoint).dt.total_seconds()
    else: # 'pyl'
        df_plot = df.query('Timestamp >= @intv.lowe/r & Timestamp <= @intv.upper').copy().reset_index(drop=True)
        df_plot['rel_time'] = (df_plot['Timestamp'] - midpoint).dt.total_seconds()
    df_plot['cat_id'] = ((df_plot['rel_time'] + 0.005) // 0.01) * 0.01
    
    ts_group = df_plot.groupby(['cat_id'])
    table = ts_group['lost'].agg(['count','sum','mean']).copy().reset_index()
    table = table.rename(columns={'count':'tx_count', 'sum':'lost', 'mean':'PLR'})
    table['PLR'] = table['PLR'] * 100
    # display(table)
    return table, intv

def merge_profile(tables, intrs):
    intr = np.mean(intrs)
    table = pd.DataFrame(columns=['cat_id','tx_count','lost','PLR'])
    table['cat_id'] = table['cat_id'].astype('float32')
    table['tx_count'] = table['tx_count'].astype('Int32')
    table['lost'] = table['lost'].astype('Int32')
    table['PLR'] = table['PLR'].astype('float32')
    for i in range(len(tables)):
        _table = tables[i].copy()
        table = table.merge(_table, on=['cat_id'], how='outer').fillna(0)
        table['tx_count'] = table['tx_count_x'] + table['tx_count_y']
        table['lost'] = table['lost_x'] + table['lost_y']
        table['PLR'] = 0
        table = table[['cat_id','tx_count','lost','PLR']]
    table['PLR'] = table['lost'] / (table['tx_count'] + 1e-9) * 100
    table = table[['cat_id','tx_count','lost','PLR']].copy().sort_values(by=['cat_id']).reset_index(drop=True)
    return table, intr

def plot_profile(table, intr=0, title='', mode='lost', xlim=0, path='', flow='ul', stable_plr=0, plr=0, plr1=0):
    fig, ax = plt.subplots(figsize=(6, 4))
    if flow == 'ul':
        ax.set_title(f'Uplink: {title}')
    else: # 'dl'
        ax.set_title(f'Downlink: {title}')
    if xlim == 0:
        ax.set_xlim(table.iat[0, table.columns.get_loc('cat_id')], table.iat[-1, table.columns.get_loc('cat_id')])
    else:
        ax.set_xlim(-xlim, xlim)
    if mode == 'lost':
        ax.bar(table['cat_id'], table['lost'], width=0.01, alpha=0.97)
        ax.set_ylabel('Lost Number')
        ax.set_ylim(bottom=0)
    if mode == 'plr':
        ax.bar(table['cat_id'], table['PLR'], width=0.01, alpha=0.97)
        ax.set_ylabel('Packet Loss Rate (%)')
        ax.axhline(stable_plr, color='tab:pink', linestyle='--', label='Stable PLR')
        ax.axhline(plr1, color='tab:green', linestyle='--', label=f'{title} PLR')
        ax.text(-1.078*xlim, plr1, '{:.2f}'.format(plr1), ha='center', fontweight='bold', fontsize=10, color='tab:green')
        # ax.axhline(plr, color='tab:orange', linestyle='--', label=f'{title} PLR')
        # ax.text(-1.078*xlim, plr, '{:.2f}'.format(plr), ha='center', fontweight='bold', fontsize=10, color='tab:orange')
        ax.legend()
        bleft = -ImpactScope[title][0]
        bright = ImpactScope[title][1]
        rect1 = patches.Rectangle((bleft, 0), bright-bleft, plr, ec=None, fc='#ffbc00', alpha=0.5)  # 左下角座標點, 寬度, 高度, 邊界顏色, 填滿顏色
        ax.add_patch(rect1)
        # ax.set_ylim(top=105)
        ax.set_ylim(bottom=0)
    intr /= 2
    # ax.axvline((start-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    # ax.axvline((end-midpoint).total_seconds(), color='tab:red', alpha=0.5)
    ax.axvline(-intr, color='tab:red', alpha=0.5)
    ax.axvline(intr, color='tab:red', alpha=0.5)
    ax.set_xlabel('Relative Timestamp (sec)')
    plt.gcf().autofmt_xdate()
    plt.savefig(os.path.join(path, f'{title}_{flow.upper()}_{mode}.png'), bbox_inches='tight', dpi=300)
    plt.show()

def plot_intrs(data, tag, path=''):
    data = [s*1000 for s in data]
    
    # Plot the violin plot
    fig, ax = plt.subplots(figsize=(6, 1.5))
    ax.violinplot(data, vert=False, quantiles=[0.25, 0.5, 0.75])

    # Calculate and plot the mean and median values
    mean = np.mean(data)
    ax.axvline(mean, color='r', linestyle='--', label='Mean')
    ax.text(mean, 0.58, '{:.1f}'.format(mean), ha='center', fontweight='bold', fontsize=10, color='r')
    ax.set_xlim(left=0)
    ax.set_yticks([])
    ax.set_title(tag)
    ax.set_xlabel('Handover Interruption Time (ms)')

    # Add legend and title
    ax.legend()
    
    # Show the plot
    plt.savefig(os.path.join(path, f'{tag}_intr_dist.png'), bbox_inches='tight', dpi=300)
    plt.show()

# %%
# root = '/home/wmnlab/D/database'
root = '/Users/jackbedford/Desktop/MOXA/Code/data'
paths = [s for s in os.listdir(root) if s.startswith('202') and os.path.isdir(os.path.join(root, s))]

md_files = []

for date_dir in paths:
    datedir = os.path.join(root, date_dir)
    md_file = [os.path.join(datedir, s) for s in os.listdir(datedir) if s.endswith('.md')]
    md_files += md_file

md_files = sorted(md_files)

# Select dates
# md_files = md_files[:-1]
# md_files = [md_files[2]]
md_files = [s for s in md_files if '05-04' not in s and '05-07' not in s]

pprint(md_files)
# Out:
# ['/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/2023-03-16.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/2023-03-26.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/2023-04-01.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/2023-04-10.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/2023-04-17.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/2023-05-15.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/2023-05-24.md',
#  '/Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/2023-05-26.md']

# %%
class Experiment():
    
    def __init__(self, dir_name, setting):
        
        self.dir_name = dir_name
        self.setting = setting
        
    def __repr__(self):
        return f'{self.dir_name} -> {self.setting}'

exp_list = []

for md_file in md_files:
    
    md_f = open(md_file, 'r')
    lines = []
    l = md_f.readline()[:-1]
    
    while l:
        
        if l == '#endif':
            break
        lines.append(l)
        l = md_f.readline()[:-1]
        
    md_f.close()
    
    for exp, dic in zip(lines[::2], lines[1::2]):
        
        dictionary = ast.literal_eval(dic)
        parent_dir = os.path.dirname(md_file)
        experiment = Experiment(dir_name = os.path.join(parent_dir, exp), setting=dictionary)
        exp_list.append(experiment)
        
pprint(exp_list)
# Out:
# [/Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q -> {'qc00': 'B1', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q -> {'qc00': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q -> {'qc00': 'B1B3', 'qc01': 'B1B8', 'qc02': 'LTE', 'qc03': 'All'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q -> {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1 -> {'qc00': 'All', 'qc01': 'All', 'qc02': 'All', 'qc03': 'All'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2 -> {'qc00': 'B1', 'qc01': 'B3', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3 -> {'qc00': 'LTE', 'qc01': 'All', 'qc02': 'B7B8', 'qc03': 'B7'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'All', 'qc03': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1', 'qc03': 'B3'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B7', 'qc03': 'B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B3', 'qc03': 'B3B7'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B7', 'qc03': 'B7B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q -> {'qc00': 'All', 'qc01': 'LTE', 'qc02': 'B1B8', 'qc03': 'B3B8'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'},
#  /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-26/Bandlock_8_Schemes_Phone -> {'sm00': 'B3B7B8', 'sm01': 'B3', 'sm02': 'B7', 'sm03': 'B8', 'sm04': 'B3B7', 'sm05': 'B3B8', 'sm06': 'B7B8', 'sm07': 'LTE'}]

# %%
## Downlink
ImpactScope = {
    # 'LTE_HO': (),
    # 'NR_HO': (),
    # 'RLF': (),
    # 'NR_Setup': (),
    'LTE_HO': (1.11, 0.7), 
    'MN_HO': (1.39, 1.62),
    'SN_HO': (0.87, 1.28),
    'SN_Setup': (0.36, 1.5),
    'SN_Rel': (0.03, 0.1),
    'SN_Rel_MN_HO': (0.4, 0.58),
    'SCG_Failure_t310-Expiry (0)': (1.5, 1.2),
    'SCG_Failure_synchReconfigFailureSCG (3)': (0.03, 0.03),
    'MCG_Failure_reconfigurationFailure (0)': (2, 2),
    'MCG_Failure_handoverFailure (1)': (0.7, 1.23),
    'MCG_Failure_otherFailure (2)': (5.66, 1.25),
    'NAS_Recovery_handoverFailure (1)': (0.5, 0.5),
    'NAS_Recovery_otherFailure (2)': (0.81, 1.61),
}

## Uplink
# ImpactScope = {
#     'LTE_HO': (),
#     'NR_HO': (),
#     'RLF': (),
#     'NR_Setup': (),
#     # 'LTE_HO': (0.5, 1),
#     # 'MN_HO': (1.21, 2),
#     # 'SN_HO': (0.87, 1.27),
#     # 'SN_Setup': (0.4, 1.7),
#     # 'SN_Rel': (0.12, 0.15),
#     # 'SN_Rel_MN_HO': (0.25 , 0.51),
#     # 'SCG_Failure_t310-Expiry (0)': (1.3, 1.21),
#     # 'SCG_Failure_synchReconfigFailureSCG (3)': (0.03, 0.05),
#     # 'MCG_Failure_reconfigurationFailure (0)': (2, 2),
#     # 'MCG_Failure_handoverFailure (1)': (0.8, 1.25),
#     # 'MCG_Failure_otherFailure (2)': (5, 1.5),
#     # 'NAS_Recovery_handoverFailure (1)': (0.3, 0.3),
#     # 'NAS_Recovery_otherFailure (2)': (0.75, 1.6),
# }

# %%
sorter = ['LTE_HO','MN_HO','SN_HO','MNSN_HO','SN_Rel','SN_Setup','SN_Rel_MN_HO','SN_Setup_MN_HO',
          'SCG_Failure_t310-Expiry (0)','SCG_Failure_randomAccessProblem (1)','SCG_Failure_rlc-MaxNumRetx (2)','SCG_Failure_synchReconfigFailureSCG (3)',
          'SCG_Failure_scg-ReconfigFailure (4)','SCG_Failure_srb3-IntegrityFailure (5)','SCG_Failure_other-r16 (6)',
          'MCG_Failure_reconfigurationFailure (0)','MCG_Failure_handoverFailure (1)','MCG_Failure_otherFailure (2)',
          'NAS_Recovery_reconfigurationFailure (0)','NAS_Recovery_handoverFailure (1)','NAS_Recovery_otherFailure (2)']

D = {}
for tag in sorter:
    D[tag] = {'tables': [], 'intrs': [], 'count': []}
dl_stable_pkt = 0
dl_stable_loss = 0

for exp in exp_list:
    dir_name = exp.dir_name
    devices = sorted(exp.setting.keys())
    for dev in devices:
        dev_folder = os.path.join(dir_name, dev)
        for trace in sorted(os.listdir(dev_folder)):
            if '#' not in trace:
                continue
            trace_folder = os.path.join(dev_folder, trace, 'data')
            ## read downlink
            data = os.path.join(trace_folder, 'udp_dnlk_loss_latency.csv')
            print(data, os.path.isfile(data))
            df_dl = pd.read_csv(data)
            df_dl = set_data(df_dl)
            ## read handover
            data = os.path.join(trace_folder, [s for s in os.listdir(trace_folder) if s.startswith('diag_log_') and s.endswith('_rrc.csv')][0])
            print(data, os.path.isfile(data))
            df_ho = pd.read_csv(data)
            df_ho, _, _ = mi_parse_ho(df_ho, tz=8)
            df_ho['ho_type0'] = df_ho['ho_type'].astype('string')
            df_ho.loc[df_ho['cause'].notna(), 'ho_type0'] = df_ho['ho_type'].astype('string') + '_' + df_ho['cause'].astype('string')
            df_ho['ho_type0'] = df_ho['ho_type0'].astype('category')
            ## start processing
            df = df_ho[~np.in1d(df_ho['ho_type'], ['Conn_Setup', 'Conn_Rel'])].copy().reset_index(drop=True)
            A = {}
            for tag in sorter:
                A[tag] = {'tables': [], 'intrs': []}
            _intv = P.singleton(pd.Timestamp.min)
            for i, row in df.iterrows():
                prior_row = df.iloc[i-1] if i != 0 else None
                post_row = df.iloc[i+1] if i != len(df)-1 else None
                ### peek the next event: avoid MN/LTE HO overlaps with handoverFailure
                if i != len(df)-1 and pd.notna(row.end) and row.end > post_row.start:
                    print(i, row.start, row.end, row.ho_type, row.cause)
                    print(i+1, post_row.start, post_row.end, post_row.ho_type, post_row.cause)
                    continue
                if i != 0 and pd.notna(prior_row.end) and prior_row.end > row.start:
                    prior_row = df.iloc[i-2] if i > 1 else None
                ### basic timestamp
                tag = row.ho_type0
                start, end = row.start, row.end
                intr = row.intr if pd.notna(row.intr) else 0
                ### set left, right limit
                if prior_row is not None:
                    if pd.notna(prior_row.end):
                        # left = prior_row.end
                        left = prior_row.end + (start - prior_row.end) / 2
                    else:
                        # left = prior_row.start
                        left = prior_row.start + (start - prior_row.start) / 2
                else:
                    left = pd.Timestamp.min
                if post_row is not None:
                    if pd.notna(end):
                        # right = post_row.start
                        right = end + (post_row.start - end) / 2
                    else:
                        # right = post_row.start
                        right = start + (post_row.start - start) / 2
                else:
                    right = pd.Timestamp.max
                ### Setup profile
                table, intv = setup_profile(df_dl, tag, start, end, mode='dl', left=left, right=right)
                # print(intr)
                # display(table)
                A[tag]['tables'].append(table)
                A[tag]['intrs'].append(intr)
                ### count stable loss, pkt (1)
                if i == 0:
                    lower = pd.Timestamp.min
                    upper = intv.lower
                else:
                    lower = _intv.upper
                    upper = intv.lower
                df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
                dl_stable_pkt += len(df_tmp)
                dl_stable_loss += sum(df_tmp['lost'])
                _intv = intv
            ### count stable loss, pkt (2)
            lower = _intv.upper
            upper = pd.Timestamp.max
            df_tmp = df_dl.query('arr_time > @lower & arr_time <= @upper').copy().reset_index(drop=True)
            dl_stable_pkt += len(df_tmp)
            dl_stable_loss += sum(df_tmp['lost'])
            for tag in sorter:
                if len(A[tag]['tables']) == 0:
                    continue
                table, intr = merge_profile(A[tag]['tables'], A[tag]['intrs'])
                # print('HO Count:', len(df))
                D[tag]['tables'].append(table)
                D[tag]['intrs'] = [*D[tag]['intrs'], *A[tag]['intrs']]
                D[tag]['count'].append(len(A[tag]['tables']))
            dl_stable_plr = dl_stable_loss / (dl_stable_pkt + 1e-9) * 100
            print(dl_stable_loss, dl_stable_pkt, round(dl_stable_plr, 3))
# Out:
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-16_19-23-29_rrc.csv True
# 0 119197 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-16_19-32-43_rrc.csv True
# 0 245458 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-16_19-38-36_rrc.csv True
# 0 378264 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-16_19-47-07_rrc.csv True
# 0 503406 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-03-16_19-55-14_rrc.csv True
# 0 630248 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-03-16_20-03-44_rrc.csv True
# 0 755378 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#07/data/diag_log_qc00_2023-03-16_20-09-26_rrc.csv True
# 0 878454 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#08/data/diag_log_qc00_2023-03-16_20-17-10_rrc.csv True
# 0 999721 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#09/data/diag_log_qc00_2023-03-16_20-25-39_rrc.csv True
# 0 1127969 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#10/data/diag_log_qc00_2023-03-16_20-33-14_rrc.csv True
# 0 1248660 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#11/data/diag_log_qc00_2023-03-16_20-41-22_rrc.csv True
# 0 1376393 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#12/data/diag_log_qc00_2023-03-16_20-49-00_rrc.csv True
# 0 1497827 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-16_19-23-29_rrc.csv True
# 0 1599176 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-16_19-32-43_rrc.csv True
# 0 1698573 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-16_19-38-36_rrc.csv True
# 0 1807015 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-16_19-47-07_rrc.csv True
# 0 1905802 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-03-16_19-55-14_rrc.csv True
# 0 2005887 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-03-16_20-03-44_rrc.csv True
# 2 2100386 0.0
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#07/data/diag_log_qc02_2023-03-16_20-09-26_rrc.csv True
# 79 2202485 0.004
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#08/data/diag_log_qc02_2023-03-16_20-17-10_rrc.csv True
# 79 2294261 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#09/data/diag_log_qc02_2023-03-16_20-25-39_rrc.csv True
# 79 2389598 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#10/data/diag_log_qc02_2023-03-16_20-33-14_rrc.csv True
# 79 2493910 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#11/data/diag_log_qc02_2023-03-16_20-41-22_rrc.csv True
# 79 2589481 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#12/data/diag_log_qc02_2023-03-16_20-49-00_rrc.csv True
# 79 2684505 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-16_19-23-29_rrc.csv True
# 79 2780003 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-16_19-32-43_rrc.csv True
# 79 2882356 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-16_19-38-36_rrc.csv True
# 79 2996438 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-16_19-47-07_rrc.csv True
# 79 3102010 0.003
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-03-16_19-55-14_rrc.csv True
# 79 3201109 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-03-16_20-03-44_rrc.csv True
# 79 3310919 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#07/data/diag_log_qc03_2023-03-16_20-09-26_rrc.csv True
# 79 3405532 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#08/data/diag_log_qc03_2023-03-16_20-17-10_rrc.csv True
# 79 3506133 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#09/data/diag_log_qc03_2023-03-16_20-25-39_rrc.csv True
# 79 3611050 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#10/data/diag_log_qc03_2023-03-16_20-33-14_rrc.csv True
# 79 3705004 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#11/data/diag_log_qc03_2023-03-16_20-41-22_rrc.csv True
# 79 3805844 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-16/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#12/data/diag_log_qc03_2023-03-16_20-49-00_rrc.csv True
# 79 3902957 0.002
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#01/data/diag_log_qc00_2023-03-26_16-36-49_rrc.csv True
# 494 4020449 0.012
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#02/data/diag_log_qc00_2023-03-26_16-46-50_rrc.csv True
# 682 4126176 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#03/data/diag_log_qc00_2023-03-26_16-56-26_rrc.csv True
# 800 4230358 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc00/#04/data/diag_log_qc00_2023-03-26_17-25-57_rrc.csv True
# 803 4334189 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#01/data/diag_log_qc02_2023-03-26_16-36-49_rrc.csv True
# 803 4447761 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#02/data/diag_log_qc02_2023-03-26_16-46-50_rrc.csv True
# 803 4542839 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#03/data/diag_log_qc02_2023-03-26_16-56-26_rrc.csv True
# 804 4653464 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc02/#04/data/diag_log_qc02_2023-03-26_17-25-57_rrc.csv True
# 806 4751067 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#01/data/diag_log_qc03_2023-03-26_16-36-49_rrc.csv True
# 808 4865418 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#02/data/diag_log_qc03_2023-03-26_16-46-50_rrc.csv True
# 809 4973615 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#03/data/diag_log_qc03_2023-03-26_16-56-26_rrc.csv True
# 811 5074665 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-03-26/Bandlock_Udp_All_RM500Q/qc03/#04/data/diag_log_qc03_2023-03-26_17-25-57_rrc.csv True
# 812 5178824 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_15-21-12_rrc.csv True
# 816 5305557 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_15-30-33_rrc.csv True
# 817 5409974 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_15-37-38_rrc.csv True
# 821 5535155 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_15-51-06_rrc.csv True
# 843 5638811 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_15-21-12_rrc.csv True
# 843 5758660 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_15-30-33_rrc.csv True
# 845 5859550 0.014
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_15-37-38_rrc.csv True
# 938 5972391 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_15-51-06_rrc.csv True
# 940 6071584 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_15-21-12_rrc.csv True
# 940 6215372 0.015
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_15-30-33_rrc.csv True
# 1136 6339501 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_15-37-38_rrc.csv True
# 1138 6472390 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_15-51-06_rrc.csv True
# 1138 6596825 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_15-21-12_rrc.csv True
# 1141 6708371 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_15-30-33_rrc.csv True
# 1146 6811014 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_15-37-38_rrc.csv True
# 1147 6926006 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_All_LTE_B1B3_B1B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_15-51-06_rrc.csv True
# 1148 7030311 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-01_14-07-29_rrc.csv True
# 1149 7160310 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-01_14-21-11_rrc.csv True
# 1151 7288999 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-01_14-32-06_rrc.csv True
# 1154 7429166 0.016
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-01_14-45-44_rrc.csv True
# 1659 7555892 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#05/data/diag_log_qc00_2023-04-01_14-56-44_rrc.csv True
# 1661 7696462 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc00/#06/data/diag_log_qc00_2023-04-01_15-06-08_rrc.csv True
# 1665 7821680 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-01_14-07-29_rrc.csv True
# 1665 7925867 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-01_14-21-11_rrc.csv True
# 1665 8036631 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-01_14-32-06_rrc.csv True
# 1665 8156109 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-01_14-45-44_rrc.csv True
# 1666 8260756 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#05/data/diag_log_qc01_2023-04-01_14-56-44_rrc.csv True
# 1666 8376133 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc01/#06/data/diag_log_qc01_2023-04-01_15-06-08_rrc.csv True
# 1666 8483434 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-01_14-07-29_rrc.csv True
# 1667 8589030 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-01_14-21-11_rrc.csv True
# 1668 8694996 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-01_14-32-06_rrc.csv True
# 1674 8808126 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-01_14-45-44_rrc.csv True
# 28 2023-04-01 14:49:49.990450 2023-04-01 14:49:50.443961 MN_HO nan
# 29 2023-04-01 14:49:50.311569 2023-04-01 14:49:50.395569 MCG_Failure handoverFailure (1)
# 1678 8913716 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#05/data/diag_log_qc02_2023-04-01_14-56-44_rrc.csv True
# 1682 9025968 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc02/#06/data/diag_log_qc02_2023-04-01_15-06-08_rrc.csv True
# 1683 9129988 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-01_14-07-29_rrc.csv True
# 1684 9237512 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-01_14-21-11_rrc.csv True
# 1688 9340221 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-01_14-32-06_rrc.csv True
# 1692 9458214 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-01_14-45-44_rrc.csv True
# 1693 9564909 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#05/data/diag_log_qc03_2023-04-01_14-56-44_rrc.csv True
# 11 2023-04-01 14:57:54.316881 2023-04-01 14:57:54.704566 MN_HO nan
# 12 2023-04-01 14:57:54.550779 2023-04-01 14:57:54.617962 MCG_Failure handoverFailure (1)
# 1693 9680350 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-01/Bandlock_Udp_B1_B3_B7_B8_RM500Q/qc03/#06/data/diag_log_qc03_2023-04-01_15-06-08_rrc.csv True
# 1694 9785401 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#01/data/diag_log_qc00_2023-04-10_15-05-44_rrc.csv True
# 1809 9896703 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc00/#02/data/diag_log_qc00_2023-04-10_15-19-16_rrc.csv True
# 1821 10008751 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#01/data/diag_log_qc01_2023-04-10_15-05-44_rrc.csv True
# 1821 10123230 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc01/#02/data/diag_log_qc01_2023-04-10_15-19-16_rrc.csv True
# 1821 10228985 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#01/data/diag_log_qc02_2023-04-10_15-05-44_rrc.csv True
# 1822 10343359 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc02/#02/data/diag_log_qc02_2023-04-10_15-19-16_rrc.csv True
# 1830 10450450 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#01/data/diag_log_qc03_2023-04-10_15-05-44_rrc.csv True
# 1831 10561474 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment1/qc03/#02/data/diag_log_qc03_2023-04-10_15-19-16_rrc.csv True
# 1835 10667265 0.017
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#01/data/diag_log_qc00_2023-04-10_15-45-32_rrc.csv True
# 1940 10810210 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc00/#02/data/diag_log_qc00_2023-04-10_16-06-58_rrc.csv True
# 1940 10934854 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#01/data/diag_log_qc01_2023-04-10_15-45-32_rrc.csv True
# 2008 11060584 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc01/#02/data/diag_log_qc01_2023-04-10_16-06-58_rrc.csv True
# 2008 11166973 0.018
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#01/data/diag_log_qc02_2023-04-10_15-45-32_rrc.csv True
# 2145 11284033 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc02/#02/data/diag_log_qc02_2023-04-10_16-06-58_rrc.csv True
# 2145 11383066 0.019
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#01/data/diag_log_qc03_2023-04-10_15-45-32_rrc.csv True
# 2329 11489875 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment2/qc03/#02/data/diag_log_qc03_2023-04-10_16-06-58_rrc.csv True
# 2403 11588662 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#01/data/diag_log_qc00_2023-04-10_16-29-38_rrc.csv True
# 2403 11721168 0.021
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc00/#02/data/diag_log_qc00_2023-04-10_16-42-04_rrc.csv True
# 2403 11843584 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#01/data/diag_log_qc01_2023-04-10_16-29-38_rrc.csv True
# 2403 11964902 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc01/#02/data/diag_log_qc01_2023-04-10_16-42-04_rrc.csv True
# 2403 12058631 0.02
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#01/data/diag_log_qc02_2023-04-10_16-29-38_rrc.csv True
# 2627 12174823 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc02/#02/data/diag_log_qc02_2023-04-10_16-42-04_rrc.csv True
# 3083 12271402 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#01/data/diag_log_qc03_2023-04-10_16-29-38_rrc.csv True
# 3083 12387137 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-10/Experiment3/qc03/#02/data/diag_log_qc03_2023-04-10_16-42-04_rrc.csv True
# 3121 12482171 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_16-17-28_rrc.csv True
# 3121 12580912 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_16-35-58_rrc.csv True
# 3121 12679228 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_16-43-43_rrc.csv True
# 3122 12789406 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_16-51-18_rrc.csv True
# 3150 12883701 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_16-17-28_rrc.csv True
# 3150 12987256 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_16-35-58_rrc.csv True
# 3150 13103943 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_16-43-43_rrc.csv True
# 3150 13238786 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_16-51-18_rrc.csv True
# 3150 13357160 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_16-17-28_rrc.csv True
# 3151 13457787 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_16-35-58_rrc.csv True
# 3151 13556517 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_16-43-43_rrc.csv True
# 3151 13669348 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_16-51-18_rrc.csv True
# 3162 13771001 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_16-17-28_rrc.csv True
# 3162 13882427 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_16-35-58_rrc.csv True
# 3162 13999726 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_16-43-43_rrc.csv True
# 3162 14133813 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_All_LTE_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_16-51-18_rrc.csv True
# 3162 14252528 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-01-08_rrc.csv True
# 3227 14371928 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-09-48_rrc.csv True
# 3228 14467686 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-01-08_rrc.csv True
# 3228 14605195 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-09-48_rrc.csv True
# 3228 14725300 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-01-08_rrc.csv True
# 3228 14864861 0.022
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-09-48_rrc.csv True
# 3830 14987067 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-01-08_rrc.csv True
# 3830 15110691 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1_B3_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-09-48_rrc.csv True
# 3831 15207511 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_17-18-15_rrc.csv True
# 3832 15315258 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_17-27-58_rrc.csv True
# 3847 15413019 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_17-18-15_rrc.csv True
# 3847 15545846 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_17-27-58_rrc.csv True
# 3847 15667997 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_17-18-15_rrc.csv True
# 3847 15780896 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_17-27-58_rrc.csv True
# 3849 15874743 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_17-18-15_rrc.csv True
# 3849 15990626 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B7_B8_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_17-27-58_rrc.csv True
# 4003 16090183 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-15-10_rrc.csv True
# 4003 16198066 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_14-24-04_rrc.csv True
# 4003 16301206 0.025
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_14-35-41_rrc.csv True
# 4003 16419423 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc00/#04/data/diag_log_qc00_2023-04-17_14-44-10_rrc.csv True
# 4003 16521724 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#01/data/diag_log_qc01_2023-04-17_14-15-10_rrc.csv True
# 4003 16648107 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#02/data/diag_log_qc01_2023-04-17_14-24-04_rrc.csv True
# 4003 16772306 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#03/data/diag_log_qc01_2023-04-17_14-35-41_rrc.csv True
# 4074 16911106 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc01/#04/data/diag_log_qc01_2023-04-17_14-44-10_rrc.csv True
# 4074 17030853 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#01/data/diag_log_qc02_2023-04-17_14-15-10_rrc.csv True
# 4074 17143802 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#02/data/diag_log_qc02_2023-04-17_14-24-04_rrc.csv True
# 4074 17251831 0.024
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#03/data/diag_log_qc02_2023-04-17_14-35-41_rrc.csv True
# 4075 17362899 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc02/#04/data/diag_log_qc02_2023-04-17_14-44-10_rrc.csv True
# 4075 17470384 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#01/data/diag_log_qc03_2023-04-17_14-15-10_rrc.csv True
# 4075 17579808 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#02/data/diag_log_qc03_2023-04-17_14-24-04_rrc.csv True
# 4075 17685320 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_14-35-41_rrc.csv True
# 4774 17832830 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B3_B3B7_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_14-44-10_rrc.csv True
# 4909 17969167 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#01/data/diag_log_qc00_2023-04-17_14-55-50_rrc.csv True
# 4910 18083088 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#02/data/diag_log_qc00_2023-04-17_15-04-11_rrc.csv True
# 4910 18186295 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#03/data/diag_log_qc00_2023-04-17_15-10-33_rrc.csv True
# 4910 18308339 0.027
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B7_B7B8_RM500Q/qc00/#04/data/udp_dnlk_loss_latency.csv True
# ...
# 4976 21426205 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#03/data/diag_log_qc03_2023-04-17_15-40-52_rrc.csv True
# 4976 21541381 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-04-17/Bandlock_Udp_All_LTE_B1B8_B3B8_RM500Q/qc03/#04/data/diag_log_qc03_2023-04-17_15-49-16_rrc.csv True
# 4976 21642161 0.023
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#01/data/diag_log_sm00_2023-05-15_14-50-43_rrc.csv True
# 5747 21765921 0.026
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#02/data/diag_log_sm00_2023-05-15_15-19-16_rrc.csv True
# 6209 21870787 0.028
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#03/data/diag_log_sm00_2023-05-15_15-35-35_rrc.csv True
# 7572 21987999 0.034
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm00/#04/data/diag_log_sm00_2023-05-15_15-54-14_rrc.csv True
# 8078 22090606 0.037
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#01/data/diag_log_sm01_2023-05-15_14-50-43_rrc.csv True
# 8079 22205223 0.036
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#02/data/diag_log_sm01_2023-05-15_15-19-16_rrc.csv True
# 8081 22315180 0.036
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#03/data/diag_log_sm01_2023-05-15_15-35-35_rrc.csv True
# 8081 22435837 0.036
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm01/#04/data/diag_log_sm01_2023-05-15_15-54-14_rrc.csv True
# 9396 22547371 0.042
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#01/data/diag_log_sm02_2023-05-15_14-50-43_rrc.csv True
# 9397 22667425 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#02/data/diag_log_sm02_2023-05-15_15-19-16_rrc.csv True
# 9398 22778578 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#03/data/diag_log_sm02_2023-05-15_15-35-35_rrc.csv True
# 9402 22891387 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm02/#04/data/diag_log_sm02_2023-05-15_15-54-14_rrc.csv True
# 9404 22994648 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#01/data/diag_log_sm03_2023-05-15_14-50-43_rrc.csv True
# 9405 23106840 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#02/data/diag_log_sm03_2023-05-15_15-19-16_rrc.csv True
# 9405 23211465 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#03/data/diag_log_sm03_2023-05-15_15-35-35_rrc.csv True
# 9405 23323770 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm03/#04/data/diag_log_sm03_2023-05-15_15-54-14_rrc.csv True
# 9508 23421195 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#01/data/diag_log_sm04_2023-05-15_14-50-43_rrc.csv True
# 9509 23546024 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#02/data/diag_log_sm04_2023-05-15_15-19-16_rrc.csv True
# 9510 23651409 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#03/data/diag_log_sm04_2023-05-15_15-35-35_rrc.csv True
# 9512 23766341 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm04/#04/data/diag_log_sm04_2023-05-15_15-54-14_rrc.csv True
# 9735 23869275 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#01/data/diag_log_sm05_2023-05-15_14-50-43_rrc.csv True
# 9735 23991170 0.041
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#02/data/diag_log_sm05_2023-05-15_15-19-16_rrc.csv True
# 9755 24104882 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#03/data/diag_log_sm05_2023-05-15_15-35-35_rrc.csv True
# 9763 24221295 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm05/#04/data/diag_log_sm05_2023-05-15_15-54-14_rrc.csv True
# 9794 24328328 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#01/data/diag_log_sm06_2023-05-15_14-50-43_rrc.csv True
# 9794 24448242 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#02/data/diag_log_sm06_2023-05-15_15-19-16_rrc.csv True
# 9795 24554543 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#03/data/diag_log_sm06_2023-05-15_15-35-35_rrc.csv True
# 9795 24663587 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm06/#04/data/diag_log_sm06_2023-05-15_15-54-14_rrc.csv True
# 9865 24764608 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#01/data/diag_log_sm07_2023-05-15_14-50-43_rrc.csv True
# 9865 24905175 0.04
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#02/data/diag_log_sm07_2023-05-15_15-19-16_rrc.csv True
# 9865 25029752 0.039
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#03/data/diag_log_sm07_2023-05-15_15-35-35_rrc.csv True
# 9865 25161634 0.039
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-15/Bandlock_8_Schemes_Phone/sm07/#04/data/diag_log_sm07_2023-05-15_15-54-14_rrc.csv True
# 9865 25288350 0.039
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#01/data/diag_log_sm00_2023-05-24_14-26-30_rrc.csv True
# 10941 25402044 0.043
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#02/data/diag_log_sm00_2023-05-24_14-59-17_rrc.csv True
# 11355 25512503 0.045
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#03/data/diag_log_sm00_2023-05-24_15-10-53_rrc.csv True
# 11611 25632840 0.045
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#04/data/diag_log_sm00_2023-05-24_15-24-16_rrc.csv True
# 12508 25741176 0.049
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#05/data/diag_log_sm00_2023-05-24_15-35-31_rrc.csv True
# 12756 25862603 0.049
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#06/data/diag_log_sm00_2023-05-24_15-44-18_rrc.csv True
# 13281 25970336 0.051
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#07/data/diag_log_sm00_2023-05-24_15-55-31_rrc.csv True
# 13434 26093893 0.051
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm00/#08/data/diag_log_sm00_2023-05-24_16-14-22_rrc.csv True
# 14998 26197068 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#01/data/diag_log_sm01_2023-05-24_14-26-30_rrc.csv True
# 14998 26321766 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#02/data/diag_log_sm01_2023-05-24_14-59-17_rrc.csv True
# 15000 26431579 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#03/data/diag_log_sm01_2023-05-24_15-10-53_rrc.csv True
# 15049 26556177 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#04/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#04/data/diag_log_sm01_2023-05-24_15-24-16_rrc.csv True
# 15092 26668049 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#05/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#05/data/diag_log_sm01_2023-05-24_15-35-31_rrc.csv True
# 15092 26794268 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#06/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#06/data/diag_log_sm01_2023-05-24_15-44-18_rrc.csv True
# 15095 26904207 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#07/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#07/data/diag_log_sm01_2023-05-24_15-55-31_rrc.csv True
# 15095 27021871 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#08/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm01/#08/data/diag_log_sm01_2023-05-24_16-14-22_rrc.csv True
# 15096 27128263 0.056
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#01/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#01/data/diag_log_sm02_2023-05-24_14-26-30_rrc.csv True
# 15097 27251423 0.055
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#02/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#02/data/diag_log_sm02_2023-05-24_14-59-17_rrc.csv True
# 15678 27363191 0.057
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#03/data/udp_dnlk_loss_latency.csv True
# /Users/jackbedford/Desktop/MOXA/Code/data/2023-05-24/Bandlock_8_Schemes_Phone/sm02/#03/data/diag_log_sm02_2023-05-24_15-10-53_rrc.csv True
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 75
#      73     right = pd.Timestamp.max
#      74 ### Setup profile
# ---> 75 table, intv = setup_profile(df_dl, tag, start, end, mode='dl', left=left, right=right)
#      76 # print(intr)
#      77 # display(table)
#      78 A[tag]['tables'].append(table)
#
# Cell In[3], line 10, in setup_profile(df, tag, start, end, mode, left, right, fix, wsize)
#       8 else:
#       9     midpoint = start
# ---> 10     intv = P.closed(max(start-pd.Timedelta(seconds=ImpactScope[tag][0]), left), min(start+pd.Timedelta(seconds=ImpactScope[tag][1]), right))
#      11     if fix:
#      12         intv = P.closed(max(start-pd.Timedelta(seconds=wsize), left), min(start+pd.Timedelta(seconds=wsize), right))
#
# KeyError: 'SCG_Failure_randomAccessProblem (1)'
