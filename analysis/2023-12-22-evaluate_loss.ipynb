# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
from collections import namedtuple
import ast, swifter
import math
import portion as P
from pprint import pprint
import itertools as it
import random

# %%
src_dir = "/Users/jackbedford/Desktop/MOXA/Code/results/ho_coef"

coef_dl_lost = pd.read_csv(os.path.join(src_dir, "coef_dl_lost.csv"))
coef_ul_lost = pd.read_csv(os.path.join(src_dir, "coef_ul_lost.csv"))
coef_dl_excl = pd.read_csv(os.path.join(src_dir, "coef_dl_excl.csv"))
coef_ul_excl = pd.read_csv(os.path.join(src_dir, "coef_ul_excl.csv"))

# Add Stable Rates
# coef_dl_lost['0'] = coef_dl_lost['0'] + 0.25
# coef_ul_lost['0'] = coef_ul_lost['0'] + 0.25
# coef_dl_excl['0'] = coef_dl_excl['0'] + 0.8
# coef_ul_excl['0'] = coef_ul_excl['0'] + 4.0

lookup = { t: i for i, t in zip(range(13), ['LTEH', 'ENBH', 'MCGH', 'MNBH', 'SCGM', 'SCGA', 'SCGR-I', 'SCGR-II', 'SCGC-I', 'SCGC-II', 'MCGF', 'NASR', 'SCGF']) }
print(lookup)

# %%
coef_dl_lost
# Out:
#     lower_bd  upper_bd             0             1             2  \
# 0       -4.0       2.0 -5.613315e-40  1.445241e-39  6.291191e-38
# 1       -4.0       2.5 -2.338528e-40  1.576749e-40  2.505428e-38
# 2       -3.0       3.0 -4.519243e-40  1.058239e-39  5.147781e-38
# 3       -3.0       3.0  4.581831e-40 -9.373493e-40 -4.959622e-38
# 4       -3.0       3.0  1.768773e-40  4.834306e-40 -1.934180e-38
# 5       -3.0       2.5 -7.466011e-40 -2.359888e-39  8.727547e-38
# 6       -3.5       3.0  2.202577e-39 -2.663381e-39 -2.410594e-37
# 7       -2.0       3.0 -6.501229e-39  8.286914e-39  7.246835e-37
# 8       -3.0       3.0  2.716843e-39 -1.805323e-38 -2.878526e-37
# 9       -2.0       2.0 -7.952656e-40 -3.241215e-39  8.766370e-38
# 10      -5.0       7.5  1.483773e-57 -4.310941e-56 -4.693262e-55
# 11      -4.0       7.0 -6.232835e-57 -1.444396e-55  1.929800e-54
# 12      -4.0       5.0 -1.415805e-59 -8.951443e-57  4.855192e-57
#
#                3             4             5             6             7  ...  \
# 0  -1.533166e-37 -2.026036e-36  4.456022e-36 -7.993919e-36  3.265978e-35  ...
# 1  -1.685816e-38 -7.461285e-37  4.977907e-37 -4.650037e-36  3.373715e-36  ...
# 2  -1.095227e-37 -1.706522e-36  3.030317e-36 -5.165333e-36  2.699065e-35  ...
# 3   9.889321e-38  1.511682e-36 -2.834202e-36  8.157406e-36 -2.231160e-35  ...
# 4  -5.097320e-38  5.943111e-37  1.471640e-36  3.262016e-36  1.086907e-35  ...
# 5   2.363034e-37 -3.012948e-36 -6.096868e-36 -5.728669e-36 -6.839877e-35  ...
# 6   2.821187e-37  7.459578e-36 -8.161881e-36  3.798173e-35 -6.146536e-35  ...
# 7  -8.810120e-37 -2.316673e-35  2.575003e-35 -9.495680e-35  1.830262e-34  ...
# 8   1.926944e-36  8.378350e-36 -5.662020e-35  5.895708e-35 -3.970104e-34  ...
# 9   3.433856e-37 -2.754032e-36 -9.961641e-36 -1.254150e-35 -7.335484e-35  ...
# 10  1.492316e-53  3.652215e-53 -1.425541e-51  1.680980e-51 -3.161327e-50  ...
# 11  4.966098e-53 -1.439634e-52 -4.681915e-51 -7.183932e-51 -1.101424e-49  ...
# 12  3.043533e-54 -4.323003e-55 -2.808145e-52 -1.556393e-53 -7.212262e-51  ...
#
#            61          62          63          64          65          66  \
# 0   -4.977730   -7.884675    8.353484    8.911896   -7.907662   -4.397410
# 1   -1.403880   -2.351321    2.770031    3.011574   -3.128336   -1.601655
# 2    1.986219  -14.881949   -6.807891   20.282209   12.604766  -14.027036
# 3    1.665437    6.680852   -2.866021   -9.193331    3.611508    7.744371
# 4   -2.365594    0.021100    4.382213    0.077323   -4.819986    0.419052
# 5   -6.148847  -16.984990   10.671759   20.169474   -9.276183  -14.218569
# 6   10.022601   24.766863  -19.674633  -35.115875   24.261733   31.398534
# 7  -40.068350 -129.472148   72.903164  172.649828  -78.497821 -127.043793
# 8   74.470507  -26.817118 -128.213577   43.315545  126.204893  -30.770581
# 9   13.257393  -12.825697  -24.380031   15.226897   26.996447   -8.688123
# 10   0.497643   -0.433442   -3.225602    1.342915   12.945597    1.645639
# 11   0.920173    1.308505   -4.892760   -5.642505   15.478308   14.868002
# 12   0.053959   -0.011433   -0.330069    0.056055    1.243309   -0.007807
#
#            67         68         69         70
# 0    3.362643  -0.603356  -0.288055   1.094109
# 1    1.577676  -0.732964  -0.131101   1.244199
# 2  -12.005424   1.763817   4.568389   2.252739
# 3   -3.586829  -4.591406   2.270407   2.926755
# 4    2.641850  -1.274536  -0.303933   1.398154
# 5    3.111745   4.297020  -0.242806   1.179418
# 6  -17.391407 -16.874081   6.349790   6.137379
# 7   43.046031  40.388483  -6.049906   1.029534
# 8  -59.129140   0.497170   7.354908   9.006248
# 9  -15.983225   0.743474   4.354718   1.643048
# 10 -28.343919 -23.024971  24.730294  46.916747
# 11 -29.217953 -31.251401  29.355627  69.701345
# 12  -2.436875  -0.952022   1.435308   3.016702
#
# [13 rows x 73 columns]

# %%
def heaviside(x, left, right):
    if x < left:
        return 0
    elif x > right:
        return 0
    else:
        return 1

def poly_approx(coef_table, x_list, type, center=0):
    _coef = list(coef_table.loc[type])
    
    if center != 0:
        x_list = [x - center for x in x_list]
        
    lower_bd = _coef[0]
    upper_bd = _coef[1]
    coef = _coef[2:]
    p = np.poly1d(coef)
    
    return np.clip(p(x_list)*np.vectorize(heaviside)(x_list, lower_bd, upper_bd), a_min=0, a_max=100)

def generate_random_boolean(probability_true):
    return random.random() < probability_true

# %%
data_dir = "/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown"
dev = ['sm00', 'sm01', 'sm02', 'sm03']
tr = '#01'

filepaths = []
for dev in dev:
    filepaths.append([os.path.join(data_dir, dev, tr, 'data', 'handover_info_log.csv'), os.path.join(data_dir, dev, tr, 'data', 'udp_dnlk_loss_latency.csv')])

filepaths
# Out:
# [['/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/handover_info_log.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm00/#01/data/udp_dnlk_loss_latency.csv'],
#  ['/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/handover_info_log.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm01/#01/data/udp_dnlk_loss_latency.csv'],
#  ['/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/handover_info_log.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm02/#01/data/udp_dnlk_loss_latency.csv'],
#  ['/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/handover_info_log.csv',
#   '/Users/jackbedford/Desktop/MOXA/Code/data/2023-09-12-2/UDP_Bandlock_9S_Phone_Brown/sm03/#01/data/udp_dnlk_loss_latency.csv']]

# %%
random.seed(2023)

# for s in list(it.combinations(filepaths, 2))[:1]:
for s in list(it.combinations(filepaths, 2)):
    print(s[0][0][83:87], s[1][0][83:87])
    
    ho_df1 = pd.read_csv(s[0][0], parse_dates=['start'])[['type', 'start']]
    dl_df1 = pd.read_csv(s[0][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    ho_df2 = pd.read_csv(s[1][0], parse_dates=['start'])[['type', 'start']]
    dl_df2 = pd.read_csv(s[1][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    
    df = pd.merge(dl_df1, dl_df2, on='seq', how='outer')
    # display(df)
    
    splr_ground_truth = (df['lost_x'] & df['lost_y']).mean() * 100
    
    X1 = df['arr_time_x'].to_numpy()
    X2 = df['arr_time_y'].to_numpy()
    
    C1 = ho_df1['start'].to_numpy()
    C2 = ho_df2['start'].to_numpy()
    T1 = ho_df1['type'].to_numpy()
    T2 = ho_df2['type'].to_numpy()
    
    Z1 = [(X1 - c) / np.timedelta64(1, 's') for c in C1]
    Z2 = [(X2 - c) / np.timedelta64(1, 's') for c in C2]
    
    Yp1 = []
    for i in range(len(C1)):
        # print(i, T1[i])
        y = poly_approx(coef_dl_lost.copy(), Z1[i], lookup[T1[i]])
        Yp1.append(y)
    
    Yp2 = []   
    for i in range(len(C2)):
        # print(i, T2[i])
        y = poly_approx(coef_dl_lost.copy(), Z2[i], lookup[T2[i]])
        Yp2.append(y)
    
    Y1 = [sum(s)/100 for s in zip(*Yp1)]
    Y2 = [sum(s)/100 for s in zip(*Yp2)]
    Y = [y1*y2 for y1, y2 in zip(Y1, Y2)]
    
    inst = [generate_random_boolean(s) for s in Y]
    splr = sum(inst)/len(inst) * 100
    
    print(splr, splr_ground_truth)
# Out:
# sm00 sm01
# 0.04529129285476945 0.10292834310764584
# sm00 sm02
# 0.06405684409989199 0.18575073845266038
# sm00 sm03
# 0.027019571905571183 0.0
# sm01 sm02
# 0.08211692349369414 0.1549921657350911
# sm01 sm03
# 0.029912006495984803 0.06370410817423179
# sm02 sm03
# 0.01982375902210314 0.024479873240817757

# %%
# random.seed(2023)

# for s in list(it.combinations(filepaths, 2))[:1]:
for s in list(it.combinations(filepaths, 2)):
    print(s[0][0][83:87], s[1][0][83:87])
    
    ho_df1 = pd.read_csv(s[0][0], parse_dates=['start'])[['type', 'start']]
    dl_df1 = pd.read_csv(s[0][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    ho_df2 = pd.read_csv(s[1][0], parse_dates=['start'])[['type', 'start']]
    dl_df2 = pd.read_csv(s[1][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    
    df = pd.merge(dl_df1, dl_df2, on='seq', how='outer')
    # display(df)
    
    splr_ground_truth = (df['lost_x'] & df['lost_y']).mean() * 100
    
    X1 = df['arr_time_x'].to_numpy()
    X2 = df['arr_time_y'].to_numpy()
    
    C1 = ho_df1['start'].to_numpy()
    C2 = ho_df2['start'].to_numpy()
    T1 = ho_df1['type'].to_numpy()
    T2 = ho_df2['type'].to_numpy()
    
    Z1 = [(X1 - c) / np.timedelta64(1, 's') for c in C1]
    Z2 = [(X2 - c) / np.timedelta64(1, 's') for c in C2]
    
    Yp1 = []
    for i in range(len(C1)):
        # print(i, T1[i])
        y = poly_approx(coef_dl_lost.copy(), Z1[i], lookup[T1[i]])
        Yp1.append(y)
    
    Yp2 = []   
    for i in range(len(C2)):
        # print(i, T2[i])
        y = poly_approx(coef_dl_lost.copy(), Z2[i], lookup[T2[i]])
        Yp2.append(y)
    
    Y1 = [sum(s)/100 for s in zip(*Yp1)]
    Y2 = [sum(s)/100 for s in zip(*Yp2)]
    Y = [y1*y2 for y1, y2 in zip(Y1, Y2)]
    inst = [s if s <= 1 else 1 for s in Y]
    
    # inst = [generate_random_boolean(s) for s in Y]
    splr = sum(inst)/len(inst) * 100
    
    print(splr, splr_ground_truth)
# Out:
# sm00 sm01
# 0.04795262799574567 0.10292834310764584
# sm00 sm02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb Cell 8 line 4
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=36'>37</a>     y = poly_approx(coef_dl_lost.copy(), Z2[i], lookup[T2[i]])
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=37'>38</a>     Yp2.append(y)
# ---> <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=39'>40</a> Y1 = [sum(s)/100 for s in zip(*Yp1)]
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=40'>41</a> Y2 = [sum(s)/100 for s in zip(*Yp2)]
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=41'>42</a> Y = [y1*y2 for y1, y2 in zip(Y1, Y2)]
#
# /Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb Cell 8 line 4
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=36'>37</a>     y = poly_approx(coef_dl_lost.copy(), Z2[i], lookup[T2[i]])
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=37'>38</a>     Yp2.append(y)
# ---> <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=39'>40</a> Y1 = [sum(s)/100 for s in zip(*Yp1)]
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=40'>41</a> Y2 = [sum(s)/100 for s in zip(*Yp2)]
#      <a href='vscode-notebook-cell:/Users/jackbedford/Desktop/MOXA/Code/wmnl-handoff-research/analysis/2023-12-22-evaluate_loss.ipynb#X44sZmlsZQ%3D%3D?line=41'>42</a> Y = [y1*y2 for y1, y2 in zip(Y1, Y2)]
#
# KeyboardInterrupt:

# %%
# random.seed(2023)

devices = []
Ground_Truth = []
YY = []
# for s in list(it.combinations(filepaths, 2))[:1]:
for s in list(it.combinations(filepaths, 2)):
    print(s[0][0][83:87], s[1][0][83:87])
    devices.append((s[0][0][83:87], s[1][0][83:87]))
    
    ho_df1 = pd.read_csv(s[0][0], parse_dates=['start'])[['type', 'start']]
    dl_df1 = pd.read_csv(s[0][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    ho_df2 = pd.read_csv(s[1][0], parse_dates=['start'])[['type', 'start']]
    dl_df2 = pd.read_csv(s[1][1], parse_dates=['xmit_time', 'arr_time'])[['seq', 'lost', 'excl', 'xmit_time', 'arr_time']]
    
    df = pd.merge(dl_df1, dl_df2, on='seq', how='outer')
    # display(df)
    
    splr_ground_truth = (df['lost_x'] & df['lost_y']).mean() * 100
    Ground_Truth.append(splr_ground_truth)
    
    X1 = df['arr_time_x'].to_numpy()
    X2 = df['arr_time_y'].to_numpy()
    
    C1 = ho_df1['start'].to_numpy()
    C2 = ho_df2['start'].to_numpy()
    T1 = ho_df1['type'].to_numpy()
    T2 = ho_df2['type'].to_numpy()
    
    Z1 = [(X1 - c) / np.timedelta64(1, 's') for c in C1]
    Z2 = [(X2 - c) / np.timedelta64(1, 's') for c in C2]
    
    Yp1 = []
    for i in range(len(C1)):
        # print(i, T1[i])
        y = poly_approx(coef_dl_lost.copy(), Z1[i], lookup[T1[i]])
        Yp1.append(y)
    
    Yp2 = []   
    for i in range(len(C2)):
        # print(i, T2[i])
        y = poly_approx(coef_dl_lost.copy(), Z2[i], lookup[T2[i]])
        Yp2.append(y)
    
    Y1 = [sum(s)/100 for s in zip(*Yp1)]
    Y2 = [sum(s)/100 for s in zip(*Yp2)]
    Y = [y1*y2 for y1, y2 in zip(Y1, Y2)]
    
    YY.append(Y)
    # inst = [s if s <= 1 else 1 for s in Y]
    
    # # inst = [generate_random_boolean(s) for s in Y]
    # splr = sum(inst)/len(inst) * 100
    
    # print(splr, splr_ground_truth)
# Out:
# sm00 sm01
# sm00 sm02
# sm00 sm03
# sm01 sm02
# sm01 sm03
# sm02 sm03

# %%
for splr_ground_truth, Y, dev in zip(Ground_Truth, YY, devices):
    inst = Y[:]
    splr = sum(inst)/len(inst) * 100
    print(dev[0], dev[1], splr, splr_ground_truth)
# Out:
# sm00 sm01 0.04795262799574567 0.10292834310764584
# sm00 sm02 0.06227603239691229 0.18575073845266038
# sm00 sm03 0.027779043538003544 0.0
# sm01 sm02 0.08089369855499604 0.1549921657350911
# sm01 sm03 0.03016214926831889 0.06370410817423179
# sm02 sm03 0.019133332114844432 0.024479873240817757

# %%
for splr_ground_truth, Y, dev in zip(Ground_Truth, YY, devices):
    inst = [s if s <= 1 else 1 for s in Y]
    splr = sum(inst)/len(inst) * 100
    print(dev[0], dev[1], splr, splr_ground_truth)
# Out:
# sm00 sm01 0.04795262799574567 0.10292834310764584
# sm00 sm02 0.06227603239691229 0.18575073845266038
# sm00 sm03 0.027779043538003544 0.0
# sm01 sm02 0.08089369855499604 0.1549921657350911
# sm01 sm03 0.03016214926831889 0.06370410817423179
# sm02 sm03 0.019133332114844432 0.024479873240817757

# %%
random.seed(2023)
for splr_ground_truth, Y, dev in zip(Ground_Truth, YY, devices):
    inst = [generate_random_boolean(s) for s in Y]
    splr = sum(inst)/len(inst) * 100
    print(dev[0], dev[1], splr, splr_ground_truth)
# Out:
# sm00 sm01 0.04529129285476945 0.10292834310764584
# sm00 sm02 0.06405684409989199 0.18575073845266038
# sm00 sm03 0.027019571905571183 0.0
# sm01 sm02 0.08211692349369414 0.1549921657350911
# sm01 sm03 0.029912006495984803 0.06370410817423179
# sm02 sm03 0.01982375902210314 0.024479873240817757
