# %%
import pickle
import pandas as pd

df = pd.read_pickle('./coef_dl.pkl')
df
# Out:
#                                          lower_bd  upper_bd              0  \
# LTE_HO                                      -1.11      0.70  -1.089502e+07
# MN_HO                                       -1.39      1.62   2.869516e-06
# SN_HO                                       -0.87      1.28   3.019131e+02
# SN_Rel                                      -0.03      0.10  -8.813934e+69
# SN_Setup                                    -0.36      1.50  -9.708248e-03
# SN_Rel_MN_HO                                -0.40      0.58   5.027934e+27
# SCG_Failure_t310-Expiry (0)                 -1.50      1.20   5.138315e-01
# SCG_Failure_synchReconfigFailureSCG (3)     -0.03      0.03 -1.340324e+106
# MCG_Failure_handoverFailure (1)             -0.70      1.23  -1.615089e+02
# MCG_Failure_otherFailure (2)                -5.66      1.25   2.650991e-42
# NAS_Recovery_handoverFailure (1)            -0.50      0.50   5.731293e+27
# ...
